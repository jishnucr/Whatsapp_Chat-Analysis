# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import re
import datetime as dt
# %matplotlib inline

# %%
f = open('WhatsApp_Chat_with_Data_science .txt','r',encoding='utf-8')

data = f.read()

# %%
raw = data.split('\n')
raw
# Out:
# ['26/02/24, 3:50\u202fpm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.',
#  '26/02/24, 3:01\u202fpm - jisshnu.___ (DS-Codeme) created group "Data science "',
#  '26/02/24, 3:50\u202fpm - jisshnu.___ (DS-Codeme) added you',
#  '26/02/24, 3:51\u202fpm - jisshnu.___ (DS-Codeme) added +91 86181 86237',
#  '26/02/24, 3:51\u202fpm - jisshnu.___ (DS-Codeme): try to do the project  yourself first then only refer the collab',
#  '26/02/24, 3:51\u202fpm - jisshnu.___ (DS-Codeme): https://colab.research.google.com/drive/1tKXB0p6bcZ4gwTUNjp9zNpRMYxC952qj?usp=sharing',
#  '27/02/24, 11:39\u202fam - Asif (CodeMe): https://meet.google.com/xsu-gthd-hmw',
#  '27/02/24, 12:46\u202fpm - Asif (CodeMe): https://colab.research.google.com/drive/1b_r9LNdmeSGUUIlFSQUteLKw07ESr5iQ?usp=sharing',
#  '27/02/24, 3:32\u202fpm - Asif (CodeMe): https://colab.research.google.com/drive/1yIHdz2bMzzLvGqh1Dq02AAwyYFbnJAf-?usp=sharing',
#  '27/02/24, 3:34\u202fpm - Asif (CodeMe): Refer this also while doing your project to understand how to use the sampling techniques. here i balanced the data after splitting to train and test',
#  '28/02/24, 9:16\u202fam - Asif (CodeMe): https://meet.google.com/sdk-sqzo-unn',
#  '28/02/24, 11:20\u202fam - Asif (CodeMe): https://docs.google.com/document/d/1SlzY5P0wQPr8ZsgBUc4m1mkr-fu-nlRZqBu_am2ZH2M/edit?usp=sharing',
#  '28/02/24, 11:59\u202fam - Aysha Hamna(CodeMe): https://meet.google.com/xut-tqwq-pcd',
#  '28/02/24, 12:01\u202fpm - jisshnu.___ (DS-Codeme) added +91 79077 33950',
#  '28/02/24, 1:20\u202fpm - Aysha Hamna(CodeMe): <Media omitted>',
#  '28/02/24, 1:20\u202fpm - Aysha Hamna(CodeMe): https://colab.research.google.com/drive/1ljIcfFMyAOJpIRWrrWa-61vppqIydnRU?usp=sharing',
#  '29/02/24, 9:08\u202fam - Asif (CodeMe): Same link',
#  '01/03/24, 9:25\u202fam - Asif (CodeMe): same link',
#  '01/03/24, 10:11\u202fam - Asif (CodeMe): https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit?usp=sharing',
#  '01/03/24, 11:43\u202fam - Aysha Hamna(CodeMe): https://meet.google.com/uiv-vkou-pda',
#  '01/03/24, 12:06\u202fpm - Aysha Hamna(CodeMe): <Media omitted>',
#  '01/03/24, 2:25\u202fpm - Aysha Hamna(CodeMe): join using same link',
#  '01/03/24, 3:44\u202fpm - Aysha Hamna(CodeMe): https://colab.research.google.com/drive/1P9fduGtId539V1MYs2ScQLPC6Ph8PrSx?usp=sharing',
#  '04/03/24, 9:27\u202fam - +91 86181 86237: Class started?',
#  '04/03/24, 9:30\u202fam - jisshnu.___ (DS-Codeme): no',
#  '04/03/24, 9:34\u202fam - Asif (CodeMe): https://meet.google.com/ind-raij-vzt',
#  '04/03/24, 9:44\u202fam - jisshnu.___ (DS-Codeme): https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit#gid=0',
#  '04/03/24, 11:48\u202fam - Aysha Hamna(CodeMe): This message was deleted',
#  '04/03/24, 11:50\u202fam - +91 94966 64940: It’s showing no such meeting',
#  '04/03/24, 11:50\u202fam - Aysha Hamna(CodeMe): https://meet.google.com/zpy-qjbm-sbj',
#  '04/03/24, 1:23\u202fpm - Asif (CodeMe): <Media omitted>',
#  '04/03/24, 3:05\u202fpm - Aysha Hamna(CodeMe): please join',
#  '04/03/24, 4:47\u202fpm - Amal (DS-Codeme): This message was deleted',
#  '04/03/24, 4:51\u202fpm - Rashid (DS-Codeme): Waiting for this message',
#  '04/03/24, 5:58\u202fpm - jisshnu.___ (DS-Codeme): <Media omitted>',
#  '05/03/24, 9:22\u202fam - Asif (CodeMe): SAME LINK',
#  '05/03/24, 10:07\u202fam - jisshnu.___ (DS-Codeme): <Media omitted>',
#  '05/03/24, 1:01\u202fpm - Asif (CodeMe): <Media omitted>',
#  '05/03/24, 1:01\u202fpm - Asif (CodeMe): <Media omitted>',
#  '05/03/24, 1:01\u202fpm - Asif (CodeMe): <Media omitted>',
#  '05/03/24, 5:34\u202fpm - Asif (CodeMe): <Media omitted>',
#  '06/03/24, 9:19\u202fam - Asif (CodeMe): same link',
#  '06/03/24, 12:09\u202fpm - Aysha Hamna(CodeMe): https://meet.google.com/ewj-ckus-jmv',
#  '06/03/24, 12:15\u202fpm - Aysha Hamna(CodeMe): https://hamoyehq.medium.com/hamoye-data-science-internship-fall-2024-call-for-application-79488110376d',
#  '06/03/24, 12:15\u202fpm - Aysha Hamna(CodeMe): https://docs.google.com/forms/d/e/1FAIpQLSe9Sr9L3H7oObSSZSB-qndQYNal1OGGcyTBfOppZLyuOKWPRg/viewform',
#  '06/03/24, 1:08\u202fpm - jisshnu.___ (DS-Codeme): <Media omitted>',
#  '06/03/24, 5:09\u202fpm - +91 94966 64940: Problem statement 🌚',
#  '06/03/24, 5:22\u202fpm - jisshnu.___ (DS-Codeme): EDA + Classification + Power BI',
#  '06/03/24, 5:23\u202fpm - jisshnu.___ (DS-Codeme): = certificate',
#  '06/03/24, 5:24\u202fpm - +91 94966 64940: This message was deleted',
#  '06/03/24, 7:13\u202fpm - NISAMLC: <Media omitted>',
#  '07/03/24, 9:25\u202fam - Asif (CodeMe): Same link',
#  '07/03/24, 9:36\u202fam - Asif (CodeMe): Some network issue',
#  '07/03/24, 10:10\u202fam - +91 86181 86237: This message was deleted',
#  '07/03/24, 10:15\u202fam - Asif (CodeMe): No join again',
#  '07/03/24, 2:41\u202fpm - Asif (CodeMe): same link join',
#  '08/03/24, 9:21\u202fam - Asif (CodeMe): Join the same link',
#  '08/03/24, 9:24\u202fam - +91 94966 64940: Please let me in',
#  "10/03/24, 8:41\u202fpm - Aysha Hamna(CodeMe): Tomorrow's machine learning class will start at 2 15 pm",
#  '10/03/24, 8:53\u202fpm - jisshnu.___ (DS-Codeme): This message was deleted',
#  '11/03/24, 9:48\u202fam - Asif (CodeMe): https://meet.google.com/ind-raij-vzt',
#  '11/03/24, 9:48\u202fam - Asif (CodeMe): This message was deleted',
#  '11/03/24, 9:48\u202fam - Asif (CodeMe): Join the link',
#  '11/03/24, 10:00\u202fam - +91 94966 64940: CREATE TABLE event (',
#  'event_id SERIAL PRIMARY KEY,',
#  'event_name VARCHAR(100),',
#  'event_date DATE,',
#  'event_time TIME',
#  ');',
#  'INSERT INTO event (event_id,event_name, event_date, event_time) VALUES',
#  "(1,'Meeting 1', '2024-03-02', '15:30:00'),",
#  "(2,'Meeting 2', '2023-03-03', '09:00:00'),",
#  "(3,'Conference', '2024-03-04', '10:45:00'),",
#  "(4,'Workshop', '2022-03-05', '13:00:00'),",
#  "(5,'Seminar', '2024-03-06', '16:15:00');",
#  '11/03/24, 2:48\u202fpm - Asif (CodeMe): join the same link',
#  '12/03/24, 9:30\u202fam - Amal (DS-Codeme): same link',
#  '12/03/24, 2:39\u202fpm - Asif (CodeMe): ds join the same link',
#  '13/03/24, 9:22\u202fam - jisshnu.___ (DS-Codeme): same',
#  '13/03/24, 11:39\u202fam - Aysha Hamna(CodeMe): https://meet.google.com/ewj-ckus-jmv',
#  '13/03/24, 2:32\u202fpm - Aysha Hamna(CodeMe): SAME LINK',
#  '13/03/24, 3:12\u202fpm - Aysha Hamna(CodeMe): <Media omitted>',
#  '14/03/24, 9:24\u202fam - Rashid (DS-Codeme): same link',
#  '14/03/24, 9:25\u202fam - Rashid (DS-Codeme): https://meet.google.com/ind-raij-vzt',
#  '14/03/24, 9:39\u202fam - +91 86181 86237: Let me into the class.',
#  '14/03/24, 9:42\u202fam - Rashid (DS-Codeme): network issue',
#  '14/03/24, 9:42\u202fam - +91 86181 86237: Ok',
#  '14/03/24, 9:43\u202fam - Rashid (DS-Codeme): wait couple of minutes',
#  '14/03/24, 10:36\u202fam - jisshnu.___ (DS-Codeme): This message was deleted',
#  '14/03/24, 2:36\u202fpm - Asif (CodeMe): Join the same link..',
#  '14/03/24, 2:36\u202fpm - Asif (CodeMe): .',
#  '14/03/24, 2:39\u202fpm - jisshnu.___ (DS-Codeme): in akkettilla',
#  '14/03/24, 2:39\u202fpm - Asif (CodeMe): Network issue und',
#  '14/03/24, 2:39\u202fpm - Asif (CodeMe): Wait',
#  '14/03/24, 2:39\u202fpm - jisshnu.___ (DS-Codeme): ok',
#  '14/03/24, 2:54\u202fpm - Asif (CodeMe): Join',
#  '14/03/24, 3:20\u202fpm - +91 94966 64940: Class ille',
#  '14/03/24, 3:20\u202fpm - +91 94966 64940: ??',
#  '14/03/24, 3:51\u202fpm - Asif (CodeMe): https://www.kdnuggets.com/2020/06/naive-bayes-algorithm-everything.html',
#  '15/03/24, 9:20\u202fam - Asif (CodeMe): \U0001f6dc WiFi Passwords\U0001f6dc',
#  '',
#  '*WiFi Name*: Codeme Hub (5G)',
#  '*Password*: codeme12##',
#  '',
#  '*WiFi Name*: Codeme Tech Learning',
#  '*Password*: codeme123##',
#  '15/03/24, 9:22\u202fam - Asif (CodeMe): join the same link',
#  '15/03/24, 12:54\u202fpm - Aysha Hamna(CodeMe): ML session will start at 2:15 pm',
#  '15/03/24, 2:18\u202fpm - Asif (CodeMe): join the same link',
#  '18/03/24, 9:13\u202fam - Asif (CodeMe): Same link',
#  '18/03/24, 12:29\u202fpm - Asif (CodeMe): ML Same link',
#  '18/03/24, 2:35\u202fpm - Asif (CodeMe): same limk',
#  '18/03/24, 3:46\u202fpm - jisshnu.___ (DS-Codeme): https://colab.research.google.com/drive/108YjV5uDkumB8aw5RMrie3rLCeyWcNk4?usp=sharing',
#  '19/03/24, 9:29\u202fam - Amal (DS-Codeme): Same link 9:35',
#  '19/03/24, 12:00\u202fpm - Asif (CodeMe): <Media omitted>',
#  '19/03/24, 12:01\u202fpm - Asif (CodeMe): Mandatory SQL Assessment',
#  'Deadline 9 AM- 20-03-2024',
#  '19/03/24, 3:46\u202fpm - Asif (CodeMe): This message was deleted',
#  '19/03/24, 4:07\u202fpm - Asif (CodeMe): Tomorrow Dax class will be from 11.15- 1.15 PM',
#  '19/03/24, 4:07\u202fpm - Asif (CodeMe): ML Class will be from 9 AM To 11 Am',
#  '20/03/24, 9:20\u202fam - Aysha Hamna(CodeMe): https://meet.google.com/uew-zqmr-sth',
#  '20/03/24, 11:27\u202fam - Aysha Hamna(CodeMe): <Media omitted>',
#  '20/03/24, 11:50\u202fam - Amal (DS-Codeme): same link',
#  "20/03/24, 4:23\u202fpm - Asif (CodeMe): I haven't received the SQL assessment @918618186237 ,send it ASAP",
#  '20/03/24, 4:24\u202fpm - +91 86181 86237: Where I I have to send it in  group',
#  '20/03/24, 4:24\u202fpm - Asif (CodeMe): Send here',
#  '20/03/24, 4:28\u202fpm - +91 86181 86237: This message was deleted',
#  '20/03/24, 4:30\u202fpm - Asif (CodeMe): This message was deleted',
#  '21/03/24, 9:52\u202fam - Asif (CodeMe): Power bi join the same link <This message was edited>',
#  '21/03/24, 1:18\u202fpm - Asif (CodeMe): <Media omitted>',
#  '22/03/24, 9:20\u202fam - Asif (CodeMe): Power bi same link',
#  '22/03/24, 11:18\u202fam - jisshnu.___ (DS-Codeme): screen poi',
#  '22/03/24, 11:42\u202fam - Asif (CodeMe): <Media omitted>',
#  '22/03/24, 2:03\u202fpm - Aysha Hamna(CodeMe): https://meet.google.com/uew-zqmr-sth',
#  '22/03/24, 2:03\u202fpm - Aysha Hamna(CodeMe): Join please',
#  '23/03/24, 2:31\u202fpm - Asif (CodeMe): Monday ',
#  "9-11 ML Aysha Ma'am ",
#  '11.15- 1.30 Power BI',
#  '23/03/24, 2:38\u202fpm - jisshnu.___ (DS-Codeme): Afternoon',
#  '23/03/24, 2:39\u202fpm - jisshnu.___ (DS-Codeme): Ille',
#  '23/03/24, 2:49\u202fpm - Asif (CodeMe): Class kaanum afternoon for ds',
#  '25/03/24, 9:28\u202fam - Aysha Hamna(CodeMe): join',
#  '25/03/24, 11:42\u202fam - Rashid (DS-Codeme): dax same link',
#  '25/03/24, 11:42\u202fam - Rashid (DS-Codeme): https://meet.google.com/ind-raij-vzt',
#  '25/03/24, 12:26\u202fpm - Rashid (DS-Codeme): <Media omitted>',
#  '25/03/24, 2:09\u202fpm - Aysha Hamna(CodeMe): https://www.kaggle.com/datasets/brijbhushannanda1979/bigmart-sales-data',
#  '25/03/24, 2:09\u202fpm - Aysha Hamna(CodeMe): Download dataset from this link and perform EDA',
#  '25/03/24, 2:09\u202fpm - Aysha Hamna(CodeMe): and then apply any regression model',
#  '25/03/24, 3:00\u202fpm - Aysha Hamna(CodeMe): Complete this task today',
#  "25/03/24, 3:00\u202fpm - Aysha Hamna(CodeMe): We postponed today's afternoon session",
#  '26/03/24, 11:33\u202fam - Asif (CodeMe): Power bi same link',
#  '26/03/24, 12:21\u202fpm - Asif (CodeMe): <Media omitted>',
#  '26/03/24, 2:09\u202fpm - Asif (CodeMe): <Media omitted>',
#  '27/03/24, 8:33\u202fam - +91 94966 64940: ML class',
#  'Will start at 11:00Am',
#  'Aysha Ma’am',
#  '27/03/24, 9:11\u202fam - jisshnu.___ (DS-Codeme): 👍🏽',
#  '27/03/24, 11:18\u202fam - Aysha Hamna(CodeMe): join',
#  '27/03/24, 12:15\u202fpm - Aysha Hamna(CodeMe): <Media omitted>',
#  '27/03/24, 12:34\u202fpm - Aysha Hamna(CodeMe): <Media omitted>',
#  '27/03/24, 12:38\u202fpm - Aysha Hamna(CodeMe): <Media omitted>',
#  '27/03/24, 1:03\u202fpm - Aysha Hamna(CodeMe): https://www.kaggle.com/competitions/titanic/data',
#  '27/03/24, 2:29\u202fpm - Aysha Hamna(CodeMe): join',
#  '27/03/24, 4:55\u202fpm - Asif (CodeMe): PCA Tomorrow 11.30-1 and 2.15 -3.45',
#  '28/03/24, 9:10\u202fam - Asif (CodeMe): 4th floor aan class 11.30',
#  '28/03/24, 11:30\u202fam - Asif (CodeMe): https://meet.google.com/svp-wgoq-ajb',
#  '28/03/24, 11:30\u202fam - Asif (CodeMe): join',
#  '28/03/24, 2:25\u202fpm - Amal (DS-Codeme): 2.30 join',
#  '31/03/24, 6:05\u202fpm - Amal (DS-Codeme): https://www.microsoft.com/en-us/cloudskillschallenge/ai/registration/2024?ocid=aisc23_CSC_skillsforaiblog_cnl#choose-your-challenge',
#  '31/03/24, 9:11\u202fpm - NISAMLC: Tomorrow 2.00PM:Lecture On Recommendation Engines, build your first Recommender <This message was edited>',
#  '01/04/24, 2:02\u202fpm - NISAMLC: How many of you are attending Offline??',
#  '01/04/24, 2:03\u202fpm - jisshnu.___ (DS-Codeme): Im not',
#  '01/04/24, 2:03\u202fpm - +91 94966 64940: 🤚🏻',
#  '01/04/24, 2:04\u202fpm - Amal (DS-Codeme): ✌🏻',
#  '01/04/24, 2:04\u202fpm - NISAMLC: Conference Hall <This message was edited>',
#  '01/04/24, 2:18\u202fpm - +91 86181 86237: No online class?',
#  '01/04/24, 2:31\u202fpm - Rashid (DS-Codeme): https://meet.google.com/yyp-ybak-jqd',
#  '01/04/24, 3:51\u202fpm - NISAMLC: <Media omitted>',
#  '02/04/24, 2:02\u202fpm - NISAMLC: You deleted this message',
#  '02/04/24, 2:05\u202fpm - Amal (DS-Codeme): https://meet.google.com/jiy-cjvd-ums',
#  '02/04/24, 2:07\u202fpm - NISAMLC: join in this',
#  '02/04/24, 4:05\u202fpm - NISAMLC: <Media omitted>',
#  '02/04/24, 4:06\u202fpm - NISAMLC: <Media omitted>',
#  '03/04/24, 2:10\u202fpm - NISAMLC: https://meet.google.com/wpa-gyyd-kte',
#  '04/04/24, 1:13\u202fpm - NISAMLC: class starts @2.30 pm today <This message was edited>',
#  '04/04/24, 2:40\u202fpm - NISAMLC: SAME LINK',
#  '04/04/24, 3:19\u202fpm - NISAMLC: <Media omitted>',
#  '04/04/24, 4:03\u202fpm - NISAMLC: https://github.com/JovianHQ/opendatasets/blob/master/data/countries-languages-spoken/countries-languages.csv <This message was edited>',
#  '04/04/24, 4:03\u202fpm - NISAMLC: Create a Country Recommender based on the language spoken',
#  '04/04/24, 4:07\u202fpm - NISAMLC: https://www.kaggle.com/datasets/dylanjcastillo/7k-books-with-metadata',
#  '04/04/24, 4:08\u202fpm - NISAMLC: Build a Book Recommender based on the description about the book',
#  '04/04/24, 4:14\u202fpm - +91 86181 86237: This message was deleted',
#  '04/04/24, 4:16\u202fpm - jisshnu.___ (DS-Codeme): ok',
#  '05/04/24, 9:15\u202fam - NISAMLC: No class today, try to explore more recommendation systems using various datasets',
#  '05/04/24, 9:15\u202fam - Rashid (DS-Codeme): Okay',
#  '05/04/24, 10:46\u202fam - jisshnu.___ (DS-Codeme): Okay',
#  '05/04/24, 9:46\u202fpm - Rashid (DS-Codeme): https://www.youtube.com/live/wB7m2YMqVVY?si=IJq7IixEgva7Tu8t',
#  '05/04/24, 9:47\u202fpm - Rashid (DS-Codeme): live class of hamoye',
#  '08/04/24, 1:54\u202fpm - NISAMLC: Anyone offline??',
#  '08/04/24, 2:00\u202fpm - NISAMLC: https://us05web.zoom.us/j/89944631210?pwd=Vi6hcSNnsdHS5bQgh5r44jeHLt9Hgo.1',
#  '08/04/24, 2:02\u202fpm - NISAMLC: join',
#  '08/04/24, 2:34\u202fpm - NISAMLC: https://meet.google.com/eir-sawr-tui',
#  '08/04/24, 2:34\u202fpm - NISAMLC: rejoin',
#  '09/04/24, 1:42\u202fpm - NISAMLC: <Media omitted>',
#  '09/04/24, 2:08\u202fpm - NISAMLC: https://meet.google.com/xuo-ahea-zvc',
#  '09/04/24, 2:08\u202fpm - NISAMLC: join',
#  '11/04/24, 3:17\u202fpm - NISAMLC: *Create a recommendation system which recommends books or documents* Data:scrape data from websites like goodreads and scribd or any other website, do it and submit it before coming monday 9..00AM try <This message was edited>',
#  '15/04/24, 4:25\u202fpm - NISAMLC: Tomorrow onwards There will be two sessions are going on for *Data Science* students',
#  '- 11.00pm to 1.00pm : Time Series Forecasting',
#  '- 2.30 to 5.00pm : MLOPS AND Recommendation Systems',
#  "16/04/24, 11:25\u202fam - +91 86181 86237: today's class is there?",
#  '16/04/24, 11:25\u202fam - Aysha Hamna(CodeMe): This message was deleted',
#  '16/04/24, 11:26\u202fam - Amal (DS-Codeme): https://us05web.zoom.us/j/84356593130?pwd=tE40wZMVVhZahfQfpMlWmaiuQMdVEh.1',
#  '16/04/24, 11:28\u202fam - +91 86181 86237: ML class?',
#  '16/04/24, 11:28\u202fam - Amal (DS-Codeme): Join',
#  '16/04/24, 11:45\u202fam - Amal (DS-Codeme): This message was deleted',
#  '16/04/24, 11:45\u202fam - Amal (DS-Codeme): This message was deleted',
#  '16/04/24, 11:46\u202fam - NISAMLC: join in this link',
#  '16/04/24, 11:46\u202fam - NISAMLC: https://us05web.zoom.us/j/82662632874?pwd=lgeKSnCVezGajLEX1IeAx3TBlt6Xd8.1',
#  '16/04/24, 12:30\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83954675823?pwd=hZBXtKvZBMKaci3f79IzVd4Munacw5.1',
#  '16/04/24, 12:30\u202fpm - jisshnu.___ (DS-Codeme): rejoin',
#  '16/04/24, 1:10\u202fpm - jisshnu.___ (DS-Codeme): 2.30',
#  '16/04/24, 1:10\u202fpm - jisshnu.___ (DS-Codeme): next class',
#  '16/04/24, 2:23\u202fpm - NISAMLC: join immediately',
#  '16/04/24, 2:24\u202fpm - NISAMLC: link  comes',
#  '16/04/24, 2:27\u202fpm - NISAMLC: https://us05web.zoom.us/j/89882762836?pwd=f4OJJDwtrLYksEeOXGEua1VsSK1gS0.1',
#  '16/04/24, 3:09\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83124834127?pwd=CZnC3e1LCu4BZKbtXpoR8vdUF0bY8W.1',
#  '16/04/24, 3:10\u202fpm - jisshnu.___ (DS-Codeme): rejoin',
#  '16/04/24, 3:51\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/84698759689?pwd=jc3uaX38A8XKT9i8aGEyEeV4FGOhbD.1',
#  '16/04/24, 4:31\u202fpm - NISAMLC: last join',
#  '16/04/24, 4:32\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87597044212?pwd=eYhexXtU8wlpMxKP894sKaZ9ESCEFv.1',
#  '17/04/24, 10:56\u202fam - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/81088179003?pwd=4cy88JdC9vDOk311hla6REoyV4ZHw5.1',
#  '17/04/24, 10:56\u202fam - jisshnu.___ (DS-Codeme): join',
#  '17/04/24, 11:37\u202fam - NISAMLC: https://us05web.zoom.us/j/85900123290?pwd=dHszQjo1DUVTUUK0eulZhlDGN0ePKE.1',
#  '17/04/24, 11:37\u202fam - NISAMLC: join',
#  '17/04/24, 11:55\u202fam - NISAMLC: <Media omitted>',
#  '17/04/24, 12:18\u202fpm - NISAMLC: <Media omitted>',
#  '17/04/24, 12:18\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/85320192983?pwd=mbloGXvXoW4fR5CrQ7tkevcaB2X2ZM.1',
#  '17/04/24, 12:18\u202fpm - jisshnu.___ (DS-Codeme): rejoin',
#  '17/04/24, 2:25\u202fpm - NISAMLC: join immediately',
#  '17/04/24, 2:29\u202fpm - NISAMLC: https://us05web.zoom.us/j/86955036516?pwd=bKixQEfWmQTdTbHwDigNVcsZSmkHx4.1',
#  '17/04/24, 3:11\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/88418826144?pwd=AGMp0uqMGf2gF6uSZwgJ1HqTyAjXTi.1',
#  '17/04/24, 3:52\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83068961004?pwd=fwxUEnK21rZ1M2Qn46HBArPHwUiU2g.1',
#  '17/04/24, 4:16\u202fpm - NISAMLC: https://www.kaggle.com/datasets/zygmunt/goodbooks-10k',
#  '18/04/24, 11:13\u202fam - NISAMLC: https://us05web.zoom.us/j/82196771153?pwd=5SBVgnTDk5F6vIjFduX0TzsL5VeCFa.1',
#  '18/04/24, 11:57\u202fam - Amal (DS-Codeme): https://us05web.zoom.us/j/81310056571?pwd=9bpbaQ6goaGabCrJPHmoKHR7oFPKu5.1',
#  '18/04/24, 2:23\u202fpm - NISAMLC: join immediately',
#  '18/04/24, 2:30\u202fpm - Amal (DS-Codeme): https://us05web.zoom.us/j/84126238187?pwd=WPsF79MUYkPRheBHE3vTRqdxLUqyml.1',
#  '18/04/24, 3:11\u202fpm - Amal (DS-Codeme): https://us05web.zoom.us/j/88298798338?pwd=OXqo2o2NfHu3Ty2Y5hkua2Ut3KXCP0.1',
#  '18/04/24, 3:52\u202fpm - Amal (DS-Codeme): https://us05web.zoom.us/j/84745853077?pwd=xmT9cP4e5uSFiaUD6dcLrnkabbRMfj.1',
#  '19/04/24, 11:06\u202fam - NISAMLC: JOIN',
#  '19/04/24, 11:06\u202fam - NISAMLC: https://us05web.zoom.us/j/85029807729?pwd=R2FC3g5JSz2Cmk2327RnGCnwrgbG1X.1',
#  '19/04/24, 11:13\u202fam - +91 86181 86237: Please add in',
#  '19/04/24, 11:15\u202fam - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): This message was deleted',
#  '19/04/24, 11:50\u202fam - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/84998061454?pwd=Hf7VPgXs9s10R6kaWHp9fSvP2SChXG.1',
#  '19/04/24, 12:13\u202fpm - NISAMLC: <Media omitted>',
#  '19/04/24, 2:49\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/88476935533?pwd=NGwH2oEMx62JoUOu6XIcj7GgiLQiUh.1',
#  '19/04/24, 3:28\u202fpm - NISAMLC: https://www.kaggle.com/datasets/prajitdatta/movielens-100k-dataset/data',
#  '19/04/24, 3:32\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83223361006?pwd=nMcKtUZMKxPJcn2dbwfR4Y4nwFrLUW.1',
#  '19/04/24, 4:13\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/82183401601?pwd=B90w2RLezed2fSwwFytoVvbjDG3R1R.1',
#  '19/04/24, 4:35\u202fpm - NISAMLC: <Media omitted>',
#  '19/04/24, 4:35\u202fpm - NISAMLC: <Media omitted>',
#  '22/04/24, 11:05\u202fam - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87644185104?pwd=UoZyDi9uVqE4COBvWTNKdXH6poOALK.1',
#  '22/04/24, 11:20\u202fam - NISAMLC: <Media omitted>',
#  '22/04/24, 11:47\u202fam - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83719435591?pwd=OAOinOmRv6owb4ur0XT7Xc4ezDCEhj.1',
#  '22/04/24, 12:30\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87168841298?pwd=6pkmUIjKiEwwVYMpLNv844bEVoGyC3.1',
#  '22/04/24, 12:39\u202fpm - NISAMLC: <Media omitted>',
#  '22/04/24, 1:11\u202fpm - NISAMLC: join at 2.30 pm',
#  '22/04/24, 2:30\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/86285461568?pwd=m4IKlxw6ASWObFncC4hONqzuG7JJV9.1',
#  '22/04/24, 3:11\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/82808190042?pwd=0NVFr47d2PDPGOC1ONwDGNvaTiep8q.1',
#  '22/04/24, 3:52\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/85777199753?pwd=lPVl2Yd5x1iJXohgGXhRdE0fbWH4rv.1',
#  '22/04/24, 4:17\u202fpm - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): https://visualstudio.microsoft.com/visual-cpp-build-tools/',
#  '22/04/24, 4:18\u202fpm - NISAMLC: <Media omitted>',
#  '22/04/24, 4:19\u202fpm - NISAMLC: <Media omitted>',
#  '23/04/24, 11:02\u202fam - NISAMLC: JOIN',
#  '23/04/24, 11:03\u202fam - +91 94966 64940: Link?',
#  '23/04/24, 11:04\u202fam - NISAMLC: https://us05web.zoom.us/j/84172735576?pwd=p9JDPvN1splta73xe0e0cJEljAxU14.1',
#  '23/04/24, 11:45\u202fam - Amal (DS-Codeme): https://us05web.zoom.us/j/86837283209?pwd=BiZRMT5mflOnTH7qv9PkvLXpKekvja.1',
#  '23/04/24, 2:29\u202fpm - Amal (DS-Codeme): https://us05web.zoom.us/j/87894573653?pwd=dalYPnEGwRnvhYF9wXb5tXmMWhaZX6.1',
#  '23/04/24, 3:10\u202fpm - NISAMLC: https://us05web.zoom.us/j/89958400034?pwd=pB3kaxEXbSBonzej9ZjYhnOdDycChI.1',
#  '23/04/24, 3:51\u202fpm - Amal (DS-Codeme): https://us05web.zoom.us/j/81104718108?pwd=QZabNNMb5lDbC8ddg3lwXjTrRjb2nG.1',
#  '23/04/24, 4:09\u202fpm - NISAMLC: <Media omitted>',
#  '23/04/24, 4:09\u202fpm - NISAMLC: <Media omitted>',
#  '23/04/24, 4:10\u202fpm - NISAMLC: *market basket analysis*',
#  '23/04/24, 4:10\u202fpm - NISAMLC: <Media omitted>',
#  '23/04/24, 4:11\u202fpm - NISAMLC: <Media omitted>',
#  '24/04/24, 11:05\u202fam - NISAMLC: join',
#  '24/04/24, 11:06\u202fam - NISAMLC: https://us05web.zoom.us/j/88244453101?pwd=FdH0PcnOXMSjsT3A0IoaQShXNKbsa7.1',
#  '24/04/24, 11:10\u202fam - +91 86181 86237: Please add in',
#  '24/04/24, 11:48\u202fam - NISAMLC: https://us04web.zoom.us/j/72173791910?pwd=bADdLHM7aJFqaHJxatinEs1GK6Fm7N.1',
#  '24/04/24, 11:48\u202fam - NISAMLC: join',
#  '24/04/24, 12:22\u202fpm - Amal (DS-Codeme): https://sampleportfolio-a7brzwhi85rmvtef4wngqj.streamlit.app/',
#  '24/04/24, 12:30\u202fpm - NISAMLC: let me know if you have any doubts',
#  '24/04/24, 12:31\u202fpm - NISAMLC: join',
#  '24/04/24, 12:31\u202fpm - NISAMLC: https://meet.google.com/hnf-wehd-ypx',
#  '24/04/24, 12:34\u202fpm - NISAMLC: Those who submitted :',
#  '- Amal Roshan',
#  '24/04/24, 12:56\u202fpm - NISAMLC: *JOIN AT 2.30: Time Series : ACF AND PACF MODELS FOR TIME SERIES FORASTING*',
#  '24/04/24, 2:31\u202fpm - NISAMLC: join',
#  '24/04/24, 2:33\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/88538105805?pwd=ZSYtpaIb5n02IwfADmkStah47tWKqU.1',
#  '24/04/24, 2:33\u202fpm - Asna. (DS-Codeme): https://deploy-asnafidha.streamlit.app',
#  '24/04/24, 2:33\u202fpm - NISAMLC: Those who submitted :',
#  '- Amal Roshan',
#  '- Jishnu',
#  '- Asna',
#  '24/04/24, 2:45\u202fpm - jisshnu.___ (DS-Codeme): Sorry',
#  '24/04/24, 2:46\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/81270550054?pwd=jDnkE79Y8JliuNVoPkuHfKE0oLexcG.1',
#  '24/04/24, 3:27\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/84088354300?pwd=DI2TLClARzPcf4dRnppAt8ajLO0g0v.1',
#  '24/04/24, 4:07\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/85018623759?pwd=viFBEMe7js12WkpzvnsNHG2pawwhjY.1',
#  '25/04/24, 11:07\u202fam - NISAMLC: join',
#  '25/04/24, 11:11\u202fam - NISAMLC: https://us04web.zoom.us/j/79134534643?pwd=n6ka0KpC5XbqUF1YBiVDfGJLBp0gI7.1',
#  '25/04/24, 11:52\u202fam - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87430068127?pwd=bEX00IJNqEAzL9YvMhVEdtahO84GbN.1',
#  '25/04/24, 12:32\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/86927643942?pwd=UNWBUduc0ahzwvaZbweOP4QIBxPtrC.1',
#  '25/04/24, 2:30\u202fpm - NISAMLC: join',
#  '25/04/24, 2:33\u202fpm - NISAMLC: https://us05web.zoom.us/j/86189409946?pwd=jKxbPOLxwZKt3G3FLpoaY1dk3MMp7I.1',
#  '25/04/24, 3:04\u202fpm - NISAMLC: <Media omitted>',
#  '25/04/24, 3:04\u202fpm - NISAMLC: Perform the same > AR model on Female Birth Data',
#  '25/04/24, 3:05\u202fpm - NISAMLC: 3.35 pm',
#  '25/04/24, 3:18\u202fpm - NISAMLC: https://us04web.zoom.us/j/76691224273?pwd=bby3tlcIi3rHzVyg4jYSBjd2cntbtq.1',
#  '25/04/24, 3:19\u202fpm - NISAMLC: join',
#  '25/04/24, 4:00\u202fpm - NISAMLC: Perform the same on the shampoo dataset',
#  '25/04/24, 4:00\u202fpm - jisshnu.___ (DS-Codeme): Ok',
#  '25/04/24, 4:00\u202fpm - +91 94966 64940: Please share the final notebook',
#  '25/04/24, 4:01\u202fpm - NISAMLC: k',
#  '25/04/24, 4:01\u202fpm - NISAMLC: <Media omitted>',
#  '25/04/24, 4:01\u202fpm - NISAMLC: modify the days of prediction',
#  '25/04/24, 4:01\u202fpm - NISAMLC: like if you want to predict for the last 15 days or 30 days and so on',
#  '25/04/24, 4:07\u202fpm - NISAMLC: *Download any Stock Price from yahoofinance and perform AutoRegression on top of it and findout the predicted values: measure the accuracy and evaluate it by creating plots and metrics* submit before monday :This is your first main time series task',
#  '25/04/24, 4:13\u202fpm - NISAMLC: @919946189970',
#  '25/04/24, 4:20\u202fpm - NISAMLC: https://www.kaggle.com/datasets/niketchauhan/covid-19-time-series-data',
#  '25/04/24, 4:20\u202fpm - NISAMLC: Link to Covid 19 dataset',
#  '25/04/24, 4:21\u202fpm - NISAMLC: choose one country from this data',
#  '25/04/24, 4:21\u202fpm - NISAMLC: and perform AutoRegression in order to find the covid cases',
#  '25/04/24, 4:21\u202fpm - NISAMLC: try different countries and compare results',
#  '25/04/24, 4:21\u202fpm - NISAMLC: submit it before monday',
#  "28/04/24, 10:30\u202fpm - Aysha Hamna(CodeMe): Tomorrow's Data Science session is scheduled at 2:30 pm",
#  '28/04/24, 10:35\u202fpm - jisshnu.___ (DS-Codeme): Ok',
#  '29/04/24, 2:22\u202fpm - Aysha Hamna(CodeMe): How many of u are attending online?',
#  '29/04/24, 2:23\u202fpm - jisshnu.___ (DS-Codeme): ✋🏼',
#  '29/04/24, 2:23\u202fpm - Asna. (DS-Codeme): 🤚🏽',
#  '29/04/24, 2:24\u202fpm - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): 🤚🏻',
#  '29/04/24, 2:27\u202fpm - +91 86181 86237: 🤚',
#  '29/04/24, 2:29\u202fpm - Aysha Hamna(CodeMe): For those in attendance offline, the session will take place in the last classroom.',
#  '(The classroom at corner)',
#  '29/04/24, 2:35\u202fpm - Aysha Hamna(CodeMe): https://us05web.zoom.us/j/87110841572?pwd=OWJbPWbvehs3oWoB949WmyAFXXQwMB.1',
#  '29/04/24, 2:35\u202fpm - Aysha Hamna(CodeMe): please join',
#  '29/04/24, 3:11\u202fpm - jisshnu.___ (DS-Codeme): Invalid meeting id',
#  '29/04/24, 3:11\u202fpm - Amal (DS-Codeme): https://us05web.zoom.us/j/84426665904?pwd=eW10ScuhCCcu6diyauNYhTVsWoM9LB.1',
#  '29/04/24, 3:47\u202fpm - Aysha Hamna(CodeMe): https://atlas.mitre.org/matrices/ATLAS',
#  '29/04/24, 3:48\u202fpm - Aysha Hamna(CodeMe): https://incidentdatabase.ai/',
#  '29/04/24, 3:53\u202fpm - Aysha Hamna(CodeMe): https://us05web.zoom.us/j/86732036320?pwd=yaIPNxa9hp9B6H5j9Ai3ptzuqqSWmu.1',
#  '30/04/24, 9:53\u202fam - Asif (CodeMe): https://meet.google.com/vrs-wvoh-zng',
#  '30/04/24, 9:53\u202fam - Asif (CodeMe): join',
#  '30/04/24, 9:53\u202fam - Asif (CodeMe): <Media omitted>',
#  '01/05/24, 10:57\u202fam - NISAMLC: join',
#  '01/05/24, 11:02\u202fam - +91 94966 64940: Link?',
#  '01/05/24, 11:04\u202fam - NISAMLC: https://us05web.zoom.us/j/84146894791?pwd=0FGmCXYSFl4GRMAUUQxPIJnr0y189w.1',
#  '01/05/24, 11:47\u202fam - Amal (DS-Codeme): https://us05web.zoom.us/j/85738513589?pwd=PzjFyd46iBkdv6jWYqDb4hKhaLaBWb.1',
#  '01/05/24, 12:28\u202fpm - NISAMLC: https://us05web.zoom.us/j/86258974313?pwd=ZO778uGGRCZaZ1rXJjEE9zDaMxvhCK.1',
#  '01/05/24, 1:02\u202fpm - NISAMLC: <Media omitted>',
#  '01/05/24, 2:34\u202fpm - Aysha Hamna(CodeMe): https://us05web.zoom.us/j/81324776140?pwd=NqfRe3VCI7kv6hNjXNG26xsxSFBLUh.1',
#  '01/05/24, 3:18\u202fpm - +91 94966 64940: Link?',
#  '01/05/24, 3:19\u202fpm - Amal (DS-Codeme): https://us05web.zoom.us/j/85302314572?pwd=LQlX8uiB8lxqGwzHLCuDih5lmgj0XW.1',
#  '01/05/24, 3:20\u202fpm - Aysha Hamna(CodeMe): https://www.youtube.com/watch?v=aircAruvnKk&t=784s',
#  '02/05/24, 11:03\u202fam - NISAMLC: join',
#  '02/05/24, 11:06\u202fam - NISAMLC: https://us05web.zoom.us/j/81956643317?pwd=a2Dnir1U7fq4Y1fPoLoKt4KysYsVlm.1',
#  '02/05/24, 11:47\u202fam - Amal (DS-Codeme): https://us05web.zoom.us/j/83794961231?pwd=LSLhV9pdiXCEiEHkkFmNNoW09m7PCJ.1',
#  '02/05/24, 12:08\u202fpm - NISAMLC: <Media omitted>',
#  '02/05/24, 12:29\u202fpm - NISAMLC: https://us05web.zoom.us/j/83432770790?pwd=15aIavmf3exCGAUn0MLQRw3ZW2B8VY.1',
#  "02/05/24, 8:23\u202fpm - Aysha Hamna(CodeMe): Tomorrow's schedule",
#  '11:00 am to 1:00  pm - Deep learning',
#  'Afternoon session - ',
#  'Time series',
#  '03/05/24, 11:04\u202fam - Aysha Hamna(CodeMe): anyone offline?',
#  '03/05/24, 11:05\u202fam - Amal (DS-Codeme): online 🙌🏻',
#  '03/05/24, 11:06\u202fam - Aysha Hamna(CodeMe): https://us05web.zoom.us/j/89768721231?pwd=RUHgbb3leOUDroj4M26QHtIdPloj3g.1',
#  '03/05/24, 11:47\u202fam - Rashid (DS-Codeme): link',
#  '03/05/24, 11:48\u202fam - Amal (DS-Codeme): https://us05web.zoom.us/j/81690932462?pwd=BG1xPitPTZx0ZMQ1jATFbswR3XqJuG.1',
#  '03/05/24, 2:33\u202fpm - NISAMLC: join',
#  '03/05/24, 2:37\u202fpm - NISAMLC: https://us05web.zoom.us/j/86546468416?pwd=vgLrHWK0l0WMw6nfgT0Mb2qzUdcyOG.1',
#  '03/05/24, 3:20\u202fpm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/82347408592?pwd=bap6BJ5lpH0Q6qOw9rofMePqx75Ovm.1',
#  '03/05/24, 3:42\u202fpm - NISAMLC: https://www.youtube.com/playlist?list=PLvcbYUQ5t0UHOLnBzl46_Q6QKtFgfMGc3',
#  '03/05/24, 3:58\u202fpm - +91 94966 64940: @918593099647 innalathem innathem notebooks share ako',
#  '03/05/24, 3:58\u202fpm - NISAMLC: okay',
#  '03/05/24, 3:58\u202fpm - NISAMLC: <Media omitted>',
#  '03/05/24, 3:58\u202fpm - NISAMLC: <Media omitted>',
#  '03/05/24, 3:59\u202fpm - NISAMLC: <Media omitted>',
#  '03/05/24, 3:59\u202fpm - NISAMLC: <Media omitted>',
#  '06/05/24, 10:55\u202fam - Aysha Hamna(CodeMe): Anyone offline',
#  '06/05/24, 11:02\u202fam - jisshnu.___ (DS-Codeme): ✋🏼',
#  '06/05/24, 11:03\u202fam - Aysha Hamna(CodeMe): ok',
#  '06/05/24, 11:06\u202fam - Aysha Hamna(CodeMe): https://meet.google.com/ihx-eeyg-mwi',
#  "06/05/24, 8:46\u202fpm - Aysha Hamna(CodeMe): Tomorrow's schedule",
#  'Online session at 10:00 am ',
#  'Topic : Neural Network <This message was edited>',
#  '06/05/24, 10:35\u202fpm - Aysha Hamna(CodeMe): 🔴 session rescheduled to 3 pm tomorrow',
#  '08/05/24, 11:21\u202fam - Aysha Hamna(CodeMe): same link',
#  '08/05/24, 1:04\u202fpm - Aysha Hamna(CodeMe): https://colab.research.google.com/drive/1klJqPJr4dvIQsX6fWjT6I4CRU4iqUEqH?usp=sharing',
#  '08/05/24, 8:46\u202fpm - Aysha Hamna(CodeMe): Go through the gradient descent topics that we learned for linear models.',
#  "08/05/24, 8:46\u202fpm - Aysha Hamna(CodeMe): Its necessary for tomorrow's session",
#  '08/05/24, 8:52\u202fpm - Aysha Hamna(CodeMe): We have offline session tomorrow at 11 am',
#  '09/05/24, 11:03\u202fam - NISAMLC: ANYONE OFFLINE?',
#  '09/05/24, 11:05\u202fam - NISAMLC: JOIN',
#  '09/05/24, 11:12\u202fam - NISAMLC: https://us05web.zoom.us/j/87386242572?pwd=ELelyhYQxEmPNwtWba2ZLmEDF23Et9.1',
#  '09/05/24, 11:54\u202fam - Amal (DS-Codeme): https://us05web.zoom.us/j/88583487724?pwd=gey9tmKciyfuaRjqapQa9bMCPkMy3t.1',
#  '09/05/24, 12:34\u202fpm - Amal (DS-Codeme): https://us05web.zoom.us/j/81380987479?pwd=G50yjRywUHypiqguW4p02RW9wqCqzN.1',
#  '09/05/24, 1:16\u202fpm - NISAMLC: reamining will discuss in the next class, take a look at Logistic regression',
#  '10/05/24, 11:11\u202fam - NISAMLC: class will start soon',
#  '10/05/24, 11:17\u202fam - NISAMLC: https://us05web.zoom.us/j/84975007689?pwd=h6wFrvavIAMux0cnHnaZyPadbGeFvN.1',
#  '10/05/24, 11:31\u202fam - jisshnu.___ (DS-Codeme): Let me in',
#  '10/05/24, 11:58\u202fam - NISAMLC: @919778218181 meet',
#  '10/05/24, 11:59\u202fam - Amal (DS-Codeme): https://us05web.zoom.us/j/81890576665?pwd=c1QHxvO4aEIEXCNernGf85Yy6VVQJ1.1',
#  '10/05/24, 12:34\u202fpm - NISAMLC: we can stop for todat at : Basic gradient descent , Try to unnderstand it more by incorporating the discussed concept ,and explore batch gradient descend and how it works , And *create a linear regression model by taking a real world data without using Linear Regression class from sklearn in the next class*',
#  '14/05/24, 11:01\u202fam - NISAMLC: https://us06web.zoom.us/j/82998391278?pwd=UKupeIbzYEOwemN7P4Uw5ArRaANN7k.1',
#  '14/05/24, 11:01\u202fam - NISAMLC: join',
#  '14/05/24, 11:09\u202fam - NISAMLC: ini aarenkilum join cheyyunnundo?',
#  '14/05/24, 11:09\u202fam - +91 94966 64940: Yes',
#  '14/05/24, 11:10\u202fam - NISAMLC: @917736866448 ???',
#  '14/05/24, 11:25\u202fam - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): Yes',
#  '14/05/24, 12:40\u202fpm - +91 94966 64940: Sir please let me in',
#  '14/05/24, 12:40\u202fpm - +91 94966 64940: @918593099647',
#  '14/05/24, 2:30\u202fpm - NISAMLC: https://us06web.zoom.us/j/85864309016?pwd=Yw5Zb7Ha739FPtz6n1rm74TCVSBpiU.1',
#  '14/05/24, 2:30\u202fpm - NISAMLC: join',
#  '14/05/24, 4:46\u202fpm - Rashid (DS-Codeme): Notebook',
#  '14/05/24, 4:47\u202fpm - +91 94966 64940: Recording also',
#  '14/05/24, 4:50\u202fpm - NISAMLC: <Media omitted>',
#  '14/05/24, 4:51\u202fpm - NISAMLC: check out this tutorials from tensorflow itself, https://www.tensorflow.org/tutorials',
#  "15/05/24, 10:00\u202fam - NISAMLC: Today's class starts @2.30 PM everyone be on time :",
#  'Topic: Implementation of Multi Hidden Layer Perceptron(Multi Hidden Layer Neural Network)',
#  '15/05/24, 2:34\u202fpm - NISAMLC: https://us06web.zoom.us/j/81668957371?pwd=YwBWdXxDTkypIwrWcfIutDfBzzWbw8.1',
#  '15/05/24, 7:27\u202fpm - +91 94966 64940: B- blood kittaan indo arelm',
#  '15/05/24, 7:28\u202fpm - jisshnu.___ (DS-Codeme): Positive nd',
#  '16/05/24, 10:02\u202fam - NISAMLC: join @11.00pm on : implementing a regression problem',
#  '16/05/24, 11:02\u202fam - NISAMLC: https://us06web.zoom.us/j/85790204001?pwd=aUmiRhNSlP3WI2WkMRzmzb5lfHaJAv.1',
#  '16/05/24, 11:48\u202fam - NISAMLC: <Media omitted>',
#  '17/05/24, 11:02\u202fam - NISAMLC: https://us06web.zoom.us/j/82211794464?pwd=9jODZBXpZGvJziz15TInGkFKfqh6Db.1',
#  '17/05/24, 11:07\u202fam - +91 86181 86237: Please let me in',
#  '17/05/24, 5:44\u202fpm - Aysha Hamna(CodeMe): Check out this job at Sony Research India: https://www.linkedin.com/jobs/view/3917526117',
#  '20/05/24, 12:49\u202fpm - NISAMLC: class starts @2.30pm',
#  '20/05/24, 2:31\u202fpm - NISAMLC: https://us06web.zoom.us/j/89079927141?pwd=uAuUKsCJ3HYLV9XSdtrIfFhAM4Zlua.1',
#  '20/05/24, 2:31\u202fpm - NISAMLC: join',
#  '21/05/24, 2:13\u202fpm - NISAMLC: class starts @2.30pm',
#  '21/05/24, 2:19\u202fpm - NISAMLC: on : End to End Deep Learning Project',
#  '21/05/24, 2:22\u202fpm - NISAMLC: https://us06web.zoom.us/j/84819824369?pwd=W91jLH9SSz2dwjsfUqaJnCezd6OIxy.1',
#  '21/05/24, 2:22\u202fpm - NISAMLC: join',
#  '21/05/24, 4:21\u202fpm - NISAMLC: https://www.kaggle.com/datasets/gauravtopre/bank-customer-churn-dataset',
#  '22/05/24, 1:58\u202fpm - NISAMLC: class starts @2.30 on CNN',
#  '22/05/24, 2:34\u202fpm - NISAMLC: https://us06web.zoom.us/j/84150849582?pwd=E5eNW8ZSXcnQe7krTJ3ynobU9l8qxR.1',
#  '22/05/24, 2:34\u202fpm - NISAMLC: join',
#  '22/05/24, 2:38\u202fpm - Rashid (DS-Codeme): Let me in',
#  '23/05/24, 2:07\u202fpm - NISAMLC: CLASS WILL START @2.30 ON TFL AND PADDING ANS STRIPE',
#  '23/05/24, 2:31\u202fpm - NISAMLC: https://us06web.zoom.us/j/88676945662?pwd=qtkCSpiakGI73ENb4BuLxM3JmhIMKM.1',
#  '23/05/24, 2:31\u202fpm - NISAMLC: join',
#  '23/05/24, 2:36\u202fpm - +91 94966 64940: Unable to join',
#  '23/05/24, 2:36\u202fpm - +91 94966 64940: Facing network issues',
#  '23/05/24, 3:12\u202fpm - NISAMLC: https://us06web.zoom.us/j/84774931149?pwd=IZhaEyGogISiuWUJwcbaZWxaFs5WK8.1',
#  '23/05/24, 3:12\u202fpm - NISAMLC: join',
#  '23/05/24, 3:12\u202fpm - NISAMLC: asap',
#  '24/05/24, 2:27\u202fpm - NISAMLC: https://us06web.zoom.us/j/89735874355?pwd=KtdBvYzjffeLwYbyA3HUzt7VwpuKw1.1',
#  '24/05/24, 2:28\u202fpm - NISAMLC: join',
#  '24/05/24, 3:31\u202fpm - NISAMLC: <Media omitted>',
#  '24/05/24, 4:02\u202fpm - NISAMLC: complete this task and  implement CNN on top of any image dataset',
#  '24/05/24, 4:02\u202fpm - NISAMLC: imlement CNN on flowers dataset as well',
#  '24/05/24, 4:02\u202fpm - NISAMLC: and submit those notes before monday afternoon',
#  '26/05/24, 11:12\u202fpm - NISAMLC: Tomorrow you will not have regular session instead you will be assigned a task and it will be consider as your Deep Learning *Mini Project* <This message was edited>',
#  '27/05/24, 10:20\u202fam - NISAMLC: Mini Project On Deep Learning : *Create A Multi Layer Convolutional Neural Network in order to classify Flowers using googleapi flowers dataset and classify it into 5 different categories namely Rose,Tulip, Sunflower,Daisy and Dandelion* save Your Model into h5 file and send to me via my email with notebook  : nisamlckkn@gmail.com on or before 29th of May',
#  '27/05/24, 10:21\u202fam - Rashid (DS-Codeme): Ok sir',
#  '28/05/24, 10:10\u202fam - NISAMLC: class starts @2.30 on Introduction to Computer Vision and Image manipulation',
#  '28/05/24, 2:27\u202fpm - NISAMLC: https://us06web.zoom.us/j/89163859148?pwd=lyAoMKZRNWAgriZ9pai2IszdGQ293o.1',
#  '28/05/24, 2:27\u202fpm - NISAMLC: join',
#  '29/05/24, 2:19\u202fpm - NISAMLC: class starts @2.30pm',
#  '29/05/24, 2:29\u202fpm - NISAMLC: https://us06web.zoom.us/j/85373550975?pwd=yo9UTFvYwPycn4CedQmbipCrb3kFVi.1',
#  '29/05/24, 2:29\u202fpm - NISAMLC: join',
#  '29/05/24, 2:34\u202fpm - NISAMLC: @919037649226 ????',
#  '29/05/24, 2:34\u202fpm - NISAMLC: @917907733950 ??//',
#  '29/05/24, 2:34\u202fpm - Rashid (DS-Codeme): On the way',
#  '29/05/24, 2:35\u202fpm - NISAMLC: offline aano?',
#  '29/05/24, 2:35\u202fpm - Rashid (DS-Codeme): Alla',
#  '29/05/24, 2:35\u202fpm - Rashid (DS-Codeme): Connection issue',
#  '29/05/24, 2:35\u202fpm - Rashid (DS-Codeme): Athaan',
#  '29/05/24, 2:35\u202fpm - NISAMLC: k',
#  '29/05/24, 3:41\u202fpm - +91 94966 64940: please let me in',
#  '29/05/24, 4:50\u202fpm - NISAMLC: video codec: https://docs.opencv.org/4.x/d0/d61/group__cudacodec.html',
#  '29/05/24, 4:51\u202fpm - NISAMLC: amal look at this :https://www.tutorialspoint.com/opencv/index.htm',
#  '30/05/24, 12:38\u202fpm - NISAMLC: class starts @2.30: We will discuss all image processing related topics in a brief today, make sure to attend all (we will discuss all topics we went through till regarding CV )@919778218181 , @919946189970 make sure to attend',
#  '30/05/24, 2:27\u202fpm - NISAMLC: https://us06web.zoom.us/j/83628900360?pwd=4dpav7Gb3MahIZyHBeeHSY3ktU1pu6.1',
#  '30/05/24, 5:55\u202fpm - NISAMLC: You deleted this message',
#  '30/05/24, 5:55\u202fpm - NISAMLC: <Media omitted>',
#  '30/05/24, 5:55\u202fpm - NISAMLC: <Media omitted>',
#  '30/05/24, 5:55\u202fpm - NISAMLC: <Media omitted>',
#  '31/05/24, 2:31\u202fpm - NISAMLC: https://us06web.zoom.us/j/88443754683?pwd=TSaHXIo2KIsgMhkPeVZkEuaDFd8l2W.1',
#  '31/05/24, 2:31\u202fpm - NISAMLC: JOIN',
#  '02/06/24, 10:03\u202fpm - Aysha Hamna(CodeMe): Dear Students,',
#  '',
#  '10:00 am - Karthika',
#  '10:30 am - Jishnu',
#  '11:00 am - Rashid',
#  '11:30 am - Amal Roshan',
#  '02:30 pm - Binjus',
#  '03:00 pm - Aysha',
#  '03:30 pm - Asna',
#  '',
#  'Please check your time slots for the interview tomorrow.',
#  'Hope everyone are ready for your first review plan interview.',
#  'Everyone should be there on time.',
#  'There will be theoretical and practical questions, so be prepared.',
#  '',
#  '*All the best*',
#  '',
#  'Attendance for the review plan is mandatory.',
#  '03/06/24, 11:23\u202fam - Aysha Hamna(CodeMe): Reminder:',
#  '',
#  'Interview session started.',
#  'Expecting everyone to be on time',
#  "04/06/24, 11:36\u202fam - Aysha Hamna(CodeMe): Since the review plan interviews are going on , you won't have data science session today",
#  '04/06/24, 11:36\u202fam - Rashid (DS-Codeme): Ok',
#  '04/06/24, 9:44\u202fpm - Aysha Hamna(CodeMe): Reminder:',
#  '',
#  "You will have same time schedule for tomorrow's interview.",
#  '',
#  'Be prepared and practice well.',
#  '',
#  'Bring your CV.',
#  '',
#  'Topics are listed in the review plan document.',
#  '06/06/24, 9:30\u202fam - NISAMLC: Since I do have a meeting scheduled today CV classes are postponed to Saturday (from morning to evening)',
#  "06/06/24, 9:31\u202fam - NISAMLC: And those who are attending today's Aptitude test , this is a rare chance any interview will not complete without aptitude and mental ability so make sure to attend",
#  '07/06/24, 10:18\u202fam - NISAMLC: class starts @2.30 on : CV:Drawing shapes on images: Basic to Advanced',
#  '07/06/24, 2:26\u202fpm - NISAMLC: https://us06web.zoom.us/j/82621147975?pwd=Wcj697cm8G6LqtjDXzNr6PDpsaY7KI.1',
#  '07/06/24, 2:26\u202fpm - NISAMLC: join',
#  '07/06/24, 4:50\u202fpm - NISAMLC: CV class : tomorrow(Saturday) morning 10.00 AM TO 1.00 PM class',
#  '08/06/24, 9:56\u202fam - NISAMLC: https://us06web.zoom.us/j/84505621870?pwd=s8h800UVxjg6EybmgL8AyplvEm4Qst.1',
#  '08/06/24, 9:56\u202fam - NISAMLC: join',
#  '08/06/24, 11:03\u202fam - NISAMLC: https://us04web.zoom.us/j/5019495850?pwd=dENBUnN6a043bzlHcGpJY3Ara2lWZz09',
#  '08/06/24, 11:03\u202fam - NISAMLC: rejoin',
#  '08/06/24, 11:45\u202fam - +91 79077 33950: https://us04web.zoom.us/j/74450854485?pwd=E1z5A4tcHiQkI3Tui6iNrKrMl0LxqE.1',
#  '08/06/24, 12:50\u202fpm - NISAMLC: <Media omitted>',
#  '08/06/24, 12:50\u202fpm - NISAMLC: <Media omitted>',
#  '08/06/24, 12:50\u202fpm - NISAMLC: <Media omitted>',
#  '09/06/24, 6:49\u202fpm - Aysha Hamna(CodeMe): Reminder:',
#  '',
#  'Review plan third section interview is scheduled tomorrow.',
#  '',
#  'Topic : Machine Learning.',
#  '',
#  'Bring your CV',
#  '',
#  'All the best',
#  '09/06/24, 6:50\u202fpm - Aysha Hamna(CodeMe): Dear Students,',
#  '',
#  'There is a small change in time slots.',
#  '',
#  '10:00 am - Jishnu',
#  '10:30 am - Karthika',
#  '11:00 am - Rashid',
#  '11:30 am - Amal Roshan',
#  '02:30 pm - Binjus',
#  '03:00 pm - Aysha',
#  '03:30 pm - Asna',
#  '10/06/24, 12:16\u202fpm - NISAMLC: everyone must attend github class @2.30 everyone can attend those can attend offline be offline and others can join through online *Dont Miss It*',
#  '10/06/24, 2:46\u202fpm - +91 94966 64940: Link?',
#  '10/06/24, 2:52\u202fpm - NISAMLC: https://meet.google.com/wfx-cszi-iyb',
#  "11/06/24, 10:35\u202fam - NISAMLC: How many of you are attending today's GIT class?",
#  '11/06/24, 10:35\u202fam - NISAMLC: and how many attended yesterday?',
#  "11/06/24, 10:36\u202fam - Rashid (DS-Codeme): I have attended yesterday's class",
#  '11/06/24, 10:40\u202fam - NISAMLC: what about today?',
#  '11/06/24, 10:40\u202fam - +91 94966 64940: Me',
#  '11/06/24, 10:40\u202fam - Rashid (DS-Codeme): Will attend through online',
#  '11/06/24, 10:41\u202fam - NISAMLC: okay',
#  '11/06/24, 10:41\u202fam - NISAMLC: dont miss it guys',
#  '11/06/24, 10:41\u202fam - NISAMLC: you will not get its recordings',
#  '11/06/24, 10:41\u202fam - NISAMLC: very much crucial for  team work <This message was edited>',
#  '11/06/24, 10:46\u202fam - Amal (DS-Codeme): Yesterday attended.... Today through online',
#  '11/06/24, 10:50\u202fam - NISAMLC: Okay',
#  '11/06/24, 11:09\u202fam - jisshnu.___ (DS-Codeme): Me',
#  '11/06/24, 2:41\u202fpm - NISAMLC: https://meet.google.com/wfx-cszi-iyb',
#  '12/06/24, 11:53\u202fam - NISAMLC: class starts @2.30 pm',
#  '12/06/24, 11:55\u202fam - Rashid (DS-Codeme): git or cv',
#  '12/06/24, 11:55\u202fam - NISAMLC: cv',
#  '12/06/24, 11:55\u202fam - Rashid (DS-Codeme): ok',
#  '12/06/24, 2:38\u202fpm - NISAMLC: https://meet.google.com/tfq-dyhi-aoa',
#  '12/06/24, 3:39\u202fpm - Asif (CodeMe): This message was deleted',
#  '12/06/24, 4:55\u202fpm - Asif (CodeMe): This message was deleted',
#  '12/06/24, 4:58\u202fpm - Asif (CodeMe): Dear Students,',
#  '',
#  'We have scheduled a mandatory three-day Git class on the ,19th,  20th  and 21st of this month. Attendance for all three days is compulsory. There will not be an opportunity to repeat these sessions.',
#  '',
#  'Class Details:Dates:  19th, 20th,21st',
#  '',
#  'Time: 2:30 PM - 4:30 PM',
#  '',
#  'Your presence is required. No exceptions will be made.',
#  '13/06/24, 9:41\u202fam - Aysha Hamna(CodeMe): Anyone attending interview today?',
#  '13/06/24, 2:08\u202fpm - NISAMLC: class @2.30',
#  '13/06/24, 2:26\u202fpm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '13/06/24, 2:26\u202fpm - NISAMLC: join',
#  '14/06/24, 1:30\u202fpm - Aysha Hamna(CodeMe): <Media omitted>',
#  '14/06/24, 3:05\u202fpm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '14/06/24, 3:05\u202fpm - NISAMLC: join',
#  '14/06/24, 5:39\u202fpm - NISAMLC: <Media omitted>',
#  '15/06/24, 2:29\u202fpm - NISAMLC: You deleted this message',
#  '15/06/24, 2:30\u202fpm - NISAMLC: Practice Computer Vision Tasks Which we are discussed by taking different images and push it inside Git',
#  '19/06/24, 10:30\u202fam - NISAMLC: Today we do have git classes @2.30 from Dilshad sir *from scratch* how many of are going to attend?? let me know if you are not attending i will go with CV class (There are many things which we are not disccused in our classroom in git so it will be really helpfull) , i want to know before 1.00PM',
#  '19/06/24, 10:47\u202fam - Rashid (DS-Codeme): I will attend',
#  '19/06/24, 10:52\u202fam - NISAMLC: okay',
#  '19/06/24, 10:52\u202fam - NISAMLC: anyone else?',
#  '19/06/24, 10:52\u202fam - NISAMLC: he will explain from scratch',
#  '19/06/24, 10:53\u202fam - +91 94966 64940: ✋🏻',
#  '19/06/24, 11:29\u202fam - NISAMLC: okay',
#  '19/06/24, 11:29\u202fam - NISAMLC: try to do practicals',
#  '19/06/24, 11:29\u202fam - NISAMLC: then only you will get know the mistakes and ask doubts he will rectify it',
#  '19/06/24, 1:25\u202fpm - +91 79077 33950: will attend',
#  '19/06/24, 2:29\u202fpm - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): ✋🏻',
#  '19/06/24, 2:32\u202fpm - jisshnu.___ (DS-Codeme): ✋🏼',
#  '19/06/24, 2:55\u202fpm - +91 94966 64940: Sir link?',
#  '19/06/24, 3:24\u202fpm - NISAMLC: To join the meeting on Google Meet, click this link: ',
#  'https://meet.google.com/wfx-cszi-iyb ',
#  ' ',
#  'Or open Meet and enter this code: wfx-cszi-iyb',
#  '19/06/24, 3:24\u202fpm - NISAMLC: become late',
#  '19/06/24, 3:24\u202fpm - NISAMLC: just started',
#  '19/06/24, 3:24\u202fpm - NISAMLC: join now',
#  '19/06/24, 3:25\u202fpm - NISAMLC: join immediately',
#  '19/06/24, 3:25\u202fpm - NISAMLC: otherwise you cant follow',
#  '19/06/24, 10:09\u202fpm - Aysha Hamna(CodeMe): 🔴Review plan update :',
#  'Since DL portions are not completed yet, review plan is paused.',
#  '',
#  'Will update about review plan in coming week',
#  '20/06/24, 2:42\u202fpm - NISAMLC: join in the same link',
#  '21/06/24, 2:41\u202fpm - Aysha Hamna(CodeMe): To join the meeting on Google Meet, click this link: ',
#  'https://meet.google.com/wfx-cszi-iyb ',
#  ' ',
#  'Or open Meet and enter this code: wfx-cszi-iyb',
#  '21/06/24, 2:41\u202fpm - Aysha Hamna(CodeMe): Join in this link for git session',
#  '24/06/24, 2:36\u202fpm - NISAMLC: You guys can now access the entire course recordings go through it accordingly (you will be notified in your mail)',
#  '24/06/24, 2:36\u202fpm - NISAMLC: let me know if you dont',
#  '24/06/24, 2:37\u202fpm - +91 94966 64940: Notification already sent?',
#  '24/06/24, 2:38\u202fpm - NISAMLC: ya',
#  '24/06/24, 2:39\u202fpm - NISAMLC: @919946189970  your mail id?',
#  '24/06/24, 2:39\u202fpm - jisshnu.___ (DS-Codeme): jishnumss7@gmail.com',
#  '24/06/24, 2:39\u202fpm - NISAMLC: k',
#  '24/06/24, 2:39\u202fpm - +91 94966 64940: Received . Thanks',
#  '24/06/24, 2:41\u202fpm - jisshnu.___ (DS-Codeme): Recieved',
#  '24/06/24, 2:42\u202fpm - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): Received',
#  '24/06/24, 2:54\u202fpm - +91 86181 86237: Received',
#  '24/06/24, 3:44\u202fpm - Amal (DS-Codeme): Received',
#  '24/06/24, 6:35\u202fpm - Asna. (DS-Codeme): Not received',
#  '25/06/24, 9:33\u202fam - NISAMLC: Go through the CNN section and we will continue our discussion from tomorrow onwards',
#  '26/06/24, 11:03\u202fam - NISAMLC: Class @2.30 PM',
#  '26/06/24, 2:25\u202fpm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '26/06/24, 2:25\u202fpm - NISAMLC: join <This message was edited>',
#  '26/06/24, 4:07\u202fpm - NISAMLC: <Media omitted>',
#  '26/06/24, 4:07\u202fpm - NISAMLC: <Media omitted>',
#  '26/06/24, 4:07\u202fpm - NISAMLC: <Media omitted>',
#  '26/06/24, 4:07\u202fpm - NISAMLC: <Media omitted>',
#  '26/06/24, 4:07\u202fpm - NISAMLC: <Media omitted>',
#  '26/06/24, 4:07\u202fpm - NISAMLC: Workout try it on different images',
#  '27/06/24, 2:19\u202fpm - NISAMLC: class @2.30',
#  '27/06/24, 2:32\u202fpm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '27/06/24, 2:34\u202fpm - NISAMLC: join',
#  '27/06/24, 5:21\u202fpm - NISAMLC: <Media omitted>',
#  '27/06/24, 5:21\u202fpm - NISAMLC: Object Detection',
#  '27/06/24, 5:21\u202fpm - NISAMLC: Resources',
#  '27/06/24, 5:21\u202fpm - NISAMLC: try out',
#  '27/06/24, 5:22\u202fpm - NISAMLC: and implement other image processing techniques',
#  '30/06/24, 9:05\u202fpm - NISAMLC: We will start our NLP (Natural Language Processing) session from tomorrow (6/1/2024) 2.30PM onwards',
#  'New Session  dont miss any, definitely be an addition to your profile',
#  '* NLP Fundamentals',
#  '30/06/24, 9:20\u202fpm - Rashid (DS-Codeme): Okay',
#  '01/07/24, 2:31\u202fpm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '01/07/24, 2:31\u202fpm - NISAMLC: join',
#  '01/07/24, 2:36\u202fpm - +91 94966 64940: Please admit',
#  '01/07/24, 2:41\u202fpm - +91 94966 64940: @918593099647',
#  '01/07/24, 4:17\u202fpm - NISAMLC: <Media omitted>',
#  "02/07/24, 11:15\u202fam - Asif (CodeMe): There won't be any session this afternoon",
#  '02/07/24, 11:15\u202fam - Rashid (DS-Codeme): Ok',
#  "03/07/24, 8:02\u202fam - Asif (CodeMe): There won't be any session today",
#  '03/07/24, 8:03\u202fam - Asif (CodeMe): Complete your regex assignment and share the GitHub link',
#  "10/07/24, 1:19\u202fpm - Aysha Hamna(CodeMe): We'll resume your NLP sessions from tomorrow ",
#  'Time: 2:30 pm',
#  '11/07/24, 2:56\u202fpm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '11/07/24, 2:56\u202fpm - NISAMLC: joinn',
#  '12/07/24, 2:25\u202fpm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '12/07/24, 2:25\u202fpm - NISAMLC: join',
#  '12/07/24, 2:35\u202fpm - NISAMLC: anyone joining?',
#  '12/07/24, 2:36\u202fpm - Rashid (DS-Codeme): Yes, sir oru 5 mins',
#  '12/07/24, 2:37\u202fpm - NISAMLC: k',
#  '15/07/24, 2:24\u202fpm - NISAMLC: class starts @2.30pm',
#  '15/07/24, 2:33\u202fpm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '15/07/24, 2:35\u202fpm - NISAMLC: @919037649226 are you join??',
#  '15/07/24, 2:35\u202fpm - Rashid (DS-Codeme): yes',
#  '15/07/24, 5:26\u202fpm - Rashid (DS-Codeme): sir notebook share cheyuo',
#  '15/07/24, 5:53\u202fpm - NISAMLC: <Media omitted>',
#  '16/07/24, 2:21\u202fpm - NISAMLC: class starts @2.30pm',
#  '16/07/24, 2:33\u202fpm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '16/07/24, 2:33\u202fpm - NISAMLC: join',
#  '16/07/24, 2:39\u202fpm - NISAMLC: any more people joining? <This message was edited>',
#  '16/07/24, 2:42\u202fpm - NISAMLC: will wait until 2.45',
#  '16/07/24, 2:45\u202fpm - Rashid (DS-Codeme): Sir',
#  '16/07/24, 2:45\u202fpm - Rashid (DS-Codeme): Njn ind',
#  '16/07/24, 2:48\u202fpm - Rashid (DS-Codeme): let me in',
#  '16/07/24, 2:50\u202fpm - Rashid (DS-Codeme): hi',
#  '18/07/24, 2:12\u202fpm - NISAMLC: class starts at 2.30pm',
#  '18/07/24, 2:33\u202fpm - Rashid (DS-Codeme): Link',
#  '18/07/24, 2:34\u202fpm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '18/07/24, 4:02\u202fpm - NISAMLC: <Media omitted>',
#  '18/07/24, 4:05\u202fpm - NISAMLC: Monday onwards you will get Class on Django for MLOPS your last session',
#  '19/07/24, 2:13\u202fpm - NISAMLC: class starts @2.30',
#  '19/07/24, 2:32\u202fpm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '19/07/24, 2:32\u202fpm - NISAMLC: join',
#  '19/07/24, 3:43\u202fpm - NISAMLC: <Media omitted>',
#  '19/07/24, 3:54\u202fpm - NISAMLC: <Media omitted>',
#  '22/07/24, 9:53\u202fam - NISAMLC: we are planning to give a 30 days Project Bootcamp for this batch *30 days 30 Projects*, where we will build 30 end to end projects from various domains which we are discussed in our entire curriculum. how many of you are interested ?? i need everyone to attend the session otherwise we will drop the plan every day 2 hrs , if you are interested let me know.',
#  'we will start this session once you Django session completed <This message was edited>',
#  '22/07/24, 9:55\u202fam - Rashid (DS-Codeme): Iam interested',
#  '22/07/24, 9:55\u202fam - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): ✋🏻',
#  '22/07/24, 10:03\u202fam - Amal (DS-Codeme): ✋🏻',
#  '22/07/24, 10:05\u202fam - jisshnu.___ (DS-Codeme): 👍🏼',
#  '22/07/24, 10:10\u202fam - jisshnu.___ (DS-Codeme) added Nayana(OldBatch) J Nair',
#  '22/07/24, 10:14\u202fam - Asna. (DS-Codeme): ✋🏼',
#  '22/07/24, 10:18\u202fam - +91 86181 86237: ✋🏻',
#  '22/07/24, 11:04\u202fam - +91 94966 64940: ✋🏻',
#  "22/07/24, 2:40\u202fpm - Nayana(OldBatch) J Nair: Today's session postponed to 3.pm",
#  '22/07/24, 3:06\u202fpm - Nayana(OldBatch) J Nair: https://meet.google.com/exf-ftsp-xpg',
#  '24/07/24, 12:47\u202fpm - Asif (CodeMe): https://blogs.oracle.com/oracleuniversity/post/announcing-oci-2024-generative-ai-professional-certification-and-course',
#  '24/07/24, 1:01\u202fpm - jisshnu.___ (DS-Codeme): <Media omitted>',
#  '24/07/24, 2:28\u202fpm - Nayana(OldBatch) J Nair: join all',
#  '25/07/24, 2:30\u202fpm - Nayana(OldBatch) J Nair: https://meet.google.com/exf-ftsp-xpg',
#  '26/07/24, 2:31\u202fpm - Nayana(OldBatch) J Nair: join all',
#  '29/07/24, 3:03\u202fpm - Nayana(OldBatch) J Nair: please join',
#  '29/07/24, 5:05\u202fpm - NISAMLC: You deleted this message',
#  '29/07/24, 5:24\u202fpm - NISAMLC: 🎤Since the django session has been completed we will be starting our 30 Days Project session from  Thursday August-1 by taking projects from ML,CV,DL,RECOMMENDER ENGINES AND SO ON *let me know how many of you are in* ?',
#  '',
#  '*What i will do*',
#  '- 2 hours per day i will be discussing a project with you and i will share the resources',
#  '- Every week i will assign a project to you means 4 projects you will be completing from your side at the end of camp',
#  '*What you need to do*',
#  '- Every day i will share the discussed projects resources, you should go through the project and execute it ',
#  '- You should create a github repo for every project and share it to LinkedIn means 30 posts at the end of the camp(excluding your own projects)',
#  '- I will assign weekly projects, you should complete it within the stipulated time period and mandatory to share that in the LinkedIn',
#  '- In the case of deployed projects you should share the link to the website and share it to linkedin along with github repo',
#  "*What if the plan don't work properly*",
#  '- if someone got into the project bootcamp and fail to do the assigned task or *fail to attend the session for even one day then we will end the bootcamp for them and they will not be able to join in any coming sessions* <This message was edited>',
#  '29/07/24, 5:24\u202fpm - NISAMLC: let me know how many of you are in?',
#  '29/07/24, 5:29\u202fpm - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): ✋🏻',
#  '29/07/24, 5:31\u202fpm - jisshnu.___ (DS-Codeme): 👍🏼',
#  '29/07/24, 6:04\u202fpm - Amal (DS-Codeme): ✋🏻',
#  '29/07/24, 6:06\u202fpm - Rashid (DS-Codeme): Count me in',
#  '29/07/24, 6:25\u202fpm - Asna. (DS-Codeme): ✋🏼',
#  '29/07/24, 7:00\u202fpm - +91 94966 64940: ✋🏻',
#  '29/07/24, 7:39\u202fpm - +91 86181 86237: This message was deleted',
#  '29/07/24, 7:40\u202fpm - +91 86181 86237: ✋🏻',
#  '30/07/24, 3:09\u202fpm - NISAMLC: Those who attending the Camp',
#  '- Karthika',
#  '- Jishnu',
#  '- Amal',
#  '- Rashid',
#  '- Asna',
#  '- Binjus',
#  '- Ayesha',
#  '31/07/24, 4:35\u202fpm - NISAMLC: We will be starting our project session from Tomorrow onwards',
#  '',
#  '- Scheduled Time : 2.30 to 4.30 (it can vary depends on the problem)',
#  '- Be Ready on Time',
#  '01/08/24, 2:23\u202fpm - NISAMLC: *Day 1 of Project Bootcamp*',
#  '*starts at 2.30PM*',
#  'Linke to Join : https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '02/08/24, 2:30\u202fpm - NISAMLC: *Day 2 of Project Bootcamp*',
#  '*starts at 2.30PM*',
#  'Linke to Join : https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '02/08/24, 2:35\u202fpm - Rashid (DS-Codeme): Waiting..',
#  '02/08/24, 2:36\u202fpm - NISAMLC: Who can join today and coming lectures:',
#  '- Amal',
#  '- Jishnu',
#  '- Asna',
#  '- Karthika',
#  '- Rashid',
#  '03/08/24, 2:36\u202fpm - Asif (CodeMe): https://www.pwc.in/careers/experienced-jobs/description.html?wdjobreqid=554074WD&wdcountry=IND&jobtitle=Specialist%203&wdjobsite=Global_Experienced_Careers',
#  '03/08/24, 2:37\u202fpm - Asif (CodeMe): pwc fresher opening for ds,apply asap',
#  '05/08/24, 10:22\u202fam - NISAMLC: those who are not submitted the project task will get a chance to submit their project link before 2.30pm today',
#  "Those who are not submitted will not be able to join in today's project",
#  '']

# %%
dummy = [ data.replace('\u202f', '') for data in raw]
dummy
# Out:
# ['26/02/24, 3:50pm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.',
#  '26/02/24, 3:01pm - jisshnu.___ (DS-Codeme) created group "Data science "',
#  '26/02/24, 3:50pm - jisshnu.___ (DS-Codeme) added you',
#  '26/02/24, 3:51pm - jisshnu.___ (DS-Codeme) added +91 86181 86237',
#  '26/02/24, 3:51pm - jisshnu.___ (DS-Codeme): try to do the project  yourself first then only refer the collab',
#  '26/02/24, 3:51pm - jisshnu.___ (DS-Codeme): https://colab.research.google.com/drive/1tKXB0p6bcZ4gwTUNjp9zNpRMYxC952qj?usp=sharing',
#  '27/02/24, 11:39am - Asif (CodeMe): https://meet.google.com/xsu-gthd-hmw',
#  '27/02/24, 12:46pm - Asif (CodeMe): https://colab.research.google.com/drive/1b_r9LNdmeSGUUIlFSQUteLKw07ESr5iQ?usp=sharing',
#  '27/02/24, 3:32pm - Asif (CodeMe): https://colab.research.google.com/drive/1yIHdz2bMzzLvGqh1Dq02AAwyYFbnJAf-?usp=sharing',
#  '27/02/24, 3:34pm - Asif (CodeMe): Refer this also while doing your project to understand how to use the sampling techniques. here i balanced the data after splitting to train and test',
#  '28/02/24, 9:16am - Asif (CodeMe): https://meet.google.com/sdk-sqzo-unn',
#  '28/02/24, 11:20am - Asif (CodeMe): https://docs.google.com/document/d/1SlzY5P0wQPr8ZsgBUc4m1mkr-fu-nlRZqBu_am2ZH2M/edit?usp=sharing',
#  '28/02/24, 11:59am - Aysha Hamna(CodeMe): https://meet.google.com/xut-tqwq-pcd',
#  '28/02/24, 12:01pm - jisshnu.___ (DS-Codeme) added +91 79077 33950',
#  '28/02/24, 1:20pm - Aysha Hamna(CodeMe): <Media omitted>',
#  '28/02/24, 1:20pm - Aysha Hamna(CodeMe): https://colab.research.google.com/drive/1ljIcfFMyAOJpIRWrrWa-61vppqIydnRU?usp=sharing',
#  '29/02/24, 9:08am - Asif (CodeMe): Same link',
#  '01/03/24, 9:25am - Asif (CodeMe): same link',
#  '01/03/24, 10:11am - Asif (CodeMe): https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit?usp=sharing',
#  '01/03/24, 11:43am - Aysha Hamna(CodeMe): https://meet.google.com/uiv-vkou-pda',
#  '01/03/24, 12:06pm - Aysha Hamna(CodeMe): <Media omitted>',
#  '01/03/24, 2:25pm - Aysha Hamna(CodeMe): join using same link',
#  '01/03/24, 3:44pm - Aysha Hamna(CodeMe): https://colab.research.google.com/drive/1P9fduGtId539V1MYs2ScQLPC6Ph8PrSx?usp=sharing',
#  '04/03/24, 9:27am - +91 86181 86237: Class started?',
#  '04/03/24, 9:30am - jisshnu.___ (DS-Codeme): no',
#  '04/03/24, 9:34am - Asif (CodeMe): https://meet.google.com/ind-raij-vzt',
#  '04/03/24, 9:44am - jisshnu.___ (DS-Codeme): https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit#gid=0',
#  '04/03/24, 11:48am - Aysha Hamna(CodeMe): This message was deleted',
#  '04/03/24, 11:50am - +91 94966 64940: It’s showing no such meeting',
#  '04/03/24, 11:50am - Aysha Hamna(CodeMe): https://meet.google.com/zpy-qjbm-sbj',
#  '04/03/24, 1:23pm - Asif (CodeMe): <Media omitted>',
#  '04/03/24, 3:05pm - Aysha Hamna(CodeMe): please join',
#  '04/03/24, 4:47pm - Amal (DS-Codeme): This message was deleted',
#  '04/03/24, 4:51pm - Rashid (DS-Codeme): Waiting for this message',
#  '04/03/24, 5:58pm - jisshnu.___ (DS-Codeme): <Media omitted>',
#  '05/03/24, 9:22am - Asif (CodeMe): SAME LINK',
#  '05/03/24, 10:07am - jisshnu.___ (DS-Codeme): <Media omitted>',
#  '05/03/24, 1:01pm - Asif (CodeMe): <Media omitted>',
#  '05/03/24, 1:01pm - Asif (CodeMe): <Media omitted>',
#  '05/03/24, 1:01pm - Asif (CodeMe): <Media omitted>',
#  '05/03/24, 5:34pm - Asif (CodeMe): <Media omitted>',
#  '06/03/24, 9:19am - Asif (CodeMe): same link',
#  '06/03/24, 12:09pm - Aysha Hamna(CodeMe): https://meet.google.com/ewj-ckus-jmv',
#  '06/03/24, 12:15pm - Aysha Hamna(CodeMe): https://hamoyehq.medium.com/hamoye-data-science-internship-fall-2024-call-for-application-79488110376d',
#  '06/03/24, 12:15pm - Aysha Hamna(CodeMe): https://docs.google.com/forms/d/e/1FAIpQLSe9Sr9L3H7oObSSZSB-qndQYNal1OGGcyTBfOppZLyuOKWPRg/viewform',
#  '06/03/24, 1:08pm - jisshnu.___ (DS-Codeme): <Media omitted>',
#  '06/03/24, 5:09pm - +91 94966 64940: Problem statement 🌚',
#  '06/03/24, 5:22pm - jisshnu.___ (DS-Codeme): EDA + Classification + Power BI',
#  '06/03/24, 5:23pm - jisshnu.___ (DS-Codeme): = certificate',
#  '06/03/24, 5:24pm - +91 94966 64940: This message was deleted',
#  '06/03/24, 7:13pm - NISAMLC: <Media omitted>',
#  '07/03/24, 9:25am - Asif (CodeMe): Same link',
#  '07/03/24, 9:36am - Asif (CodeMe): Some network issue',
#  '07/03/24, 10:10am - +91 86181 86237: This message was deleted',
#  '07/03/24, 10:15am - Asif (CodeMe): No join again',
#  '07/03/24, 2:41pm - Asif (CodeMe): same link join',
#  '08/03/24, 9:21am - Asif (CodeMe): Join the same link',
#  '08/03/24, 9:24am - +91 94966 64940: Please let me in',
#  "10/03/24, 8:41pm - Aysha Hamna(CodeMe): Tomorrow's machine learning class will start at 2 15 pm",
#  '10/03/24, 8:53pm - jisshnu.___ (DS-Codeme): This message was deleted',
#  '11/03/24, 9:48am - Asif (CodeMe): https://meet.google.com/ind-raij-vzt',
#  '11/03/24, 9:48am - Asif (CodeMe): This message was deleted',
#  '11/03/24, 9:48am - Asif (CodeMe): Join the link',
#  '11/03/24, 10:00am - +91 94966 64940: CREATE TABLE event (',
#  'event_id SERIAL PRIMARY KEY,',
#  'event_name VARCHAR(100),',
#  'event_date DATE,',
#  'event_time TIME',
#  ');',
#  'INSERT INTO event (event_id,event_name, event_date, event_time) VALUES',
#  "(1,'Meeting 1', '2024-03-02', '15:30:00'),",
#  "(2,'Meeting 2', '2023-03-03', '09:00:00'),",
#  "(3,'Conference', '2024-03-04', '10:45:00'),",
#  "(4,'Workshop', '2022-03-05', '13:00:00'),",
#  "(5,'Seminar', '2024-03-06', '16:15:00');",
#  '11/03/24, 2:48pm - Asif (CodeMe): join the same link',
#  '12/03/24, 9:30am - Amal (DS-Codeme): same link',
#  '12/03/24, 2:39pm - Asif (CodeMe): ds join the same link',
#  '13/03/24, 9:22am - jisshnu.___ (DS-Codeme): same',
#  '13/03/24, 11:39am - Aysha Hamna(CodeMe): https://meet.google.com/ewj-ckus-jmv',
#  '13/03/24, 2:32pm - Aysha Hamna(CodeMe): SAME LINK',
#  '13/03/24, 3:12pm - Aysha Hamna(CodeMe): <Media omitted>',
#  '14/03/24, 9:24am - Rashid (DS-Codeme): same link',
#  '14/03/24, 9:25am - Rashid (DS-Codeme): https://meet.google.com/ind-raij-vzt',
#  '14/03/24, 9:39am - +91 86181 86237: Let me into the class.',
#  '14/03/24, 9:42am - Rashid (DS-Codeme): network issue',
#  '14/03/24, 9:42am - +91 86181 86237: Ok',
#  '14/03/24, 9:43am - Rashid (DS-Codeme): wait couple of minutes',
#  '14/03/24, 10:36am - jisshnu.___ (DS-Codeme): This message was deleted',
#  '14/03/24, 2:36pm - Asif (CodeMe): Join the same link..',
#  '14/03/24, 2:36pm - Asif (CodeMe): .',
#  '14/03/24, 2:39pm - jisshnu.___ (DS-Codeme): in akkettilla',
#  '14/03/24, 2:39pm - Asif (CodeMe): Network issue und',
#  '14/03/24, 2:39pm - Asif (CodeMe): Wait',
#  '14/03/24, 2:39pm - jisshnu.___ (DS-Codeme): ok',
#  '14/03/24, 2:54pm - Asif (CodeMe): Join',
#  '14/03/24, 3:20pm - +91 94966 64940: Class ille',
#  '14/03/24, 3:20pm - +91 94966 64940: ??',
#  '14/03/24, 3:51pm - Asif (CodeMe): https://www.kdnuggets.com/2020/06/naive-bayes-algorithm-everything.html',
#  '15/03/24, 9:20am - Asif (CodeMe): \U0001f6dc WiFi Passwords\U0001f6dc',
#  '',
#  '*WiFi Name*: Codeme Hub (5G)',
#  '*Password*: codeme12##',
#  '',
#  '*WiFi Name*: Codeme Tech Learning',
#  '*Password*: codeme123##',
#  '15/03/24, 9:22am - Asif (CodeMe): join the same link',
#  '15/03/24, 12:54pm - Aysha Hamna(CodeMe): ML session will start at 2:15 pm',
#  '15/03/24, 2:18pm - Asif (CodeMe): join the same link',
#  '18/03/24, 9:13am - Asif (CodeMe): Same link',
#  '18/03/24, 12:29pm - Asif (CodeMe): ML Same link',
#  '18/03/24, 2:35pm - Asif (CodeMe): same limk',
#  '18/03/24, 3:46pm - jisshnu.___ (DS-Codeme): https://colab.research.google.com/drive/108YjV5uDkumB8aw5RMrie3rLCeyWcNk4?usp=sharing',
#  '19/03/24, 9:29am - Amal (DS-Codeme): Same link 9:35',
#  '19/03/24, 12:00pm - Asif (CodeMe): <Media omitted>',
#  '19/03/24, 12:01pm - Asif (CodeMe): Mandatory SQL Assessment',
#  'Deadline 9 AM- 20-03-2024',
#  '19/03/24, 3:46pm - Asif (CodeMe): This message was deleted',
#  '19/03/24, 4:07pm - Asif (CodeMe): Tomorrow Dax class will be from 11.15- 1.15 PM',
#  '19/03/24, 4:07pm - Asif (CodeMe): ML Class will be from 9 AM To 11 Am',
#  '20/03/24, 9:20am - Aysha Hamna(CodeMe): https://meet.google.com/uew-zqmr-sth',
#  '20/03/24, 11:27am - Aysha Hamna(CodeMe): <Media omitted>',
#  '20/03/24, 11:50am - Amal (DS-Codeme): same link',
#  "20/03/24, 4:23pm - Asif (CodeMe): I haven't received the SQL assessment @918618186237 ,send it ASAP",
#  '20/03/24, 4:24pm - +91 86181 86237: Where I I have to send it in  group',
#  '20/03/24, 4:24pm - Asif (CodeMe): Send here',
#  '20/03/24, 4:28pm - +91 86181 86237: This message was deleted',
#  '20/03/24, 4:30pm - Asif (CodeMe): This message was deleted',
#  '21/03/24, 9:52am - Asif (CodeMe): Power bi join the same link <This message was edited>',
#  '21/03/24, 1:18pm - Asif (CodeMe): <Media omitted>',
#  '22/03/24, 9:20am - Asif (CodeMe): Power bi same link',
#  '22/03/24, 11:18am - jisshnu.___ (DS-Codeme): screen poi',
#  '22/03/24, 11:42am - Asif (CodeMe): <Media omitted>',
#  '22/03/24, 2:03pm - Aysha Hamna(CodeMe): https://meet.google.com/uew-zqmr-sth',
#  '22/03/24, 2:03pm - Aysha Hamna(CodeMe): Join please',
#  '23/03/24, 2:31pm - Asif (CodeMe): Monday ',
#  "9-11 ML Aysha Ma'am ",
#  '11.15- 1.30 Power BI',
#  '23/03/24, 2:38pm - jisshnu.___ (DS-Codeme): Afternoon',
#  '23/03/24, 2:39pm - jisshnu.___ (DS-Codeme): Ille',
#  '23/03/24, 2:49pm - Asif (CodeMe): Class kaanum afternoon for ds',
#  '25/03/24, 9:28am - Aysha Hamna(CodeMe): join',
#  '25/03/24, 11:42am - Rashid (DS-Codeme): dax same link',
#  '25/03/24, 11:42am - Rashid (DS-Codeme): https://meet.google.com/ind-raij-vzt',
#  '25/03/24, 12:26pm - Rashid (DS-Codeme): <Media omitted>',
#  '25/03/24, 2:09pm - Aysha Hamna(CodeMe): https://www.kaggle.com/datasets/brijbhushannanda1979/bigmart-sales-data',
#  '25/03/24, 2:09pm - Aysha Hamna(CodeMe): Download dataset from this link and perform EDA',
#  '25/03/24, 2:09pm - Aysha Hamna(CodeMe): and then apply any regression model',
#  '25/03/24, 3:00pm - Aysha Hamna(CodeMe): Complete this task today',
#  "25/03/24, 3:00pm - Aysha Hamna(CodeMe): We postponed today's afternoon session",
#  '26/03/24, 11:33am - Asif (CodeMe): Power bi same link',
#  '26/03/24, 12:21pm - Asif (CodeMe): <Media omitted>',
#  '26/03/24, 2:09pm - Asif (CodeMe): <Media omitted>',
#  '27/03/24, 8:33am - +91 94966 64940: ML class',
#  'Will start at 11:00Am',
#  'Aysha Ma’am',
#  '27/03/24, 9:11am - jisshnu.___ (DS-Codeme): 👍🏽',
#  '27/03/24, 11:18am - Aysha Hamna(CodeMe): join',
#  '27/03/24, 12:15pm - Aysha Hamna(CodeMe): <Media omitted>',
#  '27/03/24, 12:34pm - Aysha Hamna(CodeMe): <Media omitted>',
#  '27/03/24, 12:38pm - Aysha Hamna(CodeMe): <Media omitted>',
#  '27/03/24, 1:03pm - Aysha Hamna(CodeMe): https://www.kaggle.com/competitions/titanic/data',
#  '27/03/24, 2:29pm - Aysha Hamna(CodeMe): join',
#  '27/03/24, 4:55pm - Asif (CodeMe): PCA Tomorrow 11.30-1 and 2.15 -3.45',
#  '28/03/24, 9:10am - Asif (CodeMe): 4th floor aan class 11.30',
#  '28/03/24, 11:30am - Asif (CodeMe): https://meet.google.com/svp-wgoq-ajb',
#  '28/03/24, 11:30am - Asif (CodeMe): join',
#  '28/03/24, 2:25pm - Amal (DS-Codeme): 2.30 join',
#  '31/03/24, 6:05pm - Amal (DS-Codeme): https://www.microsoft.com/en-us/cloudskillschallenge/ai/registration/2024?ocid=aisc23_CSC_skillsforaiblog_cnl#choose-your-challenge',
#  '31/03/24, 9:11pm - NISAMLC: Tomorrow 2.00PM:Lecture On Recommendation Engines, build your first Recommender <This message was edited>',
#  '01/04/24, 2:02pm - NISAMLC: How many of you are attending Offline??',
#  '01/04/24, 2:03pm - jisshnu.___ (DS-Codeme): Im not',
#  '01/04/24, 2:03pm - +91 94966 64940: 🤚🏻',
#  '01/04/24, 2:04pm - Amal (DS-Codeme): ✌🏻',
#  '01/04/24, 2:04pm - NISAMLC: Conference Hall <This message was edited>',
#  '01/04/24, 2:18pm - +91 86181 86237: No online class?',
#  '01/04/24, 2:31pm - Rashid (DS-Codeme): https://meet.google.com/yyp-ybak-jqd',
#  '01/04/24, 3:51pm - NISAMLC: <Media omitted>',
#  '02/04/24, 2:02pm - NISAMLC: You deleted this message',
#  '02/04/24, 2:05pm - Amal (DS-Codeme): https://meet.google.com/jiy-cjvd-ums',
#  '02/04/24, 2:07pm - NISAMLC: join in this',
#  '02/04/24, 4:05pm - NISAMLC: <Media omitted>',
#  '02/04/24, 4:06pm - NISAMLC: <Media omitted>',
#  '03/04/24, 2:10pm - NISAMLC: https://meet.google.com/wpa-gyyd-kte',
#  '04/04/24, 1:13pm - NISAMLC: class starts @2.30 pm today <This message was edited>',
#  '04/04/24, 2:40pm - NISAMLC: SAME LINK',
#  '04/04/24, 3:19pm - NISAMLC: <Media omitted>',
#  '04/04/24, 4:03pm - NISAMLC: https://github.com/JovianHQ/opendatasets/blob/master/data/countries-languages-spoken/countries-languages.csv <This message was edited>',
#  '04/04/24, 4:03pm - NISAMLC: Create a Country Recommender based on the language spoken',
#  '04/04/24, 4:07pm - NISAMLC: https://www.kaggle.com/datasets/dylanjcastillo/7k-books-with-metadata',
#  '04/04/24, 4:08pm - NISAMLC: Build a Book Recommender based on the description about the book',
#  '04/04/24, 4:14pm - +91 86181 86237: This message was deleted',
#  '04/04/24, 4:16pm - jisshnu.___ (DS-Codeme): ok',
#  '05/04/24, 9:15am - NISAMLC: No class today, try to explore more recommendation systems using various datasets',
#  '05/04/24, 9:15am - Rashid (DS-Codeme): Okay',
#  '05/04/24, 10:46am - jisshnu.___ (DS-Codeme): Okay',
#  '05/04/24, 9:46pm - Rashid (DS-Codeme): https://www.youtube.com/live/wB7m2YMqVVY?si=IJq7IixEgva7Tu8t',
#  '05/04/24, 9:47pm - Rashid (DS-Codeme): live class of hamoye',
#  '08/04/24, 1:54pm - NISAMLC: Anyone offline??',
#  '08/04/24, 2:00pm - NISAMLC: https://us05web.zoom.us/j/89944631210?pwd=Vi6hcSNnsdHS5bQgh5r44jeHLt9Hgo.1',
#  '08/04/24, 2:02pm - NISAMLC: join',
#  '08/04/24, 2:34pm - NISAMLC: https://meet.google.com/eir-sawr-tui',
#  '08/04/24, 2:34pm - NISAMLC: rejoin',
#  '09/04/24, 1:42pm - NISAMLC: <Media omitted>',
#  '09/04/24, 2:08pm - NISAMLC: https://meet.google.com/xuo-ahea-zvc',
#  '09/04/24, 2:08pm - NISAMLC: join',
#  '11/04/24, 3:17pm - NISAMLC: *Create a recommendation system which recommends books or documents* Data:scrape data from websites like goodreads and scribd or any other website, do it and submit it before coming monday 9..00AM try <This message was edited>',
#  '15/04/24, 4:25pm - NISAMLC: Tomorrow onwards There will be two sessions are going on for *Data Science* students',
#  '- 11.00pm to 1.00pm : Time Series Forecasting',
#  '- 2.30 to 5.00pm : MLOPS AND Recommendation Systems',
#  "16/04/24, 11:25am - +91 86181 86237: today's class is there?",
#  '16/04/24, 11:25am - Aysha Hamna(CodeMe): This message was deleted',
#  '16/04/24, 11:26am - Amal (DS-Codeme): https://us05web.zoom.us/j/84356593130?pwd=tE40wZMVVhZahfQfpMlWmaiuQMdVEh.1',
#  '16/04/24, 11:28am - +91 86181 86237: ML class?',
#  '16/04/24, 11:28am - Amal (DS-Codeme): Join',
#  '16/04/24, 11:45am - Amal (DS-Codeme): This message was deleted',
#  '16/04/24, 11:45am - Amal (DS-Codeme): This message was deleted',
#  '16/04/24, 11:46am - NISAMLC: join in this link',
#  '16/04/24, 11:46am - NISAMLC: https://us05web.zoom.us/j/82662632874?pwd=lgeKSnCVezGajLEX1IeAx3TBlt6Xd8.1',
#  '16/04/24, 12:30pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83954675823?pwd=hZBXtKvZBMKaci3f79IzVd4Munacw5.1',
#  '16/04/24, 12:30pm - jisshnu.___ (DS-Codeme): rejoin',
#  '16/04/24, 1:10pm - jisshnu.___ (DS-Codeme): 2.30',
#  '16/04/24, 1:10pm - jisshnu.___ (DS-Codeme): next class',
#  '16/04/24, 2:23pm - NISAMLC: join immediately',
#  '16/04/24, 2:24pm - NISAMLC: link  comes',
#  '16/04/24, 2:27pm - NISAMLC: https://us05web.zoom.us/j/89882762836?pwd=f4OJJDwtrLYksEeOXGEua1VsSK1gS0.1',
#  '16/04/24, 3:09pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83124834127?pwd=CZnC3e1LCu4BZKbtXpoR8vdUF0bY8W.1',
#  '16/04/24, 3:10pm - jisshnu.___ (DS-Codeme): rejoin',
#  '16/04/24, 3:51pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/84698759689?pwd=jc3uaX38A8XKT9i8aGEyEeV4FGOhbD.1',
#  '16/04/24, 4:31pm - NISAMLC: last join',
#  '16/04/24, 4:32pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87597044212?pwd=eYhexXtU8wlpMxKP894sKaZ9ESCEFv.1',
#  '17/04/24, 10:56am - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/81088179003?pwd=4cy88JdC9vDOk311hla6REoyV4ZHw5.1',
#  '17/04/24, 10:56am - jisshnu.___ (DS-Codeme): join',
#  '17/04/24, 11:37am - NISAMLC: https://us05web.zoom.us/j/85900123290?pwd=dHszQjo1DUVTUUK0eulZhlDGN0ePKE.1',
#  '17/04/24, 11:37am - NISAMLC: join',
#  '17/04/24, 11:55am - NISAMLC: <Media omitted>',
#  '17/04/24, 12:18pm - NISAMLC: <Media omitted>',
#  '17/04/24, 12:18pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/85320192983?pwd=mbloGXvXoW4fR5CrQ7tkevcaB2X2ZM.1',
#  '17/04/24, 12:18pm - jisshnu.___ (DS-Codeme): rejoin',
#  '17/04/24, 2:25pm - NISAMLC: join immediately',
#  '17/04/24, 2:29pm - NISAMLC: https://us05web.zoom.us/j/86955036516?pwd=bKixQEfWmQTdTbHwDigNVcsZSmkHx4.1',
#  '17/04/24, 3:11pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/88418826144?pwd=AGMp0uqMGf2gF6uSZwgJ1HqTyAjXTi.1',
#  '17/04/24, 3:52pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83068961004?pwd=fwxUEnK21rZ1M2Qn46HBArPHwUiU2g.1',
#  '17/04/24, 4:16pm - NISAMLC: https://www.kaggle.com/datasets/zygmunt/goodbooks-10k',
#  '18/04/24, 11:13am - NISAMLC: https://us05web.zoom.us/j/82196771153?pwd=5SBVgnTDk5F6vIjFduX0TzsL5VeCFa.1',
#  '18/04/24, 11:57am - Amal (DS-Codeme): https://us05web.zoom.us/j/81310056571?pwd=9bpbaQ6goaGabCrJPHmoKHR7oFPKu5.1',
#  '18/04/24, 2:23pm - NISAMLC: join immediately',
#  '18/04/24, 2:30pm - Amal (DS-Codeme): https://us05web.zoom.us/j/84126238187?pwd=WPsF79MUYkPRheBHE3vTRqdxLUqyml.1',
#  '18/04/24, 3:11pm - Amal (DS-Codeme): https://us05web.zoom.us/j/88298798338?pwd=OXqo2o2NfHu3Ty2Y5hkua2Ut3KXCP0.1',
#  '18/04/24, 3:52pm - Amal (DS-Codeme): https://us05web.zoom.us/j/84745853077?pwd=xmT9cP4e5uSFiaUD6dcLrnkabbRMfj.1',
#  '19/04/24, 11:06am - NISAMLC: JOIN',
#  '19/04/24, 11:06am - NISAMLC: https://us05web.zoom.us/j/85029807729?pwd=R2FC3g5JSz2Cmk2327RnGCnwrgbG1X.1',
#  '19/04/24, 11:13am - +91 86181 86237: Please add in',
#  '19/04/24, 11:15am - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): This message was deleted',
#  '19/04/24, 11:50am - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/84998061454?pwd=Hf7VPgXs9s10R6kaWHp9fSvP2SChXG.1',
#  '19/04/24, 12:13pm - NISAMLC: <Media omitted>',
#  '19/04/24, 2:49pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/88476935533?pwd=NGwH2oEMx62JoUOu6XIcj7GgiLQiUh.1',
#  '19/04/24, 3:28pm - NISAMLC: https://www.kaggle.com/datasets/prajitdatta/movielens-100k-dataset/data',
#  '19/04/24, 3:32pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83223361006?pwd=nMcKtUZMKxPJcn2dbwfR4Y4nwFrLUW.1',
#  '19/04/24, 4:13pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/82183401601?pwd=B90w2RLezed2fSwwFytoVvbjDG3R1R.1',
#  '19/04/24, 4:35pm - NISAMLC: <Media omitted>',
#  '19/04/24, 4:35pm - NISAMLC: <Media omitted>',
#  '22/04/24, 11:05am - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87644185104?pwd=UoZyDi9uVqE4COBvWTNKdXH6poOALK.1',
#  '22/04/24, 11:20am - NISAMLC: <Media omitted>',
#  '22/04/24, 11:47am - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83719435591?pwd=OAOinOmRv6owb4ur0XT7Xc4ezDCEhj.1',
#  '22/04/24, 12:30pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87168841298?pwd=6pkmUIjKiEwwVYMpLNv844bEVoGyC3.1',
#  '22/04/24, 12:39pm - NISAMLC: <Media omitted>',
#  '22/04/24, 1:11pm - NISAMLC: join at 2.30 pm',
#  '22/04/24, 2:30pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/86285461568?pwd=m4IKlxw6ASWObFncC4hONqzuG7JJV9.1',
#  '22/04/24, 3:11pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/82808190042?pwd=0NVFr47d2PDPGOC1ONwDGNvaTiep8q.1',
#  '22/04/24, 3:52pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/85777199753?pwd=lPVl2Yd5x1iJXohgGXhRdE0fbWH4rv.1',
#  '22/04/24, 4:17pm - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): https://visualstudio.microsoft.com/visual-cpp-build-tools/',
#  '22/04/24, 4:18pm - NISAMLC: <Media omitted>',
#  '22/04/24, 4:19pm - NISAMLC: <Media omitted>',
#  '23/04/24, 11:02am - NISAMLC: JOIN',
#  '23/04/24, 11:03am - +91 94966 64940: Link?',
#  '23/04/24, 11:04am - NISAMLC: https://us05web.zoom.us/j/84172735576?pwd=p9JDPvN1splta73xe0e0cJEljAxU14.1',
#  '23/04/24, 11:45am - Amal (DS-Codeme): https://us05web.zoom.us/j/86837283209?pwd=BiZRMT5mflOnTH7qv9PkvLXpKekvja.1',
#  '23/04/24, 2:29pm - Amal (DS-Codeme): https://us05web.zoom.us/j/87894573653?pwd=dalYPnEGwRnvhYF9wXb5tXmMWhaZX6.1',
#  '23/04/24, 3:10pm - NISAMLC: https://us05web.zoom.us/j/89958400034?pwd=pB3kaxEXbSBonzej9ZjYhnOdDycChI.1',
#  '23/04/24, 3:51pm - Amal (DS-Codeme): https://us05web.zoom.us/j/81104718108?pwd=QZabNNMb5lDbC8ddg3lwXjTrRjb2nG.1',
#  '23/04/24, 4:09pm - NISAMLC: <Media omitted>',
#  '23/04/24, 4:09pm - NISAMLC: <Media omitted>',
#  '23/04/24, 4:10pm - NISAMLC: *market basket analysis*',
#  '23/04/24, 4:10pm - NISAMLC: <Media omitted>',
#  '23/04/24, 4:11pm - NISAMLC: <Media omitted>',
#  '24/04/24, 11:05am - NISAMLC: join',
#  '24/04/24, 11:06am - NISAMLC: https://us05web.zoom.us/j/88244453101?pwd=FdH0PcnOXMSjsT3A0IoaQShXNKbsa7.1',
#  '24/04/24, 11:10am - +91 86181 86237: Please add in',
#  '24/04/24, 11:48am - NISAMLC: https://us04web.zoom.us/j/72173791910?pwd=bADdLHM7aJFqaHJxatinEs1GK6Fm7N.1',
#  '24/04/24, 11:48am - NISAMLC: join',
#  '24/04/24, 12:22pm - Amal (DS-Codeme): https://sampleportfolio-a7brzwhi85rmvtef4wngqj.streamlit.app/',
#  '24/04/24, 12:30pm - NISAMLC: let me know if you have any doubts',
#  '24/04/24, 12:31pm - NISAMLC: join',
#  '24/04/24, 12:31pm - NISAMLC: https://meet.google.com/hnf-wehd-ypx',
#  '24/04/24, 12:34pm - NISAMLC: Those who submitted :',
#  '- Amal Roshan',
#  '24/04/24, 12:56pm - NISAMLC: *JOIN AT 2.30: Time Series : ACF AND PACF MODELS FOR TIME SERIES FORASTING*',
#  '24/04/24, 2:31pm - NISAMLC: join',
#  '24/04/24, 2:33pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/88538105805?pwd=ZSYtpaIb5n02IwfADmkStah47tWKqU.1',
#  '24/04/24, 2:33pm - Asna. (DS-Codeme): https://deploy-asnafidha.streamlit.app',
#  '24/04/24, 2:33pm - NISAMLC: Those who submitted :',
#  '- Amal Roshan',
#  '- Jishnu',
#  '- Asna',
#  '24/04/24, 2:45pm - jisshnu.___ (DS-Codeme): Sorry',
#  '24/04/24, 2:46pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/81270550054?pwd=jDnkE79Y8JliuNVoPkuHfKE0oLexcG.1',
#  '24/04/24, 3:27pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/84088354300?pwd=DI2TLClARzPcf4dRnppAt8ajLO0g0v.1',
#  '24/04/24, 4:07pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/85018623759?pwd=viFBEMe7js12WkpzvnsNHG2pawwhjY.1',
#  '25/04/24, 11:07am - NISAMLC: join',
#  '25/04/24, 11:11am - NISAMLC: https://us04web.zoom.us/j/79134534643?pwd=n6ka0KpC5XbqUF1YBiVDfGJLBp0gI7.1',
#  '25/04/24, 11:52am - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87430068127?pwd=bEX00IJNqEAzL9YvMhVEdtahO84GbN.1',
#  '25/04/24, 12:32pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/86927643942?pwd=UNWBUduc0ahzwvaZbweOP4QIBxPtrC.1',
#  '25/04/24, 2:30pm - NISAMLC: join',
#  '25/04/24, 2:33pm - NISAMLC: https://us05web.zoom.us/j/86189409946?pwd=jKxbPOLxwZKt3G3FLpoaY1dk3MMp7I.1',
#  '25/04/24, 3:04pm - NISAMLC: <Media omitted>',
#  '25/04/24, 3:04pm - NISAMLC: Perform the same > AR model on Female Birth Data',
#  '25/04/24, 3:05pm - NISAMLC: 3.35 pm',
#  '25/04/24, 3:18pm - NISAMLC: https://us04web.zoom.us/j/76691224273?pwd=bby3tlcIi3rHzVyg4jYSBjd2cntbtq.1',
#  '25/04/24, 3:19pm - NISAMLC: join',
#  '25/04/24, 4:00pm - NISAMLC: Perform the same on the shampoo dataset',
#  '25/04/24, 4:00pm - jisshnu.___ (DS-Codeme): Ok',
#  '25/04/24, 4:00pm - +91 94966 64940: Please share the final notebook',
#  '25/04/24, 4:01pm - NISAMLC: k',
#  '25/04/24, 4:01pm - NISAMLC: <Media omitted>',
#  '25/04/24, 4:01pm - NISAMLC: modify the days of prediction',
#  '25/04/24, 4:01pm - NISAMLC: like if you want to predict for the last 15 days or 30 days and so on',
#  '25/04/24, 4:07pm - NISAMLC: *Download any Stock Price from yahoofinance and perform AutoRegression on top of it and findout the predicted values: measure the accuracy and evaluate it by creating plots and metrics* submit before monday :This is your first main time series task',
#  '25/04/24, 4:13pm - NISAMLC: @919946189970',
#  '25/04/24, 4:20pm - NISAMLC: https://www.kaggle.com/datasets/niketchauhan/covid-19-time-series-data',
#  '25/04/24, 4:20pm - NISAMLC: Link to Covid 19 dataset',
#  '25/04/24, 4:21pm - NISAMLC: choose one country from this data',
#  '25/04/24, 4:21pm - NISAMLC: and perform AutoRegression in order to find the covid cases',
#  '25/04/24, 4:21pm - NISAMLC: try different countries and compare results',
#  '25/04/24, 4:21pm - NISAMLC: submit it before monday',
#  "28/04/24, 10:30pm - Aysha Hamna(CodeMe): Tomorrow's Data Science session is scheduled at 2:30 pm",
#  '28/04/24, 10:35pm - jisshnu.___ (DS-Codeme): Ok',
#  '29/04/24, 2:22pm - Aysha Hamna(CodeMe): How many of u are attending online?',
#  '29/04/24, 2:23pm - jisshnu.___ (DS-Codeme): ✋🏼',
#  '29/04/24, 2:23pm - Asna. (DS-Codeme): 🤚🏽',
#  '29/04/24, 2:24pm - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): 🤚🏻',
#  '29/04/24, 2:27pm - +91 86181 86237: 🤚',
#  '29/04/24, 2:29pm - Aysha Hamna(CodeMe): For those in attendance offline, the session will take place in the last classroom.',
#  '(The classroom at corner)',
#  '29/04/24, 2:35pm - Aysha Hamna(CodeMe): https://us05web.zoom.us/j/87110841572?pwd=OWJbPWbvehs3oWoB949WmyAFXXQwMB.1',
#  '29/04/24, 2:35pm - Aysha Hamna(CodeMe): please join',
#  '29/04/24, 3:11pm - jisshnu.___ (DS-Codeme): Invalid meeting id',
#  '29/04/24, 3:11pm - Amal (DS-Codeme): https://us05web.zoom.us/j/84426665904?pwd=eW10ScuhCCcu6diyauNYhTVsWoM9LB.1',
#  '29/04/24, 3:47pm - Aysha Hamna(CodeMe): https://atlas.mitre.org/matrices/ATLAS',
#  '29/04/24, 3:48pm - Aysha Hamna(CodeMe): https://incidentdatabase.ai/',
#  '29/04/24, 3:53pm - Aysha Hamna(CodeMe): https://us05web.zoom.us/j/86732036320?pwd=yaIPNxa9hp9B6H5j9Ai3ptzuqqSWmu.1',
#  '30/04/24, 9:53am - Asif (CodeMe): https://meet.google.com/vrs-wvoh-zng',
#  '30/04/24, 9:53am - Asif (CodeMe): join',
#  '30/04/24, 9:53am - Asif (CodeMe): <Media omitted>',
#  '01/05/24, 10:57am - NISAMLC: join',
#  '01/05/24, 11:02am - +91 94966 64940: Link?',
#  '01/05/24, 11:04am - NISAMLC: https://us05web.zoom.us/j/84146894791?pwd=0FGmCXYSFl4GRMAUUQxPIJnr0y189w.1',
#  '01/05/24, 11:47am - Amal (DS-Codeme): https://us05web.zoom.us/j/85738513589?pwd=PzjFyd46iBkdv6jWYqDb4hKhaLaBWb.1',
#  '01/05/24, 12:28pm - NISAMLC: https://us05web.zoom.us/j/86258974313?pwd=ZO778uGGRCZaZ1rXJjEE9zDaMxvhCK.1',
#  '01/05/24, 1:02pm - NISAMLC: <Media omitted>',
#  '01/05/24, 2:34pm - Aysha Hamna(CodeMe): https://us05web.zoom.us/j/81324776140?pwd=NqfRe3VCI7kv6hNjXNG26xsxSFBLUh.1',
#  '01/05/24, 3:18pm - +91 94966 64940: Link?',
#  '01/05/24, 3:19pm - Amal (DS-Codeme): https://us05web.zoom.us/j/85302314572?pwd=LQlX8uiB8lxqGwzHLCuDih5lmgj0XW.1',
#  '01/05/24, 3:20pm - Aysha Hamna(CodeMe): https://www.youtube.com/watch?v=aircAruvnKk&t=784s',
#  '02/05/24, 11:03am - NISAMLC: join',
#  '02/05/24, 11:06am - NISAMLC: https://us05web.zoom.us/j/81956643317?pwd=a2Dnir1U7fq4Y1fPoLoKt4KysYsVlm.1',
#  '02/05/24, 11:47am - Amal (DS-Codeme): https://us05web.zoom.us/j/83794961231?pwd=LSLhV9pdiXCEiEHkkFmNNoW09m7PCJ.1',
#  '02/05/24, 12:08pm - NISAMLC: <Media omitted>',
#  '02/05/24, 12:29pm - NISAMLC: https://us05web.zoom.us/j/83432770790?pwd=15aIavmf3exCGAUn0MLQRw3ZW2B8VY.1',
#  "02/05/24, 8:23pm - Aysha Hamna(CodeMe): Tomorrow's schedule",
#  '11:00 am to 1:00  pm - Deep learning',
#  'Afternoon session - ',
#  'Time series',
#  '03/05/24, 11:04am - Aysha Hamna(CodeMe): anyone offline?',
#  '03/05/24, 11:05am - Amal (DS-Codeme): online 🙌🏻',
#  '03/05/24, 11:06am - Aysha Hamna(CodeMe): https://us05web.zoom.us/j/89768721231?pwd=RUHgbb3leOUDroj4M26QHtIdPloj3g.1',
#  '03/05/24, 11:47am - Rashid (DS-Codeme): link',
#  '03/05/24, 11:48am - Amal (DS-Codeme): https://us05web.zoom.us/j/81690932462?pwd=BG1xPitPTZx0ZMQ1jATFbswR3XqJuG.1',
#  '03/05/24, 2:33pm - NISAMLC: join',
#  '03/05/24, 2:37pm - NISAMLC: https://us05web.zoom.us/j/86546468416?pwd=vgLrHWK0l0WMw6nfgT0Mb2qzUdcyOG.1',
#  '03/05/24, 3:20pm - jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/82347408592?pwd=bap6BJ5lpH0Q6qOw9rofMePqx75Ovm.1',
#  '03/05/24, 3:42pm - NISAMLC: https://www.youtube.com/playlist?list=PLvcbYUQ5t0UHOLnBzl46_Q6QKtFgfMGc3',
#  '03/05/24, 3:58pm - +91 94966 64940: @918593099647 innalathem innathem notebooks share ako',
#  '03/05/24, 3:58pm - NISAMLC: okay',
#  '03/05/24, 3:58pm - NISAMLC: <Media omitted>',
#  '03/05/24, 3:58pm - NISAMLC: <Media omitted>',
#  '03/05/24, 3:59pm - NISAMLC: <Media omitted>',
#  '03/05/24, 3:59pm - NISAMLC: <Media omitted>',
#  '06/05/24, 10:55am - Aysha Hamna(CodeMe): Anyone offline',
#  '06/05/24, 11:02am - jisshnu.___ (DS-Codeme): ✋🏼',
#  '06/05/24, 11:03am - Aysha Hamna(CodeMe): ok',
#  '06/05/24, 11:06am - Aysha Hamna(CodeMe): https://meet.google.com/ihx-eeyg-mwi',
#  "06/05/24, 8:46pm - Aysha Hamna(CodeMe): Tomorrow's schedule",
#  'Online session at 10:00 am ',
#  'Topic : Neural Network <This message was edited>',
#  '06/05/24, 10:35pm - Aysha Hamna(CodeMe): 🔴 session rescheduled to 3 pm tomorrow',
#  '08/05/24, 11:21am - Aysha Hamna(CodeMe): same link',
#  '08/05/24, 1:04pm - Aysha Hamna(CodeMe): https://colab.research.google.com/drive/1klJqPJr4dvIQsX6fWjT6I4CRU4iqUEqH?usp=sharing',
#  '08/05/24, 8:46pm - Aysha Hamna(CodeMe): Go through the gradient descent topics that we learned for linear models.',
#  "08/05/24, 8:46pm - Aysha Hamna(CodeMe): Its necessary for tomorrow's session",
#  '08/05/24, 8:52pm - Aysha Hamna(CodeMe): We have offline session tomorrow at 11 am',
#  '09/05/24, 11:03am - NISAMLC: ANYONE OFFLINE?',
#  '09/05/24, 11:05am - NISAMLC: JOIN',
#  '09/05/24, 11:12am - NISAMLC: https://us05web.zoom.us/j/87386242572?pwd=ELelyhYQxEmPNwtWba2ZLmEDF23Et9.1',
#  '09/05/24, 11:54am - Amal (DS-Codeme): https://us05web.zoom.us/j/88583487724?pwd=gey9tmKciyfuaRjqapQa9bMCPkMy3t.1',
#  '09/05/24, 12:34pm - Amal (DS-Codeme): https://us05web.zoom.us/j/81380987479?pwd=G50yjRywUHypiqguW4p02RW9wqCqzN.1',
#  '09/05/24, 1:16pm - NISAMLC: reamining will discuss in the next class, take a look at Logistic regression',
#  '10/05/24, 11:11am - NISAMLC: class will start soon',
#  '10/05/24, 11:17am - NISAMLC: https://us05web.zoom.us/j/84975007689?pwd=h6wFrvavIAMux0cnHnaZyPadbGeFvN.1',
#  '10/05/24, 11:31am - jisshnu.___ (DS-Codeme): Let me in',
#  '10/05/24, 11:58am - NISAMLC: @919778218181 meet',
#  '10/05/24, 11:59am - Amal (DS-Codeme): https://us05web.zoom.us/j/81890576665?pwd=c1QHxvO4aEIEXCNernGf85Yy6VVQJ1.1',
#  '10/05/24, 12:34pm - NISAMLC: we can stop for todat at : Basic gradient descent , Try to unnderstand it more by incorporating the discussed concept ,and explore batch gradient descend and how it works , And *create a linear regression model by taking a real world data without using Linear Regression class from sklearn in the next class*',
#  '14/05/24, 11:01am - NISAMLC: https://us06web.zoom.us/j/82998391278?pwd=UKupeIbzYEOwemN7P4Uw5ArRaANN7k.1',
#  '14/05/24, 11:01am - NISAMLC: join',
#  '14/05/24, 11:09am - NISAMLC: ini aarenkilum join cheyyunnundo?',
#  '14/05/24, 11:09am - +91 94966 64940: Yes',
#  '14/05/24, 11:10am - NISAMLC: @917736866448 ???',
#  '14/05/24, 11:25am - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): Yes',
#  '14/05/24, 12:40pm - +91 94966 64940: Sir please let me in',
#  '14/05/24, 12:40pm - +91 94966 64940: @918593099647',
#  '14/05/24, 2:30pm - NISAMLC: https://us06web.zoom.us/j/85864309016?pwd=Yw5Zb7Ha739FPtz6n1rm74TCVSBpiU.1',
#  '14/05/24, 2:30pm - NISAMLC: join',
#  '14/05/24, 4:46pm - Rashid (DS-Codeme): Notebook',
#  '14/05/24, 4:47pm - +91 94966 64940: Recording also',
#  '14/05/24, 4:50pm - NISAMLC: <Media omitted>',
#  '14/05/24, 4:51pm - NISAMLC: check out this tutorials from tensorflow itself, https://www.tensorflow.org/tutorials',
#  "15/05/24, 10:00am - NISAMLC: Today's class starts @2.30 PM everyone be on time :",
#  'Topic: Implementation of Multi Hidden Layer Perceptron(Multi Hidden Layer Neural Network)',
#  '15/05/24, 2:34pm - NISAMLC: https://us06web.zoom.us/j/81668957371?pwd=YwBWdXxDTkypIwrWcfIutDfBzzWbw8.1',
#  '15/05/24, 7:27pm - +91 94966 64940: B- blood kittaan indo arelm',
#  '15/05/24, 7:28pm - jisshnu.___ (DS-Codeme): Positive nd',
#  '16/05/24, 10:02am - NISAMLC: join @11.00pm on : implementing a regression problem',
#  '16/05/24, 11:02am - NISAMLC: https://us06web.zoom.us/j/85790204001?pwd=aUmiRhNSlP3WI2WkMRzmzb5lfHaJAv.1',
#  '16/05/24, 11:48am - NISAMLC: <Media omitted>',
#  '17/05/24, 11:02am - NISAMLC: https://us06web.zoom.us/j/82211794464?pwd=9jODZBXpZGvJziz15TInGkFKfqh6Db.1',
#  '17/05/24, 11:07am - +91 86181 86237: Please let me in',
#  '17/05/24, 5:44pm - Aysha Hamna(CodeMe): Check out this job at Sony Research India: https://www.linkedin.com/jobs/view/3917526117',
#  '20/05/24, 12:49pm - NISAMLC: class starts @2.30pm',
#  '20/05/24, 2:31pm - NISAMLC: https://us06web.zoom.us/j/89079927141?pwd=uAuUKsCJ3HYLV9XSdtrIfFhAM4Zlua.1',
#  '20/05/24, 2:31pm - NISAMLC: join',
#  '21/05/24, 2:13pm - NISAMLC: class starts @2.30pm',
#  '21/05/24, 2:19pm - NISAMLC: on : End to End Deep Learning Project',
#  '21/05/24, 2:22pm - NISAMLC: https://us06web.zoom.us/j/84819824369?pwd=W91jLH9SSz2dwjsfUqaJnCezd6OIxy.1',
#  '21/05/24, 2:22pm - NISAMLC: join',
#  '21/05/24, 4:21pm - NISAMLC: https://www.kaggle.com/datasets/gauravtopre/bank-customer-churn-dataset',
#  '22/05/24, 1:58pm - NISAMLC: class starts @2.30 on CNN',
#  '22/05/24, 2:34pm - NISAMLC: https://us06web.zoom.us/j/84150849582?pwd=E5eNW8ZSXcnQe7krTJ3ynobU9l8qxR.1',
#  '22/05/24, 2:34pm - NISAMLC: join',
#  '22/05/24, 2:38pm - Rashid (DS-Codeme): Let me in',
#  '23/05/24, 2:07pm - NISAMLC: CLASS WILL START @2.30 ON TFL AND PADDING ANS STRIPE',
#  '23/05/24, 2:31pm - NISAMLC: https://us06web.zoom.us/j/88676945662?pwd=qtkCSpiakGI73ENb4BuLxM3JmhIMKM.1',
#  '23/05/24, 2:31pm - NISAMLC: join',
#  '23/05/24, 2:36pm - +91 94966 64940: Unable to join',
#  '23/05/24, 2:36pm - +91 94966 64940: Facing network issues',
#  '23/05/24, 3:12pm - NISAMLC: https://us06web.zoom.us/j/84774931149?pwd=IZhaEyGogISiuWUJwcbaZWxaFs5WK8.1',
#  '23/05/24, 3:12pm - NISAMLC: join',
#  '23/05/24, 3:12pm - NISAMLC: asap',
#  '24/05/24, 2:27pm - NISAMLC: https://us06web.zoom.us/j/89735874355?pwd=KtdBvYzjffeLwYbyA3HUzt7VwpuKw1.1',
#  '24/05/24, 2:28pm - NISAMLC: join',
#  '24/05/24, 3:31pm - NISAMLC: <Media omitted>',
#  '24/05/24, 4:02pm - NISAMLC: complete this task and  implement CNN on top of any image dataset',
#  '24/05/24, 4:02pm - NISAMLC: imlement CNN on flowers dataset as well',
#  '24/05/24, 4:02pm - NISAMLC: and submit those notes before monday afternoon',
#  '26/05/24, 11:12pm - NISAMLC: Tomorrow you will not have regular session instead you will be assigned a task and it will be consider as your Deep Learning *Mini Project* <This message was edited>',
#  '27/05/24, 10:20am - NISAMLC: Mini Project On Deep Learning : *Create A Multi Layer Convolutional Neural Network in order to classify Flowers using googleapi flowers dataset and classify it into 5 different categories namely Rose,Tulip, Sunflower,Daisy and Dandelion* save Your Model into h5 file and send to me via my email with notebook  : nisamlckkn@gmail.com on or before 29th of May',
#  '27/05/24, 10:21am - Rashid (DS-Codeme): Ok sir',
#  '28/05/24, 10:10am - NISAMLC: class starts @2.30 on Introduction to Computer Vision and Image manipulation',
#  '28/05/24, 2:27pm - NISAMLC: https://us06web.zoom.us/j/89163859148?pwd=lyAoMKZRNWAgriZ9pai2IszdGQ293o.1',
#  '28/05/24, 2:27pm - NISAMLC: join',
#  '29/05/24, 2:19pm - NISAMLC: class starts @2.30pm',
#  '29/05/24, 2:29pm - NISAMLC: https://us06web.zoom.us/j/85373550975?pwd=yo9UTFvYwPycn4CedQmbipCrb3kFVi.1',
#  '29/05/24, 2:29pm - NISAMLC: join',
#  '29/05/24, 2:34pm - NISAMLC: @919037649226 ????',
#  '29/05/24, 2:34pm - NISAMLC: @917907733950 ??//',
#  '29/05/24, 2:34pm - Rashid (DS-Codeme): On the way',
#  '29/05/24, 2:35pm - NISAMLC: offline aano?',
#  '29/05/24, 2:35pm - Rashid (DS-Codeme): Alla',
#  '29/05/24, 2:35pm - Rashid (DS-Codeme): Connection issue',
#  '29/05/24, 2:35pm - Rashid (DS-Codeme): Athaan',
#  '29/05/24, 2:35pm - NISAMLC: k',
#  '29/05/24, 3:41pm - +91 94966 64940: please let me in',
#  '29/05/24, 4:50pm - NISAMLC: video codec: https://docs.opencv.org/4.x/d0/d61/group__cudacodec.html',
#  '29/05/24, 4:51pm - NISAMLC: amal look at this :https://www.tutorialspoint.com/opencv/index.htm',
#  '30/05/24, 12:38pm - NISAMLC: class starts @2.30: We will discuss all image processing related topics in a brief today, make sure to attend all (we will discuss all topics we went through till regarding CV )@919778218181 , @919946189970 make sure to attend',
#  '30/05/24, 2:27pm - NISAMLC: https://us06web.zoom.us/j/83628900360?pwd=4dpav7Gb3MahIZyHBeeHSY3ktU1pu6.1',
#  '30/05/24, 5:55pm - NISAMLC: You deleted this message',
#  '30/05/24, 5:55pm - NISAMLC: <Media omitted>',
#  '30/05/24, 5:55pm - NISAMLC: <Media omitted>',
#  '30/05/24, 5:55pm - NISAMLC: <Media omitted>',
#  '31/05/24, 2:31pm - NISAMLC: https://us06web.zoom.us/j/88443754683?pwd=TSaHXIo2KIsgMhkPeVZkEuaDFd8l2W.1',
#  '31/05/24, 2:31pm - NISAMLC: JOIN',
#  '02/06/24, 10:03pm - Aysha Hamna(CodeMe): Dear Students,',
#  '',
#  '10:00 am - Karthika',
#  '10:30 am - Jishnu',
#  '11:00 am - Rashid',
#  '11:30 am - Amal Roshan',
#  '02:30 pm - Binjus',
#  '03:00 pm - Aysha',
#  '03:30 pm - Asna',
#  '',
#  'Please check your time slots for the interview tomorrow.',
#  'Hope everyone are ready for your first review plan interview.',
#  'Everyone should be there on time.',
#  'There will be theoretical and practical questions, so be prepared.',
#  '',
#  '*All the best*',
#  '',
#  'Attendance for the review plan is mandatory.',
#  '03/06/24, 11:23am - Aysha Hamna(CodeMe): Reminder:',
#  '',
#  'Interview session started.',
#  'Expecting everyone to be on time',
#  "04/06/24, 11:36am - Aysha Hamna(CodeMe): Since the review plan interviews are going on , you won't have data science session today",
#  '04/06/24, 11:36am - Rashid (DS-Codeme): Ok',
#  '04/06/24, 9:44pm - Aysha Hamna(CodeMe): Reminder:',
#  '',
#  "You will have same time schedule for tomorrow's interview.",
#  '',
#  'Be prepared and practice well.',
#  '',
#  'Bring your CV.',
#  '',
#  'Topics are listed in the review plan document.',
#  '06/06/24, 9:30am - NISAMLC: Since I do have a meeting scheduled today CV classes are postponed to Saturday (from morning to evening)',
#  "06/06/24, 9:31am - NISAMLC: And those who are attending today's Aptitude test , this is a rare chance any interview will not complete without aptitude and mental ability so make sure to attend",
#  '07/06/24, 10:18am - NISAMLC: class starts @2.30 on : CV:Drawing shapes on images: Basic to Advanced',
#  '07/06/24, 2:26pm - NISAMLC: https://us06web.zoom.us/j/82621147975?pwd=Wcj697cm8G6LqtjDXzNr6PDpsaY7KI.1',
#  '07/06/24, 2:26pm - NISAMLC: join',
#  '07/06/24, 4:50pm - NISAMLC: CV class : tomorrow(Saturday) morning 10.00 AM TO 1.00 PM class',
#  '08/06/24, 9:56am - NISAMLC: https://us06web.zoom.us/j/84505621870?pwd=s8h800UVxjg6EybmgL8AyplvEm4Qst.1',
#  '08/06/24, 9:56am - NISAMLC: join',
#  '08/06/24, 11:03am - NISAMLC: https://us04web.zoom.us/j/5019495850?pwd=dENBUnN6a043bzlHcGpJY3Ara2lWZz09',
#  '08/06/24, 11:03am - NISAMLC: rejoin',
#  '08/06/24, 11:45am - +91 79077 33950: https://us04web.zoom.us/j/74450854485?pwd=E1z5A4tcHiQkI3Tui6iNrKrMl0LxqE.1',
#  '08/06/24, 12:50pm - NISAMLC: <Media omitted>',
#  '08/06/24, 12:50pm - NISAMLC: <Media omitted>',
#  '08/06/24, 12:50pm - NISAMLC: <Media omitted>',
#  '09/06/24, 6:49pm - Aysha Hamna(CodeMe): Reminder:',
#  '',
#  'Review plan third section interview is scheduled tomorrow.',
#  '',
#  'Topic : Machine Learning.',
#  '',
#  'Bring your CV',
#  '',
#  'All the best',
#  '09/06/24, 6:50pm - Aysha Hamna(CodeMe): Dear Students,',
#  '',
#  'There is a small change in time slots.',
#  '',
#  '10:00 am - Jishnu',
#  '10:30 am - Karthika',
#  '11:00 am - Rashid',
#  '11:30 am - Amal Roshan',
#  '02:30 pm - Binjus',
#  '03:00 pm - Aysha',
#  '03:30 pm - Asna',
#  '10/06/24, 12:16pm - NISAMLC: everyone must attend github class @2.30 everyone can attend those can attend offline be offline and others can join through online *Dont Miss It*',
#  '10/06/24, 2:46pm - +91 94966 64940: Link?',
#  '10/06/24, 2:52pm - NISAMLC: https://meet.google.com/wfx-cszi-iyb',
#  "11/06/24, 10:35am - NISAMLC: How many of you are attending today's GIT class?",
#  '11/06/24, 10:35am - NISAMLC: and how many attended yesterday?',
#  "11/06/24, 10:36am - Rashid (DS-Codeme): I have attended yesterday's class",
#  '11/06/24, 10:40am - NISAMLC: what about today?',
#  '11/06/24, 10:40am - +91 94966 64940: Me',
#  '11/06/24, 10:40am - Rashid (DS-Codeme): Will attend through online',
#  '11/06/24, 10:41am - NISAMLC: okay',
#  '11/06/24, 10:41am - NISAMLC: dont miss it guys',
#  '11/06/24, 10:41am - NISAMLC: you will not get its recordings',
#  '11/06/24, 10:41am - NISAMLC: very much crucial for  team work <This message was edited>',
#  '11/06/24, 10:46am - Amal (DS-Codeme): Yesterday attended.... Today through online',
#  '11/06/24, 10:50am - NISAMLC: Okay',
#  '11/06/24, 11:09am - jisshnu.___ (DS-Codeme): Me',
#  '11/06/24, 2:41pm - NISAMLC: https://meet.google.com/wfx-cszi-iyb',
#  '12/06/24, 11:53am - NISAMLC: class starts @2.30 pm',
#  '12/06/24, 11:55am - Rashid (DS-Codeme): git or cv',
#  '12/06/24, 11:55am - NISAMLC: cv',
#  '12/06/24, 11:55am - Rashid (DS-Codeme): ok',
#  '12/06/24, 2:38pm - NISAMLC: https://meet.google.com/tfq-dyhi-aoa',
#  '12/06/24, 3:39pm - Asif (CodeMe): This message was deleted',
#  '12/06/24, 4:55pm - Asif (CodeMe): This message was deleted',
#  '12/06/24, 4:58pm - Asif (CodeMe): Dear Students,',
#  '',
#  'We have scheduled a mandatory three-day Git class on the ,19th,  20th  and 21st of this month. Attendance for all three days is compulsory. There will not be an opportunity to repeat these sessions.',
#  '',
#  'Class Details:Dates:  19th, 20th,21st',
#  '',
#  'Time: 2:30 PM - 4:30 PM',
#  '',
#  'Your presence is required. No exceptions will be made.',
#  '13/06/24, 9:41am - Aysha Hamna(CodeMe): Anyone attending interview today?',
#  '13/06/24, 2:08pm - NISAMLC: class @2.30',
#  '13/06/24, 2:26pm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '13/06/24, 2:26pm - NISAMLC: join',
#  '14/06/24, 1:30pm - Aysha Hamna(CodeMe): <Media omitted>',
#  '14/06/24, 3:05pm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '14/06/24, 3:05pm - NISAMLC: join',
#  '14/06/24, 5:39pm - NISAMLC: <Media omitted>',
#  '15/06/24, 2:29pm - NISAMLC: You deleted this message',
#  '15/06/24, 2:30pm - NISAMLC: Practice Computer Vision Tasks Which we are discussed by taking different images and push it inside Git',
#  '19/06/24, 10:30am - NISAMLC: Today we do have git classes @2.30 from Dilshad sir *from scratch* how many of are going to attend?? let me know if you are not attending i will go with CV class (There are many things which we are not disccused in our classroom in git so it will be really helpfull) , i want to know before 1.00PM',
#  '19/06/24, 10:47am - Rashid (DS-Codeme): I will attend',
#  '19/06/24, 10:52am - NISAMLC: okay',
#  '19/06/24, 10:52am - NISAMLC: anyone else?',
#  '19/06/24, 10:52am - NISAMLC: he will explain from scratch',
#  '19/06/24, 10:53am - +91 94966 64940: ✋🏻',
#  '19/06/24, 11:29am - NISAMLC: okay',
#  '19/06/24, 11:29am - NISAMLC: try to do practicals',
#  '19/06/24, 11:29am - NISAMLC: then only you will get know the mistakes and ask doubts he will rectify it',
#  '19/06/24, 1:25pm - +91 79077 33950: will attend',
#  '19/06/24, 2:29pm - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): ✋🏻',
#  '19/06/24, 2:32pm - jisshnu.___ (DS-Codeme): ✋🏼',
#  '19/06/24, 2:55pm - +91 94966 64940: Sir link?',
#  '19/06/24, 3:24pm - NISAMLC: To join the meeting on Google Meet, click this link: ',
#  'https://meet.google.com/wfx-cszi-iyb ',
#  ' ',
#  'Or open Meet and enter this code: wfx-cszi-iyb',
#  '19/06/24, 3:24pm - NISAMLC: become late',
#  '19/06/24, 3:24pm - NISAMLC: just started',
#  '19/06/24, 3:24pm - NISAMLC: join now',
#  '19/06/24, 3:25pm - NISAMLC: join immediately',
#  '19/06/24, 3:25pm - NISAMLC: otherwise you cant follow',
#  '19/06/24, 10:09pm - Aysha Hamna(CodeMe): 🔴Review plan update :',
#  'Since DL portions are not completed yet, review plan is paused.',
#  '',
#  'Will update about review plan in coming week',
#  '20/06/24, 2:42pm - NISAMLC: join in the same link',
#  '21/06/24, 2:41pm - Aysha Hamna(CodeMe): To join the meeting on Google Meet, click this link: ',
#  'https://meet.google.com/wfx-cszi-iyb ',
#  ' ',
#  'Or open Meet and enter this code: wfx-cszi-iyb',
#  '21/06/24, 2:41pm - Aysha Hamna(CodeMe): Join in this link for git session',
#  '24/06/24, 2:36pm - NISAMLC: You guys can now access the entire course recordings go through it accordingly (you will be notified in your mail)',
#  '24/06/24, 2:36pm - NISAMLC: let me know if you dont',
#  '24/06/24, 2:37pm - +91 94966 64940: Notification already sent?',
#  '24/06/24, 2:38pm - NISAMLC: ya',
#  '24/06/24, 2:39pm - NISAMLC: @919946189970  your mail id?',
#  '24/06/24, 2:39pm - jisshnu.___ (DS-Codeme): jishnumss7@gmail.com',
#  '24/06/24, 2:39pm - NISAMLC: k',
#  '24/06/24, 2:39pm - +91 94966 64940: Received . Thanks',
#  '24/06/24, 2:41pm - jisshnu.___ (DS-Codeme): Recieved',
#  '24/06/24, 2:42pm - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): Received',
#  '24/06/24, 2:54pm - +91 86181 86237: Received',
#  '24/06/24, 3:44pm - Amal (DS-Codeme): Received',
#  '24/06/24, 6:35pm - Asna. (DS-Codeme): Not received',
#  '25/06/24, 9:33am - NISAMLC: Go through the CNN section and we will continue our discussion from tomorrow onwards',
#  '26/06/24, 11:03am - NISAMLC: Class @2.30 PM',
#  '26/06/24, 2:25pm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '26/06/24, 2:25pm - NISAMLC: join <This message was edited>',
#  '26/06/24, 4:07pm - NISAMLC: <Media omitted>',
#  '26/06/24, 4:07pm - NISAMLC: <Media omitted>',
#  '26/06/24, 4:07pm - NISAMLC: <Media omitted>',
#  '26/06/24, 4:07pm - NISAMLC: <Media omitted>',
#  '26/06/24, 4:07pm - NISAMLC: <Media omitted>',
#  '26/06/24, 4:07pm - NISAMLC: Workout try it on different images',
#  '27/06/24, 2:19pm - NISAMLC: class @2.30',
#  '27/06/24, 2:32pm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '27/06/24, 2:34pm - NISAMLC: join',
#  '27/06/24, 5:21pm - NISAMLC: <Media omitted>',
#  '27/06/24, 5:21pm - NISAMLC: Object Detection',
#  '27/06/24, 5:21pm - NISAMLC: Resources',
#  '27/06/24, 5:21pm - NISAMLC: try out',
#  '27/06/24, 5:22pm - NISAMLC: and implement other image processing techniques',
#  '30/06/24, 9:05pm - NISAMLC: We will start our NLP (Natural Language Processing) session from tomorrow (6/1/2024) 2.30PM onwards',
#  'New Session  dont miss any, definitely be an addition to your profile',
#  '* NLP Fundamentals',
#  '30/06/24, 9:20pm - Rashid (DS-Codeme): Okay',
#  '01/07/24, 2:31pm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '01/07/24, 2:31pm - NISAMLC: join',
#  '01/07/24, 2:36pm - +91 94966 64940: Please admit',
#  '01/07/24, 2:41pm - +91 94966 64940: @918593099647',
#  '01/07/24, 4:17pm - NISAMLC: <Media omitted>',
#  "02/07/24, 11:15am - Asif (CodeMe): There won't be any session this afternoon",
#  '02/07/24, 11:15am - Rashid (DS-Codeme): Ok',
#  "03/07/24, 8:02am - Asif (CodeMe): There won't be any session today",
#  '03/07/24, 8:03am - Asif (CodeMe): Complete your regex assignment and share the GitHub link',
#  "10/07/24, 1:19pm - Aysha Hamna(CodeMe): We'll resume your NLP sessions from tomorrow ",
#  'Time: 2:30 pm',
#  '11/07/24, 2:56pm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '11/07/24, 2:56pm - NISAMLC: joinn',
#  '12/07/24, 2:25pm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '12/07/24, 2:25pm - NISAMLC: join',
#  '12/07/24, 2:35pm - NISAMLC: anyone joining?',
#  '12/07/24, 2:36pm - Rashid (DS-Codeme): Yes, sir oru 5 mins',
#  '12/07/24, 2:37pm - NISAMLC: k',
#  '15/07/24, 2:24pm - NISAMLC: class starts @2.30pm',
#  '15/07/24, 2:33pm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '15/07/24, 2:35pm - NISAMLC: @919037649226 are you join??',
#  '15/07/24, 2:35pm - Rashid (DS-Codeme): yes',
#  '15/07/24, 5:26pm - Rashid (DS-Codeme): sir notebook share cheyuo',
#  '15/07/24, 5:53pm - NISAMLC: <Media omitted>',
#  '16/07/24, 2:21pm - NISAMLC: class starts @2.30pm',
#  '16/07/24, 2:33pm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '16/07/24, 2:33pm - NISAMLC: join',
#  '16/07/24, 2:39pm - NISAMLC: any more people joining? <This message was edited>',
#  '16/07/24, 2:42pm - NISAMLC: will wait until 2.45',
#  '16/07/24, 2:45pm - Rashid (DS-Codeme): Sir',
#  '16/07/24, 2:45pm - Rashid (DS-Codeme): Njn ind',
#  '16/07/24, 2:48pm - Rashid (DS-Codeme): let me in',
#  '16/07/24, 2:50pm - Rashid (DS-Codeme): hi',
#  '18/07/24, 2:12pm - NISAMLC: class starts at 2.30pm',
#  '18/07/24, 2:33pm - Rashid (DS-Codeme): Link',
#  '18/07/24, 2:34pm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '18/07/24, 4:02pm - NISAMLC: <Media omitted>',
#  '18/07/24, 4:05pm - NISAMLC: Monday onwards you will get Class on Django for MLOPS your last session',
#  '19/07/24, 2:13pm - NISAMLC: class starts @2.30',
#  '19/07/24, 2:32pm - NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '19/07/24, 2:32pm - NISAMLC: join',
#  '19/07/24, 3:43pm - NISAMLC: <Media omitted>',
#  '19/07/24, 3:54pm - NISAMLC: <Media omitted>',
#  '22/07/24, 9:53am - NISAMLC: we are planning to give a 30 days Project Bootcamp for this batch *30 days 30 Projects*, where we will build 30 end to end projects from various domains which we are discussed in our entire curriculum. how many of you are interested ?? i need everyone to attend the session otherwise we will drop the plan every day 2 hrs , if you are interested let me know.',
#  'we will start this session once you Django session completed <This message was edited>',
#  '22/07/24, 9:55am - Rashid (DS-Codeme): Iam interested',
#  '22/07/24, 9:55am - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): ✋🏻',
#  '22/07/24, 10:03am - Amal (DS-Codeme): ✋🏻',
#  '22/07/24, 10:05am - jisshnu.___ (DS-Codeme): 👍🏼',
#  '22/07/24, 10:10am - jisshnu.___ (DS-Codeme) added Nayana(OldBatch) J Nair',
#  '22/07/24, 10:14am - Asna. (DS-Codeme): ✋🏼',
#  '22/07/24, 10:18am - +91 86181 86237: ✋🏻',
#  '22/07/24, 11:04am - +91 94966 64940: ✋🏻',
#  "22/07/24, 2:40pm - Nayana(OldBatch) J Nair: Today's session postponed to 3.pm",
#  '22/07/24, 3:06pm - Nayana(OldBatch) J Nair: https://meet.google.com/exf-ftsp-xpg',
#  '24/07/24, 12:47pm - Asif (CodeMe): https://blogs.oracle.com/oracleuniversity/post/announcing-oci-2024-generative-ai-professional-certification-and-course',
#  '24/07/24, 1:01pm - jisshnu.___ (DS-Codeme): <Media omitted>',
#  '24/07/24, 2:28pm - Nayana(OldBatch) J Nair: join all',
#  '25/07/24, 2:30pm - Nayana(OldBatch) J Nair: https://meet.google.com/exf-ftsp-xpg',
#  '26/07/24, 2:31pm - Nayana(OldBatch) J Nair: join all',
#  '29/07/24, 3:03pm - Nayana(OldBatch) J Nair: please join',
#  '29/07/24, 5:05pm - NISAMLC: You deleted this message',
#  '29/07/24, 5:24pm - NISAMLC: 🎤Since the django session has been completed we will be starting our 30 Days Project session from  Thursday August-1 by taking projects from ML,CV,DL,RECOMMENDER ENGINES AND SO ON *let me know how many of you are in* ?',
#  '',
#  '*What i will do*',
#  '- 2 hours per day i will be discussing a project with you and i will share the resources',
#  '- Every week i will assign a project to you means 4 projects you will be completing from your side at the end of camp',
#  '*What you need to do*',
#  '- Every day i will share the discussed projects resources, you should go through the project and execute it ',
#  '- You should create a github repo for every project and share it to LinkedIn means 30 posts at the end of the camp(excluding your own projects)',
#  '- I will assign weekly projects, you should complete it within the stipulated time period and mandatory to share that in the LinkedIn',
#  '- In the case of deployed projects you should share the link to the website and share it to linkedin along with github repo',
#  "*What if the plan don't work properly*",
#  '- if someone got into the project bootcamp and fail to do the assigned task or *fail to attend the session for even one day then we will end the bootcamp for them and they will not be able to join in any coming sessions* <This message was edited>',
#  '29/07/24, 5:24pm - NISAMLC: let me know how many of you are in?',
#  '29/07/24, 5:29pm - 𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): ✋🏻',
#  '29/07/24, 5:31pm - jisshnu.___ (DS-Codeme): 👍🏼',
#  '29/07/24, 6:04pm - Amal (DS-Codeme): ✋🏻',
#  '29/07/24, 6:06pm - Rashid (DS-Codeme): Count me in',
#  '29/07/24, 6:25pm - Asna. (DS-Codeme): ✋🏼',
#  '29/07/24, 7:00pm - +91 94966 64940: ✋🏻',
#  '29/07/24, 7:39pm - +91 86181 86237: This message was deleted',
#  '29/07/24, 7:40pm - +91 86181 86237: ✋🏻',
#  '30/07/24, 3:09pm - NISAMLC: Those who attending the Camp',
#  '- Karthika',
#  '- Jishnu',
#  '- Amal',
#  '- Rashid',
#  '- Asna',
#  '- Binjus',
#  '- Ayesha',
#  '31/07/24, 4:35pm - NISAMLC: We will be starting our project session from Tomorrow onwards',
#  '',
#  '- Scheduled Time : 2.30 to 4.30 (it can vary depends on the problem)',
#  '- Be Ready on Time',
#  '01/08/24, 2:23pm - NISAMLC: *Day 1 of Project Bootcamp*',
#  '*starts at 2.30PM*',
#  'Linke to Join : https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '02/08/24, 2:30pm - NISAMLC: *Day 2 of Project Bootcamp*',
#  '*starts at 2.30PM*',
#  'Linke to Join : https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  '02/08/24, 2:35pm - Rashid (DS-Codeme): Waiting..',
#  '02/08/24, 2:36pm - NISAMLC: Who can join today and coming lectures:',
#  '- Amal',
#  '- Jishnu',
#  '- Asna',
#  '- Karthika',
#  '- Rashid',
#  '03/08/24, 2:36pm - Asif (CodeMe): https://www.pwc.in/careers/experienced-jobs/description.html?wdjobreqid=554074WD&wdcountry=IND&jobtitle=Specialist%203&wdjobsite=Global_Experienced_Careers',
#  '03/08/24, 2:37pm - Asif (CodeMe): pwc fresher opening for ds,apply asap',
#  '05/08/24, 10:22am - NISAMLC: those who are not submitted the project task will get a chance to submit their project link before 2.30pm today',
#  "Those who are not submitted will not be able to join in today's project",
#  '']

# %%
# '27/03/24, 11:18am - Aysha Hamna(CodeMe): join'
# 

'27/03/24, 11:18am - 0
    
Aysha Hamna(CodeMe): join' = 1
# Out:
#   Cell In[8], line 4
#     '27/03/24, 11:18am - 0
#     ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
# date and message in different col

pattern = r'\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}(?:am|pm)\s-\s'

all_messages = []
all_dates = []

for cleaned_data in dummy:
    # Extract dates
    dates = re.findall(pattern, cleaned_data)
    all_dates.extend(dates)
    
    # Extract messages
    messages = re.split(pattern, cleaned_data)[1:]
    
    all_messages.extend(messages)
    
print(len(all_messages))
print(len(all_dates))

# messages = re.split(pattern,dummy)[1:]
# print(len(messages))

# # ## extracting dates as well in different col

# dates = re.findall(pattern,dummy)
# print(len(dates))
# Out:
# 648
# 648

# %%
all_messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.',
#  'jisshnu.___ (DS-Codeme) created group "Data science "',
#  'jisshnu.___ (DS-Codeme) added you',
#  'jisshnu.___ (DS-Codeme) added +91 86181 86237',
#  'jisshnu.___ (DS-Codeme): try to do the project  yourself first then only refer the collab',
#  'jisshnu.___ (DS-Codeme): https://colab.research.google.com/drive/1tKXB0p6bcZ4gwTUNjp9zNpRMYxC952qj?usp=sharing',
#  'Asif (CodeMe): https://meet.google.com/xsu-gthd-hmw',
#  'Asif (CodeMe): https://colab.research.google.com/drive/1b_r9LNdmeSGUUIlFSQUteLKw07ESr5iQ?usp=sharing',
#  'Asif (CodeMe): https://colab.research.google.com/drive/1yIHdz2bMzzLvGqh1Dq02AAwyYFbnJAf-?usp=sharing',
#  'Asif (CodeMe): Refer this also while doing your project to understand how to use the sampling techniques. here i balanced the data after splitting to train and test',
#  'Asif (CodeMe): https://meet.google.com/sdk-sqzo-unn',
#  'Asif (CodeMe): https://docs.google.com/document/d/1SlzY5P0wQPr8ZsgBUc4m1mkr-fu-nlRZqBu_am2ZH2M/edit?usp=sharing',
#  'Aysha Hamna(CodeMe): https://meet.google.com/xut-tqwq-pcd',
#  'jisshnu.___ (DS-Codeme) added +91 79077 33950',
#  'Aysha Hamna(CodeMe): <Media omitted>',
#  'Aysha Hamna(CodeMe): https://colab.research.google.com/drive/1ljIcfFMyAOJpIRWrrWa-61vppqIydnRU?usp=sharing',
#  'Asif (CodeMe): Same link',
#  'Asif (CodeMe): same link',
#  'Asif (CodeMe): https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit?usp=sharing',
#  'Aysha Hamna(CodeMe): https://meet.google.com/uiv-vkou-pda',
#  'Aysha Hamna(CodeMe): <Media omitted>',
#  'Aysha Hamna(CodeMe): join using same link',
#  'Aysha Hamna(CodeMe): https://colab.research.google.com/drive/1P9fduGtId539V1MYs2ScQLPC6Ph8PrSx?usp=sharing',
#  '+91 86181 86237: Class started?',
#  'jisshnu.___ (DS-Codeme): no',
#  'Asif (CodeMe): https://meet.google.com/ind-raij-vzt',
#  'jisshnu.___ (DS-Codeme): https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit#gid=0',
#  'Aysha Hamna(CodeMe): This message was deleted',
#  '+91 94966 64940: It’s showing no such meeting',
#  'Aysha Hamna(CodeMe): https://meet.google.com/zpy-qjbm-sbj',
#  'Asif (CodeMe): <Media omitted>',
#  'Aysha Hamna(CodeMe): please join',
#  'Amal (DS-Codeme): This message was deleted',
#  'Rashid (DS-Codeme): Waiting for this message',
#  'jisshnu.___ (DS-Codeme): <Media omitted>',
#  'Asif (CodeMe): SAME LINK',
#  'jisshnu.___ (DS-Codeme): <Media omitted>',
#  'Asif (CodeMe): <Media omitted>',
#  'Asif (CodeMe): <Media omitted>',
#  'Asif (CodeMe): <Media omitted>',
#  'Asif (CodeMe): <Media omitted>',
#  'Asif (CodeMe): same link',
#  'Aysha Hamna(CodeMe): https://meet.google.com/ewj-ckus-jmv',
#  'Aysha Hamna(CodeMe): https://hamoyehq.medium.com/hamoye-data-science-internship-fall-2024-call-for-application-79488110376d',
#  'Aysha Hamna(CodeMe): https://docs.google.com/forms/d/e/1FAIpQLSe9Sr9L3H7oObSSZSB-qndQYNal1OGGcyTBfOppZLyuOKWPRg/viewform',
#  'jisshnu.___ (DS-Codeme): <Media omitted>',
#  '+91 94966 64940: Problem statement 🌚',
#  'jisshnu.___ (DS-Codeme): EDA + Classification + Power BI',
#  'jisshnu.___ (DS-Codeme): = certificate',
#  '+91 94966 64940: This message was deleted',
#  'NISAMLC: <Media omitted>',
#  'Asif (CodeMe): Same link',
#  'Asif (CodeMe): Some network issue',
#  '+91 86181 86237: This message was deleted',
#  'Asif (CodeMe): No join again',
#  'Asif (CodeMe): same link join',
#  'Asif (CodeMe): Join the same link',
#  '+91 94966 64940: Please let me in',
#  "Aysha Hamna(CodeMe): Tomorrow's machine learning class will start at 2 15 pm",
#  'jisshnu.___ (DS-Codeme): This message was deleted',
#  'Asif (CodeMe): https://meet.google.com/ind-raij-vzt',
#  'Asif (CodeMe): This message was deleted',
#  'Asif (CodeMe): Join the link',
#  '+91 94966 64940: CREATE TABLE event (',
#  'Asif (CodeMe): join the same link',
#  'Amal (DS-Codeme): same link',
#  'Asif (CodeMe): ds join the same link',
#  'jisshnu.___ (DS-Codeme): same',
#  'Aysha Hamna(CodeMe): https://meet.google.com/ewj-ckus-jmv',
#  'Aysha Hamna(CodeMe): SAME LINK',
#  'Aysha Hamna(CodeMe): <Media omitted>',
#  'Rashid (DS-Codeme): same link',
#  'Rashid (DS-Codeme): https://meet.google.com/ind-raij-vzt',
#  '+91 86181 86237: Let me into the class.',
#  'Rashid (DS-Codeme): network issue',
#  '+91 86181 86237: Ok',
#  'Rashid (DS-Codeme): wait couple of minutes',
#  'jisshnu.___ (DS-Codeme): This message was deleted',
#  'Asif (CodeMe): Join the same link..',
#  'Asif (CodeMe): .',
#  'jisshnu.___ (DS-Codeme): in akkettilla',
#  'Asif (CodeMe): Network issue und',
#  'Asif (CodeMe): Wait',
#  'jisshnu.___ (DS-Codeme): ok',
#  'Asif (CodeMe): Join',
#  '+91 94966 64940: Class ille',
#  '+91 94966 64940: ??',
#  'Asif (CodeMe): https://www.kdnuggets.com/2020/06/naive-bayes-algorithm-everything.html',
#  'Asif (CodeMe): \U0001f6dc WiFi Passwords\U0001f6dc',
#  'Asif (CodeMe): join the same link',
#  'Aysha Hamna(CodeMe): ML session will start at 2:15 pm',
#  'Asif (CodeMe): join the same link',
#  'Asif (CodeMe): Same link',
#  'Asif (CodeMe): ML Same link',
#  'Asif (CodeMe): same limk',
#  'jisshnu.___ (DS-Codeme): https://colab.research.google.com/drive/108YjV5uDkumB8aw5RMrie3rLCeyWcNk4?usp=sharing',
#  'Amal (DS-Codeme): Same link 9:35',
#  'Asif (CodeMe): <Media omitted>',
#  'Asif (CodeMe): Mandatory SQL Assessment',
#  'Asif (CodeMe): This message was deleted',
#  'Asif (CodeMe): Tomorrow Dax class will be from 11.15- 1.15 PM',
#  'Asif (CodeMe): ML Class will be from 9 AM To 11 Am',
#  'Aysha Hamna(CodeMe): https://meet.google.com/uew-zqmr-sth',
#  'Aysha Hamna(CodeMe): <Media omitted>',
#  'Amal (DS-Codeme): same link',
#  "Asif (CodeMe): I haven't received the SQL assessment @918618186237 ,send it ASAP",
#  '+91 86181 86237: Where I I have to send it in  group',
#  'Asif (CodeMe): Send here',
#  '+91 86181 86237: This message was deleted',
#  'Asif (CodeMe): This message was deleted',
#  'Asif (CodeMe): Power bi join the same link <This message was edited>',
#  'Asif (CodeMe): <Media omitted>',
#  'Asif (CodeMe): Power bi same link',
#  'jisshnu.___ (DS-Codeme): screen poi',
#  'Asif (CodeMe): <Media omitted>',
#  'Aysha Hamna(CodeMe): https://meet.google.com/uew-zqmr-sth',
#  'Aysha Hamna(CodeMe): Join please',
#  'Asif (CodeMe): Monday ',
#  'jisshnu.___ (DS-Codeme): Afternoon',
#  'jisshnu.___ (DS-Codeme): Ille',
#  'Asif (CodeMe): Class kaanum afternoon for ds',
#  'Aysha Hamna(CodeMe): join',
#  'Rashid (DS-Codeme): dax same link',
#  'Rashid (DS-Codeme): https://meet.google.com/ind-raij-vzt',
#  'Rashid (DS-Codeme): <Media omitted>',
#  'Aysha Hamna(CodeMe): https://www.kaggle.com/datasets/brijbhushannanda1979/bigmart-sales-data',
#  'Aysha Hamna(CodeMe): Download dataset from this link and perform EDA',
#  'Aysha Hamna(CodeMe): and then apply any regression model',
#  'Aysha Hamna(CodeMe): Complete this task today',
#  "Aysha Hamna(CodeMe): We postponed today's afternoon session",
#  'Asif (CodeMe): Power bi same link',
#  'Asif (CodeMe): <Media omitted>',
#  'Asif (CodeMe): <Media omitted>',
#  '+91 94966 64940: ML class',
#  'jisshnu.___ (DS-Codeme): 👍🏽',
#  'Aysha Hamna(CodeMe): join',
#  'Aysha Hamna(CodeMe): <Media omitted>',
#  'Aysha Hamna(CodeMe): <Media omitted>',
#  'Aysha Hamna(CodeMe): <Media omitted>',
#  'Aysha Hamna(CodeMe): https://www.kaggle.com/competitions/titanic/data',
#  'Aysha Hamna(CodeMe): join',
#  'Asif (CodeMe): PCA Tomorrow 11.30-1 and 2.15 -3.45',
#  'Asif (CodeMe): 4th floor aan class 11.30',
#  'Asif (CodeMe): https://meet.google.com/svp-wgoq-ajb',
#  'Asif (CodeMe): join',
#  'Amal (DS-Codeme): 2.30 join',
#  'Amal (DS-Codeme): https://www.microsoft.com/en-us/cloudskillschallenge/ai/registration/2024?ocid=aisc23_CSC_skillsforaiblog_cnl#choose-your-challenge',
#  'NISAMLC: Tomorrow 2.00PM:Lecture On Recommendation Engines, build your first Recommender <This message was edited>',
#  'NISAMLC: How many of you are attending Offline??',
#  'jisshnu.___ (DS-Codeme): Im not',
#  '+91 94966 64940: 🤚🏻',
#  'Amal (DS-Codeme): ✌🏻',
#  'NISAMLC: Conference Hall <This message was edited>',
#  '+91 86181 86237: No online class?',
#  'Rashid (DS-Codeme): https://meet.google.com/yyp-ybak-jqd',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: You deleted this message',
#  'Amal (DS-Codeme): https://meet.google.com/jiy-cjvd-ums',
#  'NISAMLC: join in this',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: https://meet.google.com/wpa-gyyd-kte',
#  'NISAMLC: class starts @2.30 pm today <This message was edited>',
#  'NISAMLC: SAME LINK',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: https://github.com/JovianHQ/opendatasets/blob/master/data/countries-languages-spoken/countries-languages.csv <This message was edited>',
#  'NISAMLC: Create a Country Recommender based on the language spoken',
#  'NISAMLC: https://www.kaggle.com/datasets/dylanjcastillo/7k-books-with-metadata',
#  'NISAMLC: Build a Book Recommender based on the description about the book',
#  '+91 86181 86237: This message was deleted',
#  'jisshnu.___ (DS-Codeme): ok',
#  'NISAMLC: No class today, try to explore more recommendation systems using various datasets',
#  'Rashid (DS-Codeme): Okay',
#  'jisshnu.___ (DS-Codeme): Okay',
#  'Rashid (DS-Codeme): https://www.youtube.com/live/wB7m2YMqVVY?si=IJq7IixEgva7Tu8t',
#  'Rashid (DS-Codeme): live class of hamoye',
#  'NISAMLC: Anyone offline??',
#  'NISAMLC: https://us05web.zoom.us/j/89944631210?pwd=Vi6hcSNnsdHS5bQgh5r44jeHLt9Hgo.1',
#  'NISAMLC: join',
#  'NISAMLC: https://meet.google.com/eir-sawr-tui',
#  'NISAMLC: rejoin',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: https://meet.google.com/xuo-ahea-zvc',
#  'NISAMLC: join',
#  'NISAMLC: *Create a recommendation system which recommends books or documents* Data:scrape data from websites like goodreads and scribd or any other website, do it and submit it before coming monday 9..00AM try <This message was edited>',
#  'NISAMLC: Tomorrow onwards There will be two sessions are going on for *Data Science* students',
#  "+91 86181 86237: today's class is there?",
#  'Aysha Hamna(CodeMe): This message was deleted',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/84356593130?pwd=tE40wZMVVhZahfQfpMlWmaiuQMdVEh.1',
#  '+91 86181 86237: ML class?',
#  'Amal (DS-Codeme): Join',
#  'Amal (DS-Codeme): This message was deleted',
#  'Amal (DS-Codeme): This message was deleted',
#  'NISAMLC: join in this link',
#  'NISAMLC: https://us05web.zoom.us/j/82662632874?pwd=lgeKSnCVezGajLEX1IeAx3TBlt6Xd8.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83954675823?pwd=hZBXtKvZBMKaci3f79IzVd4Munacw5.1',
#  'jisshnu.___ (DS-Codeme): rejoin',
#  'jisshnu.___ (DS-Codeme): 2.30',
#  'jisshnu.___ (DS-Codeme): next class',
#  'NISAMLC: join immediately',
#  'NISAMLC: link  comes',
#  'NISAMLC: https://us05web.zoom.us/j/89882762836?pwd=f4OJJDwtrLYksEeOXGEua1VsSK1gS0.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83124834127?pwd=CZnC3e1LCu4BZKbtXpoR8vdUF0bY8W.1',
#  'jisshnu.___ (DS-Codeme): rejoin',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/84698759689?pwd=jc3uaX38A8XKT9i8aGEyEeV4FGOhbD.1',
#  'NISAMLC: last join',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87597044212?pwd=eYhexXtU8wlpMxKP894sKaZ9ESCEFv.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/81088179003?pwd=4cy88JdC9vDOk311hla6REoyV4ZHw5.1',
#  'jisshnu.___ (DS-Codeme): join',
#  'NISAMLC: https://us05web.zoom.us/j/85900123290?pwd=dHszQjo1DUVTUUK0eulZhlDGN0ePKE.1',
#  'NISAMLC: join',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/85320192983?pwd=mbloGXvXoW4fR5CrQ7tkevcaB2X2ZM.1',
#  'jisshnu.___ (DS-Codeme): rejoin',
#  'NISAMLC: join immediately',
#  'NISAMLC: https://us05web.zoom.us/j/86955036516?pwd=bKixQEfWmQTdTbHwDigNVcsZSmkHx4.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/88418826144?pwd=AGMp0uqMGf2gF6uSZwgJ1HqTyAjXTi.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83068961004?pwd=fwxUEnK21rZ1M2Qn46HBArPHwUiU2g.1',
#  'NISAMLC: https://www.kaggle.com/datasets/zygmunt/goodbooks-10k',
#  'NISAMLC: https://us05web.zoom.us/j/82196771153?pwd=5SBVgnTDk5F6vIjFduX0TzsL5VeCFa.1',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/81310056571?pwd=9bpbaQ6goaGabCrJPHmoKHR7oFPKu5.1',
#  'NISAMLC: join immediately',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/84126238187?pwd=WPsF79MUYkPRheBHE3vTRqdxLUqyml.1',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/88298798338?pwd=OXqo2o2NfHu3Ty2Y5hkua2Ut3KXCP0.1',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/84745853077?pwd=xmT9cP4e5uSFiaUD6dcLrnkabbRMfj.1',
#  'NISAMLC: JOIN',
#  'NISAMLC: https://us05web.zoom.us/j/85029807729?pwd=R2FC3g5JSz2Cmk2327RnGCnwrgbG1X.1',
#  '+91 86181 86237: Please add in',
#  '𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): This message was deleted',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/84998061454?pwd=Hf7VPgXs9s10R6kaWHp9fSvP2SChXG.1',
#  'NISAMLC: <Media omitted>',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/88476935533?pwd=NGwH2oEMx62JoUOu6XIcj7GgiLQiUh.1',
#  'NISAMLC: https://www.kaggle.com/datasets/prajitdatta/movielens-100k-dataset/data',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83223361006?pwd=nMcKtUZMKxPJcn2dbwfR4Y4nwFrLUW.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/82183401601?pwd=B90w2RLezed2fSwwFytoVvbjDG3R1R.1',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87644185104?pwd=UoZyDi9uVqE4COBvWTNKdXH6poOALK.1',
#  'NISAMLC: <Media omitted>',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/83719435591?pwd=OAOinOmRv6owb4ur0XT7Xc4ezDCEhj.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87168841298?pwd=6pkmUIjKiEwwVYMpLNv844bEVoGyC3.1',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: join at 2.30 pm',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/86285461568?pwd=m4IKlxw6ASWObFncC4hONqzuG7JJV9.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/82808190042?pwd=0NVFr47d2PDPGOC1ONwDGNvaTiep8q.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/85777199753?pwd=lPVl2Yd5x1iJXohgGXhRdE0fbWH4rv.1',
#  '𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): https://visualstudio.microsoft.com/visual-cpp-build-tools/',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: JOIN',
#  '+91 94966 64940: Link?',
#  'NISAMLC: https://us05web.zoom.us/j/84172735576?pwd=p9JDPvN1splta73xe0e0cJEljAxU14.1',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/86837283209?pwd=BiZRMT5mflOnTH7qv9PkvLXpKekvja.1',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/87894573653?pwd=dalYPnEGwRnvhYF9wXb5tXmMWhaZX6.1',
#  'NISAMLC: https://us05web.zoom.us/j/89958400034?pwd=pB3kaxEXbSBonzej9ZjYhnOdDycChI.1',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/81104718108?pwd=QZabNNMb5lDbC8ddg3lwXjTrRjb2nG.1',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: *market basket analysis*',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: join',
#  'NISAMLC: https://us05web.zoom.us/j/88244453101?pwd=FdH0PcnOXMSjsT3A0IoaQShXNKbsa7.1',
#  '+91 86181 86237: Please add in',
#  'NISAMLC: https://us04web.zoom.us/j/72173791910?pwd=bADdLHM7aJFqaHJxatinEs1GK6Fm7N.1',
#  'NISAMLC: join',
#  'Amal (DS-Codeme): https://sampleportfolio-a7brzwhi85rmvtef4wngqj.streamlit.app/',
#  'NISAMLC: let me know if you have any doubts',
#  'NISAMLC: join',
#  'NISAMLC: https://meet.google.com/hnf-wehd-ypx',
#  'NISAMLC: Those who submitted :',
#  'NISAMLC: *JOIN AT 2.30: Time Series : ACF AND PACF MODELS FOR TIME SERIES FORASTING*',
#  'NISAMLC: join',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/88538105805?pwd=ZSYtpaIb5n02IwfADmkStah47tWKqU.1',
#  'Asna. (DS-Codeme): https://deploy-asnafidha.streamlit.app',
#  'NISAMLC: Those who submitted :',
#  'jisshnu.___ (DS-Codeme): Sorry',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/81270550054?pwd=jDnkE79Y8JliuNVoPkuHfKE0oLexcG.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/84088354300?pwd=DI2TLClARzPcf4dRnppAt8ajLO0g0v.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/85018623759?pwd=viFBEMe7js12WkpzvnsNHG2pawwhjY.1',
#  'NISAMLC: join',
#  'NISAMLC: https://us04web.zoom.us/j/79134534643?pwd=n6ka0KpC5XbqUF1YBiVDfGJLBp0gI7.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/87430068127?pwd=bEX00IJNqEAzL9YvMhVEdtahO84GbN.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/86927643942?pwd=UNWBUduc0ahzwvaZbweOP4QIBxPtrC.1',
#  'NISAMLC: join',
#  'NISAMLC: https://us05web.zoom.us/j/86189409946?pwd=jKxbPOLxwZKt3G3FLpoaY1dk3MMp7I.1',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: Perform the same > AR model on Female Birth Data',
#  'NISAMLC: 3.35 pm',
#  'NISAMLC: https://us04web.zoom.us/j/76691224273?pwd=bby3tlcIi3rHzVyg4jYSBjd2cntbtq.1',
#  'NISAMLC: join',
#  'NISAMLC: Perform the same on the shampoo dataset',
#  'jisshnu.___ (DS-Codeme): Ok',
#  '+91 94966 64940: Please share the final notebook',
#  'NISAMLC: k',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: modify the days of prediction',
#  'NISAMLC: like if you want to predict for the last 15 days or 30 days and so on',
#  'NISAMLC: *Download any Stock Price from yahoofinance and perform AutoRegression on top of it and findout the predicted values: measure the accuracy and evaluate it by creating plots and metrics* submit before monday :This is your first main time series task',
#  'NISAMLC: @919946189970',
#  'NISAMLC: https://www.kaggle.com/datasets/niketchauhan/covid-19-time-series-data',
#  'NISAMLC: Link to Covid 19 dataset',
#  'NISAMLC: choose one country from this data',
#  'NISAMLC: and perform AutoRegression in order to find the covid cases',
#  'NISAMLC: try different countries and compare results',
#  'NISAMLC: submit it before monday',
#  "Aysha Hamna(CodeMe): Tomorrow's Data Science session is scheduled at 2:30 pm",
#  'jisshnu.___ (DS-Codeme): Ok',
#  'Aysha Hamna(CodeMe): How many of u are attending online?',
#  'jisshnu.___ (DS-Codeme): ✋🏼',
#  'Asna. (DS-Codeme): 🤚🏽',
#  '𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): 🤚🏻',
#  '+91 86181 86237: 🤚',
#  'Aysha Hamna(CodeMe): For those in attendance offline, the session will take place in the last classroom.',
#  'Aysha Hamna(CodeMe): https://us05web.zoom.us/j/87110841572?pwd=OWJbPWbvehs3oWoB949WmyAFXXQwMB.1',
#  'Aysha Hamna(CodeMe): please join',
#  'jisshnu.___ (DS-Codeme): Invalid meeting id',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/84426665904?pwd=eW10ScuhCCcu6diyauNYhTVsWoM9LB.1',
#  'Aysha Hamna(CodeMe): https://atlas.mitre.org/matrices/ATLAS',
#  'Aysha Hamna(CodeMe): https://incidentdatabase.ai/',
#  'Aysha Hamna(CodeMe): https://us05web.zoom.us/j/86732036320?pwd=yaIPNxa9hp9B6H5j9Ai3ptzuqqSWmu.1',
#  'Asif (CodeMe): https://meet.google.com/vrs-wvoh-zng',
#  'Asif (CodeMe): join',
#  'Asif (CodeMe): <Media omitted>',
#  'NISAMLC: join',
#  '+91 94966 64940: Link?',
#  'NISAMLC: https://us05web.zoom.us/j/84146894791?pwd=0FGmCXYSFl4GRMAUUQxPIJnr0y189w.1',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/85738513589?pwd=PzjFyd46iBkdv6jWYqDb4hKhaLaBWb.1',
#  'NISAMLC: https://us05web.zoom.us/j/86258974313?pwd=ZO778uGGRCZaZ1rXJjEE9zDaMxvhCK.1',
#  'NISAMLC: <Media omitted>',
#  'Aysha Hamna(CodeMe): https://us05web.zoom.us/j/81324776140?pwd=NqfRe3VCI7kv6hNjXNG26xsxSFBLUh.1',
#  '+91 94966 64940: Link?',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/85302314572?pwd=LQlX8uiB8lxqGwzHLCuDih5lmgj0XW.1',
#  'Aysha Hamna(CodeMe): https://www.youtube.com/watch?v=aircAruvnKk&t=784s',
#  'NISAMLC: join',
#  'NISAMLC: https://us05web.zoom.us/j/81956643317?pwd=a2Dnir1U7fq4Y1fPoLoKt4KysYsVlm.1',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/83794961231?pwd=LSLhV9pdiXCEiEHkkFmNNoW09m7PCJ.1',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: https://us05web.zoom.us/j/83432770790?pwd=15aIavmf3exCGAUn0MLQRw3ZW2B8VY.1',
#  "Aysha Hamna(CodeMe): Tomorrow's schedule",
#  'Aysha Hamna(CodeMe): anyone offline?',
#  'Amal (DS-Codeme): online 🙌🏻',
#  'Aysha Hamna(CodeMe): https://us05web.zoom.us/j/89768721231?pwd=RUHgbb3leOUDroj4M26QHtIdPloj3g.1',
#  'Rashid (DS-Codeme): link',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/81690932462?pwd=BG1xPitPTZx0ZMQ1jATFbswR3XqJuG.1',
#  'NISAMLC: join',
#  'NISAMLC: https://us05web.zoom.us/j/86546468416?pwd=vgLrHWK0l0WMw6nfgT0Mb2qzUdcyOG.1',
#  'jisshnu.___ (DS-Codeme): https://us05web.zoom.us/j/82347408592?pwd=bap6BJ5lpH0Q6qOw9rofMePqx75Ovm.1',
#  'NISAMLC: https://www.youtube.com/playlist?list=PLvcbYUQ5t0UHOLnBzl46_Q6QKtFgfMGc3',
#  '+91 94966 64940: @918593099647 innalathem innathem notebooks share ako',
#  'NISAMLC: okay',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'Aysha Hamna(CodeMe): Anyone offline',
#  'jisshnu.___ (DS-Codeme): ✋🏼',
#  'Aysha Hamna(CodeMe): ok',
#  'Aysha Hamna(CodeMe): https://meet.google.com/ihx-eeyg-mwi',
#  "Aysha Hamna(CodeMe): Tomorrow's schedule",
#  'Aysha Hamna(CodeMe): 🔴 session rescheduled to 3 pm tomorrow',
#  'Aysha Hamna(CodeMe): same link',
#  'Aysha Hamna(CodeMe): https://colab.research.google.com/drive/1klJqPJr4dvIQsX6fWjT6I4CRU4iqUEqH?usp=sharing',
#  'Aysha Hamna(CodeMe): Go through the gradient descent topics that we learned for linear models.',
#  "Aysha Hamna(CodeMe): Its necessary for tomorrow's session",
#  'Aysha Hamna(CodeMe): We have offline session tomorrow at 11 am',
#  'NISAMLC: ANYONE OFFLINE?',
#  'NISAMLC: JOIN',
#  'NISAMLC: https://us05web.zoom.us/j/87386242572?pwd=ELelyhYQxEmPNwtWba2ZLmEDF23Et9.1',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/88583487724?pwd=gey9tmKciyfuaRjqapQa9bMCPkMy3t.1',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/81380987479?pwd=G50yjRywUHypiqguW4p02RW9wqCqzN.1',
#  'NISAMLC: reamining will discuss in the next class, take a look at Logistic regression',
#  'NISAMLC: class will start soon',
#  'NISAMLC: https://us05web.zoom.us/j/84975007689?pwd=h6wFrvavIAMux0cnHnaZyPadbGeFvN.1',
#  'jisshnu.___ (DS-Codeme): Let me in',
#  'NISAMLC: @919778218181 meet',
#  'Amal (DS-Codeme): https://us05web.zoom.us/j/81890576665?pwd=c1QHxvO4aEIEXCNernGf85Yy6VVQJ1.1',
#  'NISAMLC: we can stop for todat at : Basic gradient descent , Try to unnderstand it more by incorporating the discussed concept ,and explore batch gradient descend and how it works , And *create a linear regression model by taking a real world data without using Linear Regression class from sklearn in the next class*',
#  'NISAMLC: https://us06web.zoom.us/j/82998391278?pwd=UKupeIbzYEOwemN7P4Uw5ArRaANN7k.1',
#  'NISAMLC: join',
#  'NISAMLC: ini aarenkilum join cheyyunnundo?',
#  '+91 94966 64940: Yes',
#  'NISAMLC: @917736866448 ???',
#  '𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): Yes',
#  '+91 94966 64940: Sir please let me in',
#  '+91 94966 64940: @918593099647',
#  'NISAMLC: https://us06web.zoom.us/j/85864309016?pwd=Yw5Zb7Ha739FPtz6n1rm74TCVSBpiU.1',
#  'NISAMLC: join',
#  'Rashid (DS-Codeme): Notebook',
#  '+91 94966 64940: Recording also',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: check out this tutorials from tensorflow itself, https://www.tensorflow.org/tutorials',
#  "NISAMLC: Today's class starts @2.30 PM everyone be on time :",
#  'NISAMLC: https://us06web.zoom.us/j/81668957371?pwd=YwBWdXxDTkypIwrWcfIutDfBzzWbw8.1',
#  '+91 94966 64940: B- blood kittaan indo arelm',
#  'jisshnu.___ (DS-Codeme): Positive nd',
#  'NISAMLC: join @11.00pm on : implementing a regression problem',
#  'NISAMLC: https://us06web.zoom.us/j/85790204001?pwd=aUmiRhNSlP3WI2WkMRzmzb5lfHaJAv.1',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: https://us06web.zoom.us/j/82211794464?pwd=9jODZBXpZGvJziz15TInGkFKfqh6Db.1',
#  '+91 86181 86237: Please let me in',
#  'Aysha Hamna(CodeMe): Check out this job at Sony Research India: https://www.linkedin.com/jobs/view/3917526117',
#  'NISAMLC: class starts @2.30pm',
#  'NISAMLC: https://us06web.zoom.us/j/89079927141?pwd=uAuUKsCJ3HYLV9XSdtrIfFhAM4Zlua.1',
#  'NISAMLC: join',
#  'NISAMLC: class starts @2.30pm',
#  'NISAMLC: on : End to End Deep Learning Project',
#  'NISAMLC: https://us06web.zoom.us/j/84819824369?pwd=W91jLH9SSz2dwjsfUqaJnCezd6OIxy.1',
#  'NISAMLC: join',
#  'NISAMLC: https://www.kaggle.com/datasets/gauravtopre/bank-customer-churn-dataset',
#  'NISAMLC: class starts @2.30 on CNN',
#  'NISAMLC: https://us06web.zoom.us/j/84150849582?pwd=E5eNW8ZSXcnQe7krTJ3ynobU9l8qxR.1',
#  'NISAMLC: join',
#  'Rashid (DS-Codeme): Let me in',
#  'NISAMLC: CLASS WILL START @2.30 ON TFL AND PADDING ANS STRIPE',
#  'NISAMLC: https://us06web.zoom.us/j/88676945662?pwd=qtkCSpiakGI73ENb4BuLxM3JmhIMKM.1',
#  'NISAMLC: join',
#  '+91 94966 64940: Unable to join',
#  '+91 94966 64940: Facing network issues',
#  'NISAMLC: https://us06web.zoom.us/j/84774931149?pwd=IZhaEyGogISiuWUJwcbaZWxaFs5WK8.1',
#  'NISAMLC: join',
#  'NISAMLC: asap',
#  'NISAMLC: https://us06web.zoom.us/j/89735874355?pwd=KtdBvYzjffeLwYbyA3HUzt7VwpuKw1.1',
#  'NISAMLC: join',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: complete this task and  implement CNN on top of any image dataset',
#  'NISAMLC: imlement CNN on flowers dataset as well',
#  'NISAMLC: and submit those notes before monday afternoon',
#  'NISAMLC: Tomorrow you will not have regular session instead you will be assigned a task and it will be consider as your Deep Learning *Mini Project* <This message was edited>',
#  'NISAMLC: Mini Project On Deep Learning : *Create A Multi Layer Convolutional Neural Network in order to classify Flowers using googleapi flowers dataset and classify it into 5 different categories namely Rose,Tulip, Sunflower,Daisy and Dandelion* save Your Model into h5 file and send to me via my email with notebook  : nisamlckkn@gmail.com on or before 29th of May',
#  'Rashid (DS-Codeme): Ok sir',
#  'NISAMLC: class starts @2.30 on Introduction to Computer Vision and Image manipulation',
#  'NISAMLC: https://us06web.zoom.us/j/89163859148?pwd=lyAoMKZRNWAgriZ9pai2IszdGQ293o.1',
#  'NISAMLC: join',
#  'NISAMLC: class starts @2.30pm',
#  'NISAMLC: https://us06web.zoom.us/j/85373550975?pwd=yo9UTFvYwPycn4CedQmbipCrb3kFVi.1',
#  'NISAMLC: join',
#  'NISAMLC: @919037649226 ????',
#  'NISAMLC: @917907733950 ??//',
#  'Rashid (DS-Codeme): On the way',
#  'NISAMLC: offline aano?',
#  'Rashid (DS-Codeme): Alla',
#  'Rashid (DS-Codeme): Connection issue',
#  'Rashid (DS-Codeme): Athaan',
#  'NISAMLC: k',
#  '+91 94966 64940: please let me in',
#  'NISAMLC: video codec: https://docs.opencv.org/4.x/d0/d61/group__cudacodec.html',
#  'NISAMLC: amal look at this :https://www.tutorialspoint.com/opencv/index.htm',
#  'NISAMLC: class starts @2.30: We will discuss all image processing related topics in a brief today, make sure to attend all (we will discuss all topics we went through till regarding CV )@919778218181 , @919946189970 make sure to attend',
#  'NISAMLC: https://us06web.zoom.us/j/83628900360?pwd=4dpav7Gb3MahIZyHBeeHSY3ktU1pu6.1',
#  'NISAMLC: You deleted this message',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: https://us06web.zoom.us/j/88443754683?pwd=TSaHXIo2KIsgMhkPeVZkEuaDFd8l2W.1',
#  'NISAMLC: JOIN',
#  'Aysha Hamna(CodeMe): Dear Students,',
#  'Aysha Hamna(CodeMe): Reminder:',
#  "Aysha Hamna(CodeMe): Since the review plan interviews are going on , you won't have data science session today",
#  'Rashid (DS-Codeme): Ok',
#  'Aysha Hamna(CodeMe): Reminder:',
#  'NISAMLC: Since I do have a meeting scheduled today CV classes are postponed to Saturday (from morning to evening)',
#  "NISAMLC: And those who are attending today's Aptitude test , this is a rare chance any interview will not complete without aptitude and mental ability so make sure to attend",
#  'NISAMLC: class starts @2.30 on : CV:Drawing shapes on images: Basic to Advanced',
#  'NISAMLC: https://us06web.zoom.us/j/82621147975?pwd=Wcj697cm8G6LqtjDXzNr6PDpsaY7KI.1',
#  'NISAMLC: join',
#  'NISAMLC: CV class : tomorrow(Saturday) morning 10.00 AM TO 1.00 PM class',
#  'NISAMLC: https://us06web.zoom.us/j/84505621870?pwd=s8h800UVxjg6EybmgL8AyplvEm4Qst.1',
#  'NISAMLC: join',
#  'NISAMLC: https://us04web.zoom.us/j/5019495850?pwd=dENBUnN6a043bzlHcGpJY3Ara2lWZz09',
#  'NISAMLC: rejoin',
#  '+91 79077 33950: https://us04web.zoom.us/j/74450854485?pwd=E1z5A4tcHiQkI3Tui6iNrKrMl0LxqE.1',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'Aysha Hamna(CodeMe): Reminder:',
#  'Aysha Hamna(CodeMe): Dear Students,',
#  'NISAMLC: everyone must attend github class @2.30 everyone can attend those can attend offline be offline and others can join through online *Dont Miss It*',
#  '+91 94966 64940: Link?',
#  'NISAMLC: https://meet.google.com/wfx-cszi-iyb',
#  "NISAMLC: How many of you are attending today's GIT class?",
#  'NISAMLC: and how many attended yesterday?',
#  "Rashid (DS-Codeme): I have attended yesterday's class",
#  'NISAMLC: what about today?',
#  '+91 94966 64940: Me',
#  'Rashid (DS-Codeme): Will attend through online',
#  'NISAMLC: okay',
#  'NISAMLC: dont miss it guys',
#  'NISAMLC: you will not get its recordings',
#  'NISAMLC: very much crucial for  team work <This message was edited>',
#  'Amal (DS-Codeme): Yesterday attended.... Today through online',
#  'NISAMLC: Okay',
#  'jisshnu.___ (DS-Codeme): Me',
#  'NISAMLC: https://meet.google.com/wfx-cszi-iyb',
#  'NISAMLC: class starts @2.30 pm',
#  'Rashid (DS-Codeme): git or cv',
#  'NISAMLC: cv',
#  'Rashid (DS-Codeme): ok',
#  'NISAMLC: https://meet.google.com/tfq-dyhi-aoa',
#  'Asif (CodeMe): This message was deleted',
#  'Asif (CodeMe): This message was deleted',
#  'Asif (CodeMe): Dear Students,',
#  'Aysha Hamna(CodeMe): Anyone attending interview today?',
#  'NISAMLC: class @2.30',
#  'NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  'NISAMLC: join',
#  'Aysha Hamna(CodeMe): <Media omitted>',
#  'NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  'NISAMLC: join',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: You deleted this message',
#  'NISAMLC: Practice Computer Vision Tasks Which we are discussed by taking different images and push it inside Git',
#  'NISAMLC: Today we do have git classes @2.30 from Dilshad sir *from scratch* how many of are going to attend?? let me know if you are not attending i will go with CV class (There are many things which we are not disccused in our classroom in git so it will be really helpfull) , i want to know before 1.00PM',
#  'Rashid (DS-Codeme): I will attend',
#  'NISAMLC: okay',
#  'NISAMLC: anyone else?',
#  'NISAMLC: he will explain from scratch',
#  '+91 94966 64940: ✋🏻',
#  'NISAMLC: okay',
#  'NISAMLC: try to do practicals',
#  'NISAMLC: then only you will get know the mistakes and ask doubts he will rectify it',
#  '+91 79077 33950: will attend',
#  '𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): ✋🏻',
#  'jisshnu.___ (DS-Codeme): ✋🏼',
#  '+91 94966 64940: Sir link?',
#  'NISAMLC: To join the meeting on Google Meet, click this link: ',
#  'NISAMLC: become late',
#  'NISAMLC: just started',
#  'NISAMLC: join now',
#  'NISAMLC: join immediately',
#  'NISAMLC: otherwise you cant follow',
#  'Aysha Hamna(CodeMe): 🔴Review plan update :',
#  'NISAMLC: join in the same link',
#  'Aysha Hamna(CodeMe): To join the meeting on Google Meet, click this link: ',
#  'Aysha Hamna(CodeMe): Join in this link for git session',
#  'NISAMLC: You guys can now access the entire course recordings go through it accordingly (you will be notified in your mail)',
#  'NISAMLC: let me know if you dont',
#  '+91 94966 64940: Notification already sent?',
#  'NISAMLC: ya',
#  'NISAMLC: @919946189970  your mail id?',
#  'jisshnu.___ (DS-Codeme): jishnumss7@gmail.com',
#  'NISAMLC: k',
#  '+91 94966 64940: Received . Thanks',
#  'jisshnu.___ (DS-Codeme): Recieved',
#  '𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): Received',
#  '+91 86181 86237: Received',
#  'Amal (DS-Codeme): Received',
#  'Asna. (DS-Codeme): Not received',
#  'NISAMLC: Go through the CNN section and we will continue our discussion from tomorrow onwards',
#  'NISAMLC: Class @2.30 PM',
#  'NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  'NISAMLC: join <This message was edited>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: Workout try it on different images',
#  'NISAMLC: class @2.30',
#  'NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  'NISAMLC: join',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: Object Detection',
#  'NISAMLC: Resources',
#  'NISAMLC: try out',
#  'NISAMLC: and implement other image processing techniques',
#  'NISAMLC: We will start our NLP (Natural Language Processing) session from tomorrow (6/1/2024) 2.30PM onwards',
#  'Rashid (DS-Codeme): Okay',
#  'NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  'NISAMLC: join',
#  '+91 94966 64940: Please admit',
#  '+91 94966 64940: @918593099647',
#  'NISAMLC: <Media omitted>',
#  "Asif (CodeMe): There won't be any session this afternoon",
#  'Rashid (DS-Codeme): Ok',
#  "Asif (CodeMe): There won't be any session today",
#  'Asif (CodeMe): Complete your regex assignment and share the GitHub link',
#  "Aysha Hamna(CodeMe): We'll resume your NLP sessions from tomorrow ",
#  'NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  'NISAMLC: joinn',
#  'NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  'NISAMLC: join',
#  'NISAMLC: anyone joining?',
#  'Rashid (DS-Codeme): Yes, sir oru 5 mins',
#  'NISAMLC: k',
#  'NISAMLC: class starts @2.30pm',
#  'NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  'NISAMLC: @919037649226 are you join??',
#  'Rashid (DS-Codeme): yes',
#  'Rashid (DS-Codeme): sir notebook share cheyuo',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: class starts @2.30pm',
#  'NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  'NISAMLC: join',
#  'NISAMLC: any more people joining? <This message was edited>',
#  'NISAMLC: will wait until 2.45',
#  'Rashid (DS-Codeme): Sir',
#  'Rashid (DS-Codeme): Njn ind',
#  'Rashid (DS-Codeme): let me in',
#  'Rashid (DS-Codeme): hi',
#  'NISAMLC: class starts at 2.30pm',
#  'Rashid (DS-Codeme): Link',
#  'NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: Monday onwards you will get Class on Django for MLOPS your last session',
#  'NISAMLC: class starts @2.30',
#  'NISAMLC: https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#  'NISAMLC: join',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: <Media omitted>',
#  'NISAMLC: we are planning to give a 30 days Project Bootcamp for this batch *30 days 30 Projects*, where we will build 30 end to end projects from various domains which we are discussed in our entire curriculum. how many of you are interested ?? i need everyone to attend the session otherwise we will drop the plan every day 2 hrs , if you are interested let me know.',
#  'Rashid (DS-Codeme): Iam interested',
#  '𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): ✋🏻',
#  'Amal (DS-Codeme): ✋🏻',
#  'jisshnu.___ (DS-Codeme): 👍🏼',
#  'jisshnu.___ (DS-Codeme) added Nayana(OldBatch) J Nair',
#  'Asna. (DS-Codeme): ✋🏼',
#  '+91 86181 86237: ✋🏻',
#  '+91 94966 64940: ✋🏻',
#  "Nayana(OldBatch) J Nair: Today's session postponed to 3.pm",
#  'Nayana(OldBatch) J Nair: https://meet.google.com/exf-ftsp-xpg',
#  'Asif (CodeMe): https://blogs.oracle.com/oracleuniversity/post/announcing-oci-2024-generative-ai-professional-certification-and-course',
#  'jisshnu.___ (DS-Codeme): <Media omitted>',
#  'Nayana(OldBatch) J Nair: join all',
#  'Nayana(OldBatch) J Nair: https://meet.google.com/exf-ftsp-xpg',
#  'Nayana(OldBatch) J Nair: join all',
#  'Nayana(OldBatch) J Nair: please join',
#  'NISAMLC: You deleted this message',
#  'NISAMLC: 🎤Since the django session has been completed we will be starting our 30 Days Project session from  Thursday August-1 by taking projects from ML,CV,DL,RECOMMENDER ENGINES AND SO ON *let me know how many of you are in* ?',
#  'NISAMLC: let me know how many of you are in?',
#  '𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme): ✋🏻',
#  'jisshnu.___ (DS-Codeme): 👍🏼',
#  'Amal (DS-Codeme): ✋🏻',
#  'Rashid (DS-Codeme): Count me in',
#  'Asna. (DS-Codeme): ✋🏼',
#  '+91 94966 64940: ✋🏻',
#  '+91 86181 86237: This message was deleted',
#  '+91 86181 86237: ✋🏻',
#  'NISAMLC: Those who attending the Camp',
#  'NISAMLC: We will be starting our project session from Tomorrow onwards',
#  'NISAMLC: *Day 1 of Project Bootcamp*',
#  'NISAMLC: *Day 2 of Project Bootcamp*',
#  'Rashid (DS-Codeme): Waiting..',
#  'NISAMLC: Who can join today and coming lectures:',
#  'Asif (CodeMe): https://www.pwc.in/careers/experienced-jobs/description.html?wdjobreqid=554074WD&wdcountry=IND&jobtitle=Specialist%203&wdjobsite=Global_Experienced_Careers',
#  'Asif (CodeMe): pwc fresher opening for ds,apply asap',
#  'NISAMLC: those who are not submitted the project task will get a chance to submit their project link before 2.30pm today']

# %%
all_dates
# Out:
# ['26/02/24, 3:50pm - ',
#  '26/02/24, 3:01pm - ',
#  '26/02/24, 3:50pm - ',
#  '26/02/24, 3:51pm - ',
#  '26/02/24, 3:51pm - ',
#  '26/02/24, 3:51pm - ',
#  '27/02/24, 11:39am - ',
#  '27/02/24, 12:46pm - ',
#  '27/02/24, 3:32pm - ',
#  '27/02/24, 3:34pm - ',
#  '28/02/24, 9:16am - ',
#  '28/02/24, 11:20am - ',
#  '28/02/24, 11:59am - ',
#  '28/02/24, 12:01pm - ',
#  '28/02/24, 1:20pm - ',
#  '28/02/24, 1:20pm - ',
#  '29/02/24, 9:08am - ',
#  '01/03/24, 9:25am - ',
#  '01/03/24, 10:11am - ',
#  '01/03/24, 11:43am - ',
#  '01/03/24, 12:06pm - ',
#  '01/03/24, 2:25pm - ',
#  '01/03/24, 3:44pm - ',
#  '04/03/24, 9:27am - ',
#  '04/03/24, 9:30am - ',
#  '04/03/24, 9:34am - ',
#  '04/03/24, 9:44am - ',
#  '04/03/24, 11:48am - ',
#  '04/03/24, 11:50am - ',
#  '04/03/24, 11:50am - ',
#  '04/03/24, 1:23pm - ',
#  '04/03/24, 3:05pm - ',
#  '04/03/24, 4:47pm - ',
#  '04/03/24, 4:51pm - ',
#  '04/03/24, 5:58pm - ',
#  '05/03/24, 9:22am - ',
#  '05/03/24, 10:07am - ',
#  '05/03/24, 1:01pm - ',
#  '05/03/24, 1:01pm - ',
#  '05/03/24, 1:01pm - ',
#  '05/03/24, 5:34pm - ',
#  '06/03/24, 9:19am - ',
#  '06/03/24, 12:09pm - ',
#  '06/03/24, 12:15pm - ',
#  '06/03/24, 12:15pm - ',
#  '06/03/24, 1:08pm - ',
#  '06/03/24, 5:09pm - ',
#  '06/03/24, 5:22pm - ',
#  '06/03/24, 5:23pm - ',
#  '06/03/24, 5:24pm - ',
#  '06/03/24, 7:13pm - ',
#  '07/03/24, 9:25am - ',
#  '07/03/24, 9:36am - ',
#  '07/03/24, 10:10am - ',
#  '07/03/24, 10:15am - ',
#  '07/03/24, 2:41pm - ',
#  '08/03/24, 9:21am - ',
#  '08/03/24, 9:24am - ',
#  '10/03/24, 8:41pm - ',
#  '10/03/24, 8:53pm - ',
#  '11/03/24, 9:48am - ',
#  '11/03/24, 9:48am - ',
#  '11/03/24, 9:48am - ',
#  '11/03/24, 10:00am - ',
#  '11/03/24, 2:48pm - ',
#  '12/03/24, 9:30am - ',
#  '12/03/24, 2:39pm - ',
#  '13/03/24, 9:22am - ',
#  '13/03/24, 11:39am - ',
#  '13/03/24, 2:32pm - ',
#  '13/03/24, 3:12pm - ',
#  '14/03/24, 9:24am - ',
#  '14/03/24, 9:25am - ',
#  '14/03/24, 9:39am - ',
#  '14/03/24, 9:42am - ',
#  '14/03/24, 9:42am - ',
#  '14/03/24, 9:43am - ',
#  '14/03/24, 10:36am - ',
#  '14/03/24, 2:36pm - ',
#  '14/03/24, 2:36pm - ',
#  '14/03/24, 2:39pm - ',
#  '14/03/24, 2:39pm - ',
#  '14/03/24, 2:39pm - ',
#  '14/03/24, 2:39pm - ',
#  '14/03/24, 2:54pm - ',
#  '14/03/24, 3:20pm - ',
#  '14/03/24, 3:20pm - ',
#  '14/03/24, 3:51pm - ',
#  '15/03/24, 9:20am - ',
#  '15/03/24, 9:22am - ',
#  '15/03/24, 12:54pm - ',
#  '15/03/24, 2:18pm - ',
#  '18/03/24, 9:13am - ',
#  '18/03/24, 12:29pm - ',
#  '18/03/24, 2:35pm - ',
#  '18/03/24, 3:46pm - ',
#  '19/03/24, 9:29am - ',
#  '19/03/24, 12:00pm - ',
#  '19/03/24, 12:01pm - ',
#  '19/03/24, 3:46pm - ',
#  '19/03/24, 4:07pm - ',
#  '19/03/24, 4:07pm - ',
#  '20/03/24, 9:20am - ',
#  '20/03/24, 11:27am - ',
#  '20/03/24, 11:50am - ',
#  '20/03/24, 4:23pm - ',
#  '20/03/24, 4:24pm - ',
#  '20/03/24, 4:24pm - ',
#  '20/03/24, 4:28pm - ',
#  '20/03/24, 4:30pm - ',
#  '21/03/24, 9:52am - ',
#  '21/03/24, 1:18pm - ',
#  '22/03/24, 9:20am - ',
#  '22/03/24, 11:18am - ',
#  '22/03/24, 11:42am - ',
#  '22/03/24, 2:03pm - ',
#  '22/03/24, 2:03pm - ',
#  '23/03/24, 2:31pm - ',
#  '23/03/24, 2:38pm - ',
#  '23/03/24, 2:39pm - ',
#  '23/03/24, 2:49pm - ',
#  '25/03/24, 9:28am - ',
#  '25/03/24, 11:42am - ',
#  '25/03/24, 11:42am - ',
#  '25/03/24, 12:26pm - ',
#  '25/03/24, 2:09pm - ',
#  '25/03/24, 2:09pm - ',
#  '25/03/24, 2:09pm - ',
#  '25/03/24, 3:00pm - ',
#  '25/03/24, 3:00pm - ',
#  '26/03/24, 11:33am - ',
#  '26/03/24, 12:21pm - ',
#  '26/03/24, 2:09pm - ',
#  '27/03/24, 8:33am - ',
#  '27/03/24, 9:11am - ',
#  '27/03/24, 11:18am - ',
#  '27/03/24, 12:15pm - ',
#  '27/03/24, 12:34pm - ',
#  '27/03/24, 12:38pm - ',
#  '27/03/24, 1:03pm - ',
#  '27/03/24, 2:29pm - ',
#  '27/03/24, 4:55pm - ',
#  '28/03/24, 9:10am - ',
#  '28/03/24, 11:30am - ',
#  '28/03/24, 11:30am - ',
#  '28/03/24, 2:25pm - ',
#  '31/03/24, 6:05pm - ',
#  '31/03/24, 9:11pm - ',
#  '01/04/24, 2:02pm - ',
#  '01/04/24, 2:03pm - ',
#  '01/04/24, 2:03pm - ',
#  '01/04/24, 2:04pm - ',
#  '01/04/24, 2:04pm - ',
#  '01/04/24, 2:18pm - ',
#  '01/04/24, 2:31pm - ',
#  '01/04/24, 3:51pm - ',
#  '02/04/24, 2:02pm - ',
#  '02/04/24, 2:05pm - ',
#  '02/04/24, 2:07pm - ',
#  '02/04/24, 4:05pm - ',
#  '02/04/24, 4:06pm - ',
#  '03/04/24, 2:10pm - ',
#  '04/04/24, 1:13pm - ',
#  '04/04/24, 2:40pm - ',
#  '04/04/24, 3:19pm - ',
#  '04/04/24, 4:03pm - ',
#  '04/04/24, 4:03pm - ',
#  '04/04/24, 4:07pm - ',
#  '04/04/24, 4:08pm - ',
#  '04/04/24, 4:14pm - ',
#  '04/04/24, 4:16pm - ',
#  '05/04/24, 9:15am - ',
#  '05/04/24, 9:15am - ',
#  '05/04/24, 10:46am - ',
#  '05/04/24, 9:46pm - ',
#  '05/04/24, 9:47pm - ',
#  '08/04/24, 1:54pm - ',
#  '08/04/24, 2:00pm - ',
#  '08/04/24, 2:02pm - ',
#  '08/04/24, 2:34pm - ',
#  '08/04/24, 2:34pm - ',
#  '09/04/24, 1:42pm - ',
#  '09/04/24, 2:08pm - ',
#  '09/04/24, 2:08pm - ',
#  '11/04/24, 3:17pm - ',
#  '15/04/24, 4:25pm - ',
#  '16/04/24, 11:25am - ',
#  '16/04/24, 11:25am - ',
#  '16/04/24, 11:26am - ',
#  '16/04/24, 11:28am - ',
#  '16/04/24, 11:28am - ',
#  '16/04/24, 11:45am - ',
#  '16/04/24, 11:45am - ',
#  '16/04/24, 11:46am - ',
#  '16/04/24, 11:46am - ',
#  '16/04/24, 12:30pm - ',
#  '16/04/24, 12:30pm - ',
#  '16/04/24, 1:10pm - ',
#  '16/04/24, 1:10pm - ',
#  '16/04/24, 2:23pm - ',
#  '16/04/24, 2:24pm - ',
#  '16/04/24, 2:27pm - ',
#  '16/04/24, 3:09pm - ',
#  '16/04/24, 3:10pm - ',
#  '16/04/24, 3:51pm - ',
#  '16/04/24, 4:31pm - ',
#  '16/04/24, 4:32pm - ',
#  '17/04/24, 10:56am - ',
#  '17/04/24, 10:56am - ',
#  '17/04/24, 11:37am - ',
#  '17/04/24, 11:37am - ',
#  '17/04/24, 11:55am - ',
#  '17/04/24, 12:18pm - ',
#  '17/04/24, 12:18pm - ',
#  '17/04/24, 12:18pm - ',
#  '17/04/24, 2:25pm - ',
#  '17/04/24, 2:29pm - ',
#  '17/04/24, 3:11pm - ',
#  '17/04/24, 3:52pm - ',
#  '17/04/24, 4:16pm - ',
#  '18/04/24, 11:13am - ',
#  '18/04/24, 11:57am - ',
#  '18/04/24, 2:23pm - ',
#  '18/04/24, 2:30pm - ',
#  '18/04/24, 3:11pm - ',
#  '18/04/24, 3:52pm - ',
#  '19/04/24, 11:06am - ',
#  '19/04/24, 11:06am - ',
#  '19/04/24, 11:13am - ',
#  '19/04/24, 11:15am - ',
#  '19/04/24, 11:50am - ',
#  '19/04/24, 12:13pm - ',
#  '19/04/24, 2:49pm - ',
#  '19/04/24, 3:28pm - ',
#  '19/04/24, 3:32pm - ',
#  '19/04/24, 4:13pm - ',
#  '19/04/24, 4:35pm - ',
#  '19/04/24, 4:35pm - ',
#  '22/04/24, 11:05am - ',
#  '22/04/24, 11:20am - ',
#  '22/04/24, 11:47am - ',
#  '22/04/24, 12:30pm - ',
#  '22/04/24, 12:39pm - ',
#  '22/04/24, 1:11pm - ',
#  '22/04/24, 2:30pm - ',
#  '22/04/24, 3:11pm - ',
#  '22/04/24, 3:52pm - ',
#  '22/04/24, 4:17pm - ',
#  '22/04/24, 4:18pm - ',
#  '22/04/24, 4:19pm - ',
#  '23/04/24, 11:02am - ',
#  '23/04/24, 11:03am - ',
#  '23/04/24, 11:04am - ',
#  '23/04/24, 11:45am - ',
#  '23/04/24, 2:29pm - ',
#  '23/04/24, 3:10pm - ',
#  '23/04/24, 3:51pm - ',
#  '23/04/24, 4:09pm - ',
#  '23/04/24, 4:09pm - ',
#  '23/04/24, 4:10pm - ',
#  '23/04/24, 4:10pm - ',
#  '23/04/24, 4:11pm - ',
#  '24/04/24, 11:05am - ',
#  '24/04/24, 11:06am - ',
#  '24/04/24, 11:10am - ',
#  '24/04/24, 11:48am - ',
#  '24/04/24, 11:48am - ',
#  '24/04/24, 12:22pm - ',
#  '24/04/24, 12:30pm - ',
#  '24/04/24, 12:31pm - ',
#  '24/04/24, 12:31pm - ',
#  '24/04/24, 12:34pm - ',
#  '24/04/24, 12:56pm - ',
#  '24/04/24, 2:31pm - ',
#  '24/04/24, 2:33pm - ',
#  '24/04/24, 2:33pm - ',
#  '24/04/24, 2:33pm - ',
#  '24/04/24, 2:45pm - ',
#  '24/04/24, 2:46pm - ',
#  '24/04/24, 3:27pm - ',
#  '24/04/24, 4:07pm - ',
#  '25/04/24, 11:07am - ',
#  '25/04/24, 11:11am - ',
#  '25/04/24, 11:52am - ',
#  '25/04/24, 12:32pm - ',
#  '25/04/24, 2:30pm - ',
#  '25/04/24, 2:33pm - ',
#  '25/04/24, 3:04pm - ',
#  '25/04/24, 3:04pm - ',
#  '25/04/24, 3:05pm - ',
#  '25/04/24, 3:18pm - ',
#  '25/04/24, 3:19pm - ',
#  '25/04/24, 4:00pm - ',
#  '25/04/24, 4:00pm - ',
#  '25/04/24, 4:00pm - ',
#  '25/04/24, 4:01pm - ',
#  '25/04/24, 4:01pm - ',
#  '25/04/24, 4:01pm - ',
#  '25/04/24, 4:01pm - ',
#  '25/04/24, 4:07pm - ',
#  '25/04/24, 4:13pm - ',
#  '25/04/24, 4:20pm - ',
#  '25/04/24, 4:20pm - ',
#  '25/04/24, 4:21pm - ',
#  '25/04/24, 4:21pm - ',
#  '25/04/24, 4:21pm - ',
#  '25/04/24, 4:21pm - ',
#  '28/04/24, 10:30pm - ',
#  '28/04/24, 10:35pm - ',
#  '29/04/24, 2:22pm - ',
#  '29/04/24, 2:23pm - ',
#  '29/04/24, 2:23pm - ',
#  '29/04/24, 2:24pm - ',
#  '29/04/24, 2:27pm - ',
#  '29/04/24, 2:29pm - ',
#  '29/04/24, 2:35pm - ',
#  '29/04/24, 2:35pm - ',
#  '29/04/24, 3:11pm - ',
#  '29/04/24, 3:11pm - ',
#  '29/04/24, 3:47pm - ',
#  '29/04/24, 3:48pm - ',
#  '29/04/24, 3:53pm - ',
#  '30/04/24, 9:53am - ',
#  '30/04/24, 9:53am - ',
#  '30/04/24, 9:53am - ',
#  '01/05/24, 10:57am - ',
#  '01/05/24, 11:02am - ',
#  '01/05/24, 11:04am - ',
#  '01/05/24, 11:47am - ',
#  '01/05/24, 12:28pm - ',
#  '01/05/24, 1:02pm - ',
#  '01/05/24, 2:34pm - ',
#  '01/05/24, 3:18pm - ',
#  '01/05/24, 3:19pm - ',
#  '01/05/24, 3:20pm - ',
#  '02/05/24, 11:03am - ',
#  '02/05/24, 11:06am - ',
#  '02/05/24, 11:47am - ',
#  '02/05/24, 12:08pm - ',
#  '02/05/24, 12:29pm - ',
#  '02/05/24, 8:23pm - ',
#  '03/05/24, 11:04am - ',
#  '03/05/24, 11:05am - ',
#  '03/05/24, 11:06am - ',
#  '03/05/24, 11:47am - ',
#  '03/05/24, 11:48am - ',
#  '03/05/24, 2:33pm - ',
#  '03/05/24, 2:37pm - ',
#  '03/05/24, 3:20pm - ',
#  '03/05/24, 3:42pm - ',
#  '03/05/24, 3:58pm - ',
#  '03/05/24, 3:58pm - ',
#  '03/05/24, 3:58pm - ',
#  '03/05/24, 3:58pm - ',
#  '03/05/24, 3:59pm - ',
#  '03/05/24, 3:59pm - ',
#  '06/05/24, 10:55am - ',
#  '06/05/24, 11:02am - ',
#  '06/05/24, 11:03am - ',
#  '06/05/24, 11:06am - ',
#  '06/05/24, 8:46pm - ',
#  '06/05/24, 10:35pm - ',
#  '08/05/24, 11:21am - ',
#  '08/05/24, 1:04pm - ',
#  '08/05/24, 8:46pm - ',
#  '08/05/24, 8:46pm - ',
#  '08/05/24, 8:52pm - ',
#  '09/05/24, 11:03am - ',
#  '09/05/24, 11:05am - ',
#  '09/05/24, 11:12am - ',
#  '09/05/24, 11:54am - ',
#  '09/05/24, 12:34pm - ',
#  '09/05/24, 1:16pm - ',
#  '10/05/24, 11:11am - ',
#  '10/05/24, 11:17am - ',
#  '10/05/24, 11:31am - ',
#  '10/05/24, 11:58am - ',
#  '10/05/24, 11:59am - ',
#  '10/05/24, 12:34pm - ',
#  '14/05/24, 11:01am - ',
#  '14/05/24, 11:01am - ',
#  '14/05/24, 11:09am - ',
#  '14/05/24, 11:09am - ',
#  '14/05/24, 11:10am - ',
#  '14/05/24, 11:25am - ',
#  '14/05/24, 12:40pm - ',
#  '14/05/24, 12:40pm - ',
#  '14/05/24, 2:30pm - ',
#  '14/05/24, 2:30pm - ',
#  '14/05/24, 4:46pm - ',
#  '14/05/24, 4:47pm - ',
#  '14/05/24, 4:50pm - ',
#  '14/05/24, 4:51pm - ',
#  '15/05/24, 10:00am - ',
#  '15/05/24, 2:34pm - ',
#  '15/05/24, 7:27pm - ',
#  '15/05/24, 7:28pm - ',
#  '16/05/24, 10:02am - ',
#  '16/05/24, 11:02am - ',
#  '16/05/24, 11:48am - ',
#  '17/05/24, 11:02am - ',
#  '17/05/24, 11:07am - ',
#  '17/05/24, 5:44pm - ',
#  '20/05/24, 12:49pm - ',
#  '20/05/24, 2:31pm - ',
#  '20/05/24, 2:31pm - ',
#  '21/05/24, 2:13pm - ',
#  '21/05/24, 2:19pm - ',
#  '21/05/24, 2:22pm - ',
#  '21/05/24, 2:22pm - ',
#  '21/05/24, 4:21pm - ',
#  '22/05/24, 1:58pm - ',
#  '22/05/24, 2:34pm - ',
#  '22/05/24, 2:34pm - ',
#  '22/05/24, 2:38pm - ',
#  '23/05/24, 2:07pm - ',
#  '23/05/24, 2:31pm - ',
#  '23/05/24, 2:31pm - ',
#  '23/05/24, 2:36pm - ',
#  '23/05/24, 2:36pm - ',
#  '23/05/24, 3:12pm - ',
#  '23/05/24, 3:12pm - ',
#  '23/05/24, 3:12pm - ',
#  '24/05/24, 2:27pm - ',
#  '24/05/24, 2:28pm - ',
#  '24/05/24, 3:31pm - ',
#  '24/05/24, 4:02pm - ',
#  '24/05/24, 4:02pm - ',
#  '24/05/24, 4:02pm - ',
#  '26/05/24, 11:12pm - ',
#  '27/05/24, 10:20am - ',
#  '27/05/24, 10:21am - ',
#  '28/05/24, 10:10am - ',
#  '28/05/24, 2:27pm - ',
#  '28/05/24, 2:27pm - ',
#  '29/05/24, 2:19pm - ',
#  '29/05/24, 2:29pm - ',
#  '29/05/24, 2:29pm - ',
#  '29/05/24, 2:34pm - ',
#  '29/05/24, 2:34pm - ',
#  '29/05/24, 2:34pm - ',
#  '29/05/24, 2:35pm - ',
#  '29/05/24, 2:35pm - ',
#  '29/05/24, 2:35pm - ',
#  '29/05/24, 2:35pm - ',
#  '29/05/24, 2:35pm - ',
#  '29/05/24, 3:41pm - ',
#  '29/05/24, 4:50pm - ',
#  '29/05/24, 4:51pm - ',
#  '30/05/24, 12:38pm - ',
#  '30/05/24, 2:27pm - ',
#  '30/05/24, 5:55pm - ',
#  '30/05/24, 5:55pm - ',
#  '30/05/24, 5:55pm - ',
#  '30/05/24, 5:55pm - ',
#  '31/05/24, 2:31pm - ',
#  '31/05/24, 2:31pm - ',
#  '02/06/24, 10:03pm - ',
#  '03/06/24, 11:23am - ',
#  '04/06/24, 11:36am - ',
#  '04/06/24, 11:36am - ',
#  '04/06/24, 9:44pm - ',
#  '06/06/24, 9:30am - ',
#  '06/06/24, 9:31am - ',
#  '07/06/24, 10:18am - ',
#  '07/06/24, 2:26pm - ',
#  '07/06/24, 2:26pm - ',
#  '07/06/24, 4:50pm - ',
#  '08/06/24, 9:56am - ',
#  '08/06/24, 9:56am - ',
#  '08/06/24, 11:03am - ',
#  '08/06/24, 11:03am - ',
#  '08/06/24, 11:45am - ',
#  '08/06/24, 12:50pm - ',
#  '08/06/24, 12:50pm - ',
#  '08/06/24, 12:50pm - ',
#  '09/06/24, 6:49pm - ',
#  '09/06/24, 6:50pm - ',
#  '10/06/24, 12:16pm - ',
#  '10/06/24, 2:46pm - ',
#  '10/06/24, 2:52pm - ',
#  '11/06/24, 10:35am - ',
#  '11/06/24, 10:35am - ',
#  '11/06/24, 10:36am - ',
#  '11/06/24, 10:40am - ',
#  '11/06/24, 10:40am - ',
#  '11/06/24, 10:40am - ',
#  '11/06/24, 10:41am - ',
#  '11/06/24, 10:41am - ',
#  '11/06/24, 10:41am - ',
#  '11/06/24, 10:41am - ',
#  '11/06/24, 10:46am - ',
#  '11/06/24, 10:50am - ',
#  '11/06/24, 11:09am - ',
#  '11/06/24, 2:41pm - ',
#  '12/06/24, 11:53am - ',
#  '12/06/24, 11:55am - ',
#  '12/06/24, 11:55am - ',
#  '12/06/24, 11:55am - ',
#  '12/06/24, 2:38pm - ',
#  '12/06/24, 3:39pm - ',
#  '12/06/24, 4:55pm - ',
#  '12/06/24, 4:58pm - ',
#  '13/06/24, 9:41am - ',
#  '13/06/24, 2:08pm - ',
#  '13/06/24, 2:26pm - ',
#  '13/06/24, 2:26pm - ',
#  '14/06/24, 1:30pm - ',
#  '14/06/24, 3:05pm - ',
#  '14/06/24, 3:05pm - ',
#  '14/06/24, 5:39pm - ',
#  '15/06/24, 2:29pm - ',
#  '15/06/24, 2:30pm - ',
#  '19/06/24, 10:30am - ',
#  '19/06/24, 10:47am - ',
#  '19/06/24, 10:52am - ',
#  '19/06/24, 10:52am - ',
#  '19/06/24, 10:52am - ',
#  '19/06/24, 10:53am - ',
#  '19/06/24, 11:29am - ',
#  '19/06/24, 11:29am - ',
#  '19/06/24, 11:29am - ',
#  '19/06/24, 1:25pm - ',
#  '19/06/24, 2:29pm - ',
#  '19/06/24, 2:32pm - ',
#  '19/06/24, 2:55pm - ',
#  '19/06/24, 3:24pm - ',
#  '19/06/24, 3:24pm - ',
#  '19/06/24, 3:24pm - ',
#  '19/06/24, 3:24pm - ',
#  '19/06/24, 3:25pm - ',
#  '19/06/24, 3:25pm - ',
#  '19/06/24, 10:09pm - ',
#  '20/06/24, 2:42pm - ',
#  '21/06/24, 2:41pm - ',
#  '21/06/24, 2:41pm - ',
#  '24/06/24, 2:36pm - ',
#  '24/06/24, 2:36pm - ',
#  '24/06/24, 2:37pm - ',
#  '24/06/24, 2:38pm - ',
#  '24/06/24, 2:39pm - ',
#  '24/06/24, 2:39pm - ',
#  '24/06/24, 2:39pm - ',
#  '24/06/24, 2:39pm - ',
#  '24/06/24, 2:41pm - ',
#  '24/06/24, 2:42pm - ',
#  '24/06/24, 2:54pm - ',
#  '24/06/24, 3:44pm - ',
#  '24/06/24, 6:35pm - ',
#  '25/06/24, 9:33am - ',
#  '26/06/24, 11:03am - ',
#  '26/06/24, 2:25pm - ',
#  '26/06/24, 2:25pm - ',
#  '26/06/24, 4:07pm - ',
#  '26/06/24, 4:07pm - ',
#  '26/06/24, 4:07pm - ',
#  '26/06/24, 4:07pm - ',
#  '26/06/24, 4:07pm - ',
#  '26/06/24, 4:07pm - ',
#  '27/06/24, 2:19pm - ',
#  '27/06/24, 2:32pm - ',
#  '27/06/24, 2:34pm - ',
#  '27/06/24, 5:21pm - ',
#  '27/06/24, 5:21pm - ',
#  '27/06/24, 5:21pm - ',
#  '27/06/24, 5:21pm - ',
#  '27/06/24, 5:22pm - ',
#  '30/06/24, 9:05pm - ',
#  '30/06/24, 9:20pm - ',
#  '01/07/24, 2:31pm - ',
#  '01/07/24, 2:31pm - ',
#  '01/07/24, 2:36pm - ',
#  '01/07/24, 2:41pm - ',
#  '01/07/24, 4:17pm - ',
#  '02/07/24, 11:15am - ',
#  '02/07/24, 11:15am - ',
#  '03/07/24, 8:02am - ',
#  '03/07/24, 8:03am - ',
#  '10/07/24, 1:19pm - ',
#  '11/07/24, 2:56pm - ',
#  '11/07/24, 2:56pm - ',
#  '12/07/24, 2:25pm - ',
#  '12/07/24, 2:25pm - ',
#  '12/07/24, 2:35pm - ',
#  '12/07/24, 2:36pm - ',
#  '12/07/24, 2:37pm - ',
#  '15/07/24, 2:24pm - ',
#  '15/07/24, 2:33pm - ',
#  '15/07/24, 2:35pm - ',
#  '15/07/24, 2:35pm - ',
#  '15/07/24, 5:26pm - ',
#  '15/07/24, 5:53pm - ',
#  '16/07/24, 2:21pm - ',
#  '16/07/24, 2:33pm - ',
#  '16/07/24, 2:33pm - ',
#  '16/07/24, 2:39pm - ',
#  '16/07/24, 2:42pm - ',
#  '16/07/24, 2:45pm - ',
#  '16/07/24, 2:45pm - ',
#  '16/07/24, 2:48pm - ',
#  '16/07/24, 2:50pm - ',
#  '18/07/24, 2:12pm - ',
#  '18/07/24, 2:33pm - ',
#  '18/07/24, 2:34pm - ',
#  '18/07/24, 4:02pm - ',
#  '18/07/24, 4:05pm - ',
#  '19/07/24, 2:13pm - ',
#  '19/07/24, 2:32pm - ',
#  '19/07/24, 2:32pm - ',
#  '19/07/24, 3:43pm - ',
#  '19/07/24, 3:54pm - ',
#  '22/07/24, 9:53am - ',
#  '22/07/24, 9:55am - ',
#  '22/07/24, 9:55am - ',
#  '22/07/24, 10:03am - ',
#  '22/07/24, 10:05am - ',
#  '22/07/24, 10:10am - ',
#  '22/07/24, 10:14am - ',
#  '22/07/24, 10:18am - ',
#  '22/07/24, 11:04am - ',
#  '22/07/24, 2:40pm - ',
#  '22/07/24, 3:06pm - ',
#  '24/07/24, 12:47pm - ',
#  '24/07/24, 1:01pm - ',
#  '24/07/24, 2:28pm - ',
#  '25/07/24, 2:30pm - ',
#  '26/07/24, 2:31pm - ',
#  '29/07/24, 3:03pm - ',
#  '29/07/24, 5:05pm - ',
#  '29/07/24, 5:24pm - ',
#  '29/07/24, 5:24pm - ',
#  '29/07/24, 5:29pm - ',
#  '29/07/24, 5:31pm - ',
#  '29/07/24, 6:04pm - ',
#  '29/07/24, 6:06pm - ',
#  '29/07/24, 6:25pm - ',
#  '29/07/24, 7:00pm - ',
#  '29/07/24, 7:39pm - ',
#  '29/07/24, 7:40pm - ',
#  '30/07/24, 3:09pm - ',
#  '31/07/24, 4:35pm - ',
#  '01/08/24, 2:23pm - ',
#  '02/08/24, 2:30pm - ',
#  '02/08/24, 2:35pm - ',
#  '02/08/24, 2:36pm - ',
#  '03/08/24, 2:36pm - ',
#  '03/08/24, 2:37pm - ',
#  '05/08/24, 10:22am - ']

# %%
# this is a simple time string,we will appply this kind of transformation
# inorder to get the date and the time for our analysis

string = '16/08/18, 20:09 - '
string = string.split(',')
date,time = string[0],string[1]
time = time.split('-')
time = time[0].strip()
print(date+" and "+time)
# Out:
# 16/08/18 and 20:09

# %%
# this function is to seperate the time and date

def gettimeanddate(string):
    string = string.split(',')
    date,time = string[0],string[1]
    time = time.split('-')
    time = time[0].strip()
    
    return date+" "+time

# %%
# creating a dataframe for messages and their dates

df = pd.DataFrame({'user_messages':all_messages,
                   'message_date':all_dates})

df['message_date'] = df['message_date'].apply(lambda text:gettimeanddate(text))
df.rename(columns={'message_date':'date'},inplace=True)

df.head()
# Out:
#                                        user_messages             date
# 0  Messages and calls are end-to-end encrypted. N...  26/02/24 3:50pm
# 1  jisshnu.___ (DS-Codeme) created group "Data sc...  26/02/24 3:01pm
# 2                  jisshnu.___ (DS-Codeme) added you  26/02/24 3:50pm
# 3      jisshnu.___ (DS-Codeme) added +91 86181 86237  26/02/24 3:51pm
# 4  jisshnu.___ (DS-Codeme): try to do the project...  26/02/24 3:51pm

# %%
pattern = r'(am|pm)'
df['date'] = df['date'].str.replace(pattern, '', regex=True).str.strip()

# %%
df.head()
# Out:
#                                        user_messages           date
# 0  Messages and calls are end-to-end encrypted. N...  26/02/24 3:50
# 1  jisshnu.___ (DS-Codeme) created group "Data sc...  26/02/24 3:01
# 2                  jisshnu.___ (DS-Codeme) added you  26/02/24 3:50
# 3      jisshnu.___ (DS-Codeme) added +91 86181 86237  26/02/24 3:51
# 4  jisshnu.___ (DS-Codeme): try to do the project...  26/02/24 3:51

# %%
df.shape
# Out:
# (648, 2)

# %%
df['user_messages']
# Out:
# 0      Messages and calls are end-to-end encrypted. N...
# 1      jisshnu.___ (DS-Codeme) created group "Data sc...
# 2                      jisshnu.___ (DS-Codeme) added you
# 3          jisshnu.___ (DS-Codeme) added +91 86181 86237
# 4      jisshnu.___ (DS-Codeme): try to do the project...
#                              ...
# 643                        Rashid (DS-Codeme): Waiting..
# 644     NISAMLC: Who can join today and coming lectures:
# 645    Asif (CodeMe): https://www.pwc.in/careers/expe...
# 646    Asif (CodeMe): pwc fresher opening for ds,appl...
# 647    NISAMLC: those who are not submitted the proje...
# Name: user_messages, Length: 648, dtype: object

# %%
users = []
messages = []

for message in df['user_messages']:
    
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])

        
    else:
        users.append('Group Notification')
        messages.append(entry[0])
        
        
df['User'] = users
df['message'] = messages


def getstring(text):
    return text.split('\n')[0]

df['message'] = df['message'].apply(lambda text:getstring(text))


df = df.drop(['user_messages'],axis=1)
df = df[['message','date','User']]

df = df.rename(columns={'message':'Message',
                       'date':'Date'})

df.head()
# Out:
#                                              Message           Date  \
# 0  Messages and calls are end-to-end encrypted. N...  26/02/24 3:50
# 1  jisshnu.___ (DS-Codeme) created group "Data sc...  26/02/24 3:01
# 2                  jisshnu.___ (DS-Codeme) added you  26/02/24 3:50
# 3      jisshnu.___ (DS-Codeme) added +91 86181 86237  26/02/24 3:51
# 4  try to do the project  yourself first then onl...  26/02/24 3:51
#
#                       User
# 0       Group Notification
# 1       Group Notification
# 2       Group Notification
# 3       Group Notification
# 4  jisshnu.___ (DS-Codeme)

# %%
16/08/18 20:09
    
YYYY-MM-DD
# Out:
#   Cell In[20], line 1
#     16/08/18 20:09
#        ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
df.shape
# Out:
# (648, 3)

# %%
df['Only date'] = pd.to_datetime(df['Date']).dt.date

df['Year'] = pd.to_datetime(df['Date']).dt.year

df['Month_num'] = pd.to_datetime(df['Date']).dt.month

df['Month'] = pd.to_datetime(df['Date']).dt.month_name()

df['Day'] = pd.to_datetime(df['Date']).dt.day

df['Day_name'] = pd.to_datetime(df['Date']).dt.day_name()


df['Hour'] = pd.to_datetime(df['Date']).dt.hour

df['Minute'] = pd.to_datetime(df['Date']).dt.minute


df.head()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14980\2879012235.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Only date'] = pd.to_datetime(df['Date']).dt.date
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14980\2879012235.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Year'] = pd.to_datetime(df['Date']).dt.year
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14980\2879012235.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Month_num'] = pd.to_datetime(df['Date']).dt.month
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14980\2879012235.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Month'] = pd.to_datetime(df['Date']).dt.month_name()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14980\2879012235.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Day'] = pd.to_datetime(df['Date']).dt.day
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14980\2879012235.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Day_name'] = pd.to_datetime(df['Date']).dt.day_name()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14980\2879012235.py:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Hour'] = pd.to_datetime(df['Date']).dt.hour
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14980\2879012235.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Minute'] = pd.to_datetime(df['Date']).dt.minute
#                                              Message           Date  \
# 0  Messages and calls are end-to-end encrypted. N...  26/02/24 3:50
# 1  jisshnu.___ (DS-Codeme) created group "Data sc...  26/02/24 3:01
# 2                  jisshnu.___ (DS-Codeme) added you  26/02/24 3:50
# 3      jisshnu.___ (DS-Codeme) added +91 86181 86237  26/02/24 3:51
# 4  try to do the project  yourself first then onl...  26/02/24 3:51
#
#                       User   Only date  Year  Month_num     Month  Day  \
# 0       Group Notification  2024-02-26  2024          2  February   26
# 1       Group Notification  2024-02-26  2024          2  February   26
# 2       Group Notification  2024-02-26  2024          2  February   26
# 3       Group Notification  2024-02-26  2024          2  February   26
# 4  jisshnu.___ (DS-Codeme)  2024-02-26  2024          2  February   26
#
#   Day_name  Hour  Minute
# 0   Monday     3      50
# 1   Monday     3       1
# 2   Monday     3      50
# 3   Monday     3      51
# 4   Monday     3      51

# %%
df['User'].unique()
# Out:
# array(['Group Notification', 'jisshnu.___ (DS-Codeme)', 'Asif (CodeMe)',
#        'Aysha Hamna(CodeMe)', '+91 86181 86237', '+91 94966 64940',
#        'Amal (DS-Codeme)', 'Rashid (DS-Codeme)', 'NISAMLC',
#        '𝓚𝖆𝖗𝖙𝖍𝖎𝖐𝖆 (DS-Codeme)', 'Asna. (DS-Codeme)', '+91 79077 33950',
#        'Nayana(OldBatch) J Nair'], dtype=object)

# %%
df[df['User'] == 'Rashid (DS-Codeme)'].shape[0]
# Out:
# 39

# %%
words = []
for message in df['Message']:
    words.extend(message.split())
    
print(len(words))
# Out:
# 2067

# %%
words
# Out:
# ['Messages',
#  'and',
#  'calls',
#  'are',
#  'end-to-end',
#  'encrypted.',
#  'No',
#  'one',
#  'outside',
#  'of',
#  'this',
#  'chat,',
#  'not',
#  'even',
#  'WhatsApp,',
#  'can',
#  'read',
#  'or',
#  'listen',
#  'to',
#  'them.',
#  'Tap',
#  'to',
#  'learn',
#  'more.',
#  'jisshnu.___',
#  '(DS-Codeme)',
#  'created',
#  'group',
#  '"Data',
#  'science',
#  '"',
#  'jisshnu.___',
#  '(DS-Codeme)',
#  'added',
#  'you',
#  'jisshnu.___',
#  '(DS-Codeme)',
#  'added',
#  '+91',
#  '86181',
#  '86237',
#  'try',
#  'to',
#  'do',
#  'the',
#  'project',
#  'yourself',
#  'first',
#  'then',
#  'only',
#  'refer',
#  'the',
#  'collab',
#  'https://colab.research.google.com/drive/1tKXB0p6bcZ4gwTUNjp9zNpRMYxC952qj?usp=sharing',
#  'https://meet.google.com/xsu-gthd-hmw',
#  'https://colab.research.google.com/drive/1b_r9LNdmeSGUUIlFSQUteLKw07ESr5iQ?usp=sharing',
#  'https://colab.research.google.com/drive/1yIHdz2bMzzLvGqh1Dq02AAwyYFbnJAf-?usp=sharing',
#  'Refer',
#  'this',
#  'also',
#  'while',
#  'doing',
#  'your',
#  'project',
#  'to',
#  'understand',
#  'how',
#  'to',
#  'use',
#  'the',
#  'sampling',
#  'techniques.',
#  'here',
#  'i',
#  'balanced',
#  'the',
#  'data',
#  'after',
#  'splitting',
#  'to',
#  'train',
#  'and',
#  'test',
#  'https://meet.google.com/sdk-sqzo-unn',
#  'https://docs.google.com/document/d/1SlzY5P0wQPr8ZsgBUc4m1mkr-fu-nlRZqBu_am2ZH2M/edit?usp=sharing',
#  'https://meet.google.com/xut-tqwq-pcd',
#  'jisshnu.___',
#  '(DS-Codeme)',
#  'added',
#  '+91',
#  '79077',
#  '33950',
#  '<Media',
#  'omitted>',
#  'https://colab.research.google.com/drive/1ljIcfFMyAOJpIRWrrWa-61vppqIydnRU?usp=sharing',
#  'Same',
#  'link',
#  'same',
#  'link',
#  'https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit?usp=sharing',
#  'https://meet.google.com/uiv-vkou-pda',
#  '<Media',
#  'omitted>',
#  'join',
#  'using',
#  'same',
#  'link',
#  'https://colab.research.google.com/drive/1P9fduGtId539V1MYs2ScQLPC6Ph8PrSx?usp=sharing',
#  'Class',
#  'started?',
#  'no',
#  'https://meet.google.com/ind-raij-vzt',
#  'https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit#gid=0',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'It’s',
#  'showing',
#  'no',
#  'such',
#  'meeting',
#  'https://meet.google.com/zpy-qjbm-sbj',
#  '<Media',
#  'omitted>',
#  'please',
#  'join',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'Waiting',
#  'for',
#  'this',
#  'message',
#  '<Media',
#  'omitted>',
#  'SAME',
#  'LINK',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'same',
#  'link',
#  'https://meet.google.com/ewj-ckus-jmv',
#  'https://hamoyehq.medium.com/hamoye-data-science-internship-fall-2024-call-for-application-79488110376d',
#  'https://docs.google.com/forms/d/e/1FAIpQLSe9Sr9L3H7oObSSZSB-qndQYNal1OGGcyTBfOppZLyuOKWPRg/viewform',
#  '<Media',
#  'omitted>',
#  'Problem',
#  'statement',
#  '🌚',
#  'EDA',
#  '+',
#  'Classification',
#  '+',
#  'Power',
#  'BI',
#  '=',
#  'certificate',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  '<Media',
#  'omitted>',
#  'Same',
#  'link',
#  'Some',
#  'network',
#  'issue',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'No',
#  'join',
#  'again',
#  'same',
#  'link',
#  'join',
#  'Join',
#  'the',
#  'same',
#  'link',
#  'Please',
#  'let',
#  'me',
#  'in',
#  "Tomorrow's",
#  'machine',
#  'learning',
#  'class',
#  'will',
#  'start',
#  'at',
#  '2',
#  '15',
#  'pm',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'https://meet.google.com/ind-raij-vzt',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'Join',
#  'the',
#  'link',
#  'CREATE',
#  'TABLE',
#  'event',
#  '(',
#  'join',
#  'the',
#  'same',
#  'link',
#  'same',
#  'link',
#  'ds',
#  'join',
#  'the',
#  'same',
#  'link',
#  'same',
#  'https://meet.google.com/ewj-ckus-jmv',
#  'SAME',
#  'LINK',
#  '<Media',
#  'omitted>',
#  'same',
#  'link',
#  'https://meet.google.com/ind-raij-vzt',
#  'Let',
#  'me',
#  'into',
#  'the',
#  'class.',
#  'network',
#  'issue',
#  'Ok',
#  'wait',
#  'couple',
#  'of',
#  'minutes',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'Join',
#  'the',
#  'same',
#  'link..',
#  '.',
#  'in',
#  'akkettilla',
#  'Network',
#  'issue',
#  'und',
#  'Wait',
#  'ok',
#  'Join',
#  'Class',
#  'ille',
#  '??',
#  'https://www.kdnuggets.com/2020/06/naive-bayes-algorithm-everything.html',
#  '\U0001f6dc',
#  'WiFi',
#  'Passwords\U0001f6dc',
#  'join',
#  'the',
#  'same',
#  'link',
#  'ML',
#  'session',
#  'will',
#  'start',
#  'at',
#  '2:15',
#  'pm',
#  'join',
#  'the',
#  'same',
#  'link',
#  'Same',
#  'link',
#  'ML',
#  'Same',
#  'link',
#  'same',
#  'limk',
#  'https://colab.research.google.com/drive/108YjV5uDkumB8aw5RMrie3rLCeyWcNk4?usp=sharing',
#  'Same',
#  'link',
#  '9:35',
#  '<Media',
#  'omitted>',
#  'Mandatory',
#  'SQL',
#  'Assessment',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'Tomorrow',
#  'Dax',
#  'class',
#  'will',
#  'be',
#  'from',
#  '11.15-',
#  '1.15',
#  'PM',
#  'ML',
#  'Class',
#  'will',
#  'be',
#  'from',
#  '9',
#  'AM',
#  'To',
#  '11',
#  'Am',
#  'https://meet.google.com/uew-zqmr-sth',
#  '<Media',
#  'omitted>',
#  'same',
#  'link',
#  'I',
#  "haven't",
#  'received',
#  'the',
#  'SQL',
#  'assessment',
#  '@918618186237',
#  ',send',
#  'it',
#  'ASAP',
#  'Where',
#  'I',
#  'I',
#  'have',
#  'to',
#  'send',
#  'it',
#  'in',
#  'group',
#  'Send',
#  'here',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'Power',
#  'bi',
#  'join',
#  'the',
#  'same',
#  'link',
#  '<This',
#  'message',
#  'was',
#  'edited>',
#  '<Media',
#  'omitted>',
#  'Power',
#  'bi',
#  'same',
#  'link',
#  'screen',
#  'poi',
#  '<Media',
#  'omitted>',
#  'https://meet.google.com/uew-zqmr-sth',
#  'Join',
#  'please',
#  'Monday',
#  'Afternoon',
#  'Ille',
#  'Class',
#  'kaanum',
#  'afternoon',
#  'for',
#  'ds',
#  'join',
#  'dax',
#  'same',
#  'link',
#  'https://meet.google.com/ind-raij-vzt',
#  '<Media',
#  'omitted>',
#  'https://www.kaggle.com/datasets/brijbhushannanda1979/bigmart-sales-data',
#  'Download',
#  'dataset',
#  'from',
#  'this',
#  'link',
#  'and',
#  'perform',
#  'EDA',
#  'and',
#  'then',
#  'apply',
#  'any',
#  'regression',
#  'model',
#  'Complete',
#  'this',
#  'task',
#  'today',
#  'We',
#  'postponed',
#  "today's",
#  'afternoon',
#  'session',
#  'Power',
#  'bi',
#  'same',
#  'link',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'ML',
#  'class',
#  '👍🏽',
#  'join',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'https://www.kaggle.com/competitions/titanic/data',
#  'join',
#  'PCA',
#  'Tomorrow',
#  '11.30-1',
#  'and',
#  '2.15',
#  '-3.45',
#  '4th',
#  'floor',
#  'aan',
#  'class',
#  '11.30',
#  'https://meet.google.com/svp-wgoq-ajb',
#  'join',
#  '2.30',
#  'join',
#  'https://www.microsoft.com/en-us/cloudskillschallenge/ai/registration/2024?ocid=aisc23_CSC_skillsforaiblog_cnl#choose-your-challenge',
#  'Tomorrow',
#  '2.00PM:Lecture',
#  'On',
#  'Recommendation',
#  'Engines,',
#  'build',
#  'your',
#  'first',
#  'Recommender',
#  '<This',
#  'message',
#  'was',
#  'edited>',
#  'How',
#  'many',
#  'of',
#  'you',
#  'are',
#  'attending',
#  'Offline??',
#  'Im',
#  'not',
#  '🤚🏻',
#  '✌🏻',
#  'Conference',
#  'Hall',
#  '<This',
#  'message',
#  'was',
#  'edited>',
#  'No',
#  'online',
#  'class?',
#  'https://meet.google.com/yyp-ybak-jqd',
#  '<Media',
#  'omitted>',
#  'You',
#  'deleted',
#  'this',
#  'message',
#  'https://meet.google.com/jiy-cjvd-ums',
#  'join',
#  'in',
#  'this',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'https://meet.google.com/wpa-gyyd-kte',
#  'class',
#  'starts',
#  '@2.30',
#  'pm',
#  'today',
#  '<This',
#  'message',
#  'was',
#  'edited>',
#  'SAME',
#  'LINK',
#  '<Media',
#  'omitted>',
#  'https://github.com/JovianHQ/opendatasets/blob/master/data/countries-languages-spoken/countries-languages.csv',
#  '<This',
#  'message',
#  'was',
#  'edited>',
#  'Create',
#  'a',
#  'Country',
#  'Recommender',
#  'based',
#  'on',
#  'the',
#  'language',
#  'spoken',
#  'https://www.kaggle.com/datasets/dylanjcastillo/7k-books-with-metadata',
#  'Build',
#  'a',
#  'Book',
#  'Recommender',
#  'based',
#  'on',
#  'the',
#  'description',
#  'about',
#  'the',
#  'book',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'ok',
#  'No',
#  'class',
#  'today,',
#  'try',
#  'to',
#  'explore',
#  'more',
#  'recommendation',
#  'systems',
#  'using',
#  'various',
#  'datasets',
#  'Okay',
#  'Okay',
#  'https://www.youtube.com/live/wB7m2YMqVVY?si=IJq7IixEgva7Tu8t',
#  'live',
#  'class',
#  'of',
#  'hamoye',
#  'Anyone',
#  'offline??',
#  'https://us05web.zoom.us/j/89944631210?pwd=Vi6hcSNnsdHS5bQgh5r44jeHLt9Hgo.1',
#  'join',
#  'https://meet.google.com/eir-sawr-tui',
#  'rejoin',
#  '<Media',
#  'omitted>',
#  'https://meet.google.com/xuo-ahea-zvc',
#  'join',
#  '*Create',
#  'a',
#  'recommendation',
#  'system',
#  'which',
#  'recommends',
#  'books',
#  'or',
#  'documents*',
#  'Data:scrape',
#  'data',
#  'from',
#  'websites',
#  'like',
#  'goodreads',
#  'and',
#  'scribd',
#  'or',
#  'any',
#  'other',
#  'website,',
#  'do',
#  'it',
#  'and',
#  'submit',
#  'it',
#  'before',
#  'coming',
#  'monday',
#  '9..00AM',
#  'try',
#  '<This',
#  'message',
#  'was',
#  'edited>',
#  'Tomorrow',
#  'onwards',
#  'There',
#  'will',
#  'be',
#  'two',
#  'sessions',
#  'are',
#  'going',
#  'on',
#  'for',
#  '*Data',
#  'Science*',
#  'students',
#  "today's",
#  'class',
#  'is',
#  'there?',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'https://us05web.zoom.us/j/84356593130?pwd=tE40wZMVVhZahfQfpMlWmaiuQMdVEh.1',
#  'ML',
#  'class?',
#  'Join',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'join',
#  'in',
#  'this',
#  'link',
#  'https://us05web.zoom.us/j/82662632874?pwd=lgeKSnCVezGajLEX1IeAx3TBlt6Xd8.1',
#  'https://us05web.zoom.us/j/83954675823?pwd=hZBXtKvZBMKaci3f79IzVd4Munacw5.1',
#  'rejoin',
#  '2.30',
#  'next',
#  'class',
#  'join',
#  'immediately',
#  'link',
#  'comes',
#  'https://us05web.zoom.us/j/89882762836?pwd=f4OJJDwtrLYksEeOXGEua1VsSK1gS0.1',
#  'https://us05web.zoom.us/j/83124834127?pwd=CZnC3e1LCu4BZKbtXpoR8vdUF0bY8W.1',
#  'rejoin',
#  'https://us05web.zoom.us/j/84698759689?pwd=jc3uaX38A8XKT9i8aGEyEeV4FGOhbD.1',
#  'last',
#  'join',
#  'https://us05web.zoom.us/j/87597044212?pwd=eYhexXtU8wlpMxKP894sKaZ9ESCEFv.1',
#  'https://us05web.zoom.us/j/81088179003?pwd=4cy88JdC9vDOk311hla6REoyV4ZHw5.1',
#  'join',
#  'https://us05web.zoom.us/j/85900123290?pwd=dHszQjo1DUVTUUK0eulZhlDGN0ePKE.1',
#  'join',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'https://us05web.zoom.us/j/85320192983?pwd=mbloGXvXoW4fR5CrQ7tkevcaB2X2ZM.1',
#  'rejoin',
#  'join',
#  'immediately',
#  'https://us05web.zoom.us/j/86955036516?pwd=bKixQEfWmQTdTbHwDigNVcsZSmkHx4.1',
#  'https://us05web.zoom.us/j/88418826144?pwd=AGMp0uqMGf2gF6uSZwgJ1HqTyAjXTi.1',
#  'https://us05web.zoom.us/j/83068961004?pwd=fwxUEnK21rZ1M2Qn46HBArPHwUiU2g.1',
#  'https://www.kaggle.com/datasets/zygmunt/goodbooks-10k',
#  'https://us05web.zoom.us/j/82196771153?pwd=5SBVgnTDk5F6vIjFduX0TzsL5VeCFa.1',
#  'https://us05web.zoom.us/j/81310056571?pwd=9bpbaQ6goaGabCrJPHmoKHR7oFPKu5.1',
#  'join',
#  'immediately',
#  'https://us05web.zoom.us/j/84126238187?pwd=WPsF79MUYkPRheBHE3vTRqdxLUqyml.1',
#  'https://us05web.zoom.us/j/88298798338?pwd=OXqo2o2NfHu3Ty2Y5hkua2Ut3KXCP0.1',
#  'https://us05web.zoom.us/j/84745853077?pwd=xmT9cP4e5uSFiaUD6dcLrnkabbRMfj.1',
#  'JOIN',
#  'https://us05web.zoom.us/j/85029807729?pwd=R2FC3g5JSz2Cmk2327RnGCnwrgbG1X.1',
#  'Please',
#  'add',
#  'in',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'https://us05web.zoom.us/j/84998061454?pwd=Hf7VPgXs9s10R6kaWHp9fSvP2SChXG.1',
#  '<Media',
#  'omitted>',
#  'https://us05web.zoom.us/j/88476935533?pwd=NGwH2oEMx62JoUOu6XIcj7GgiLQiUh.1',
#  'https://www.kaggle.com/datasets/prajitdatta/movielens-100k-dataset/data',
#  'https://us05web.zoom.us/j/83223361006?pwd=nMcKtUZMKxPJcn2dbwfR4Y4nwFrLUW.1',
#  'https://us05web.zoom.us/j/82183401601?pwd=B90w2RLezed2fSwwFytoVvbjDG3R1R.1',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'https://us05web.zoom.us/j/87644185104?pwd=UoZyDi9uVqE4COBvWTNKdXH6poOALK.1',
#  '<Media',
#  'omitted>',
#  'https://us05web.zoom.us/j/83719435591?pwd=OAOinOmRv6owb4ur0XT7Xc4ezDCEhj.1',
#  'https://us05web.zoom.us/j/87168841298?pwd=6pkmUIjKiEwwVYMpLNv844bEVoGyC3.1',
#  '<Media',
#  'omitted>',
#  'join',
#  'at',
#  '2.30',
#  'pm',
#  'https://us05web.zoom.us/j/86285461568?pwd=m4IKlxw6ASWObFncC4hONqzuG7JJV9.1',
#  'https://us05web.zoom.us/j/82808190042?pwd=0NVFr47d2PDPGOC1ONwDGNvaTiep8q.1',
#  'https://us05web.zoom.us/j/85777199753?pwd=lPVl2Yd5x1iJXohgGXhRdE0fbWH4rv.1',
#  'https://visualstudio.microsoft.com/visual-cpp-build-tools/',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'JOIN',
#  'Link?',
#  'https://us05web.zoom.us/j/84172735576?pwd=p9JDPvN1splta73xe0e0cJEljAxU14.1',
#  'https://us05web.zoom.us/j/86837283209?pwd=BiZRMT5mflOnTH7qv9PkvLXpKekvja.1',
#  'https://us05web.zoom.us/j/87894573653?pwd=dalYPnEGwRnvhYF9wXb5tXmMWhaZX6.1',
#  'https://us05web.zoom.us/j/89958400034?pwd=pB3kaxEXbSBonzej9ZjYhnOdDycChI.1',
#  'https://us05web.zoom.us/j/81104718108?pwd=QZabNNMb5lDbC8ddg3lwXjTrRjb2nG.1',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '*market',
#  'basket',
#  'analysis*',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'join',
#  'https://us05web.zoom.us/j/88244453101?pwd=FdH0PcnOXMSjsT3A0IoaQShXNKbsa7.1',
#  'Please',
#  'add',
#  'in',
#  'https://us04web.zoom.us/j/72173791910?pwd=bADdLHM7aJFqaHJxatinEs1GK6Fm7N.1',
#  'join',
#  'https://sampleportfolio-a7brzwhi85rmvtef4wngqj.streamlit.app/',
#  'let',
#  'me',
#  'know',
#  'if',
#  'you',
#  'have',
#  'any',
#  'doubts',
#  'join',
#  'https://meet.google.com/hnf-wehd-ypx',
#  'Those',
#  'who',
#  'submitted',
#  ':',
#  'join',
#  'https://us05web.zoom.us/j/88538105805?pwd=ZSYtpaIb5n02IwfADmkStah47tWKqU.1',
#  'https://deploy-asnafidha.streamlit.app',
#  'Those',
#  'who',
#  'submitted',
#  ':',
#  'Sorry',
#  'https://us05web.zoom.us/j/81270550054?pwd=jDnkE79Y8JliuNVoPkuHfKE0oLexcG.1',
#  'https://us05web.zoom.us/j/84088354300?pwd=DI2TLClARzPcf4dRnppAt8ajLO0g0v.1',
#  'https://us05web.zoom.us/j/85018623759?pwd=viFBEMe7js12WkpzvnsNHG2pawwhjY.1',
#  'join',
#  'https://us04web.zoom.us/j/79134534643?pwd=n6ka0KpC5XbqUF1YBiVDfGJLBp0gI7.1',
#  'https://us05web.zoom.us/j/87430068127?pwd=bEX00IJNqEAzL9YvMhVEdtahO84GbN.1',
#  'https://us05web.zoom.us/j/86927643942?pwd=UNWBUduc0ahzwvaZbweOP4QIBxPtrC.1',
#  'join',
#  'https://us05web.zoom.us/j/86189409946?pwd=jKxbPOLxwZKt3G3FLpoaY1dk3MMp7I.1',
#  '<Media',
#  'omitted>',
#  'Perform',
#  'the',
#  'same',
#  '>',
#  'AR',
#  'model',
#  'on',
#  'Female',
#  'Birth',
#  'Data',
#  '3.35',
#  'pm',
#  'https://us04web.zoom.us/j/76691224273?pwd=bby3tlcIi3rHzVyg4jYSBjd2cntbtq.1',
#  'join',
#  'Perform',
#  'the',
#  'same',
#  'on',
#  'the',
#  'shampoo',
#  'dataset',
#  'Ok',
#  'Please',
#  'share',
#  'the',
#  'final',
#  'notebook',
#  'k',
#  '<Media',
#  'omitted>',
#  'modify',
#  'the',
#  'days',
#  'of',
#  'prediction',
#  'like',
#  'if',
#  'you',
#  'want',
#  'to',
#  'predict',
#  'for',
#  'the',
#  'last',
#  '15',
#  'days',
#  'or',
#  '30',
#  'days',
#  'and',
#  'so',
#  'on',
#  '@919946189970',
#  'https://www.kaggle.com/datasets/niketchauhan/covid-19-time-series-data',
#  'Link',
#  'to',
#  'Covid',
#  '19',
#  'dataset',
#  'choose',
#  'one',
#  'country',
#  'from',
#  'this',
#  'data',
#  'and',
#  'perform',
#  'AutoRegression',
#  'in',
#  'order',
#  'to',
#  'find',
#  'the',
#  'covid',
#  'cases',
#  'try',
#  'different',
#  'countries',
#  'and',
#  'compare',
#  'results',
#  'submit',
#  'it',
#  'before',
#  'monday',
#  "Tomorrow's",
#  'Data',
#  'Science',
#  'session',
#  'is',
#  'scheduled',
#  'at',
#  '2:30',
#  'pm',
#  'Ok',
#  'How',
#  'many',
#  'of',
#  'u',
#  'are',
#  'attending',
#  'online?',
#  '✋🏼',
#  '🤚🏽',
#  '🤚🏻',
#  '🤚',
#  'For',
#  'those',
#  'in',
#  'attendance',
#  'offline,',
#  'the',
#  'session',
#  'will',
#  'take',
#  'place',
#  'in',
#  'the',
#  'last',
#  'classroom.',
#  'https://us05web.zoom.us/j/87110841572?pwd=OWJbPWbvehs3oWoB949WmyAFXXQwMB.1',
#  'please',
#  'join',
#  'Invalid',
#  'meeting',
#  'id',
#  'https://us05web.zoom.us/j/84426665904?pwd=eW10ScuhCCcu6diyauNYhTVsWoM9LB.1',
#  'https://atlas.mitre.org/matrices/ATLAS',
#  'https://incidentdatabase.ai/',
#  'https://us05web.zoom.us/j/86732036320?pwd=yaIPNxa9hp9B6H5j9Ai3ptzuqqSWmu.1',
#  'https://meet.google.com/vrs-wvoh-zng',
#  'join',
#  '<Media',
#  'omitted>',
#  'join',
#  'Link?',
#  'https://us05web.zoom.us/j/84146894791?pwd=0FGmCXYSFl4GRMAUUQxPIJnr0y189w.1',
#  'https://us05web.zoom.us/j/85738513589?pwd=PzjFyd46iBkdv6jWYqDb4hKhaLaBWb.1',
#  'https://us05web.zoom.us/j/86258974313?pwd=ZO778uGGRCZaZ1rXJjEE9zDaMxvhCK.1',
#  '<Media',
#  'omitted>',
#  'https://us05web.zoom.us/j/81324776140?pwd=NqfRe3VCI7kv6hNjXNG26xsxSFBLUh.1',
#  'Link?',
#  'https://us05web.zoom.us/j/85302314572?pwd=LQlX8uiB8lxqGwzHLCuDih5lmgj0XW.1',
#  'https://www.youtube.com/watch?v=aircAruvnKk&t=784s',
#  'join',
#  'https://us05web.zoom.us/j/81956643317?pwd=a2Dnir1U7fq4Y1fPoLoKt4KysYsVlm.1',
#  'https://us05web.zoom.us/j/83794961231?pwd=LSLhV9pdiXCEiEHkkFmNNoW09m7PCJ.1',
#  '<Media',
#  'omitted>',
#  'https://us05web.zoom.us/j/83432770790?pwd=15aIavmf3exCGAUn0MLQRw3ZW2B8VY.1',
#  "Tomorrow's",
#  'schedule',
#  'anyone',
#  'offline?',
#  'online',
#  '🙌🏻',
#  'https://us05web.zoom.us/j/89768721231?pwd=RUHgbb3leOUDroj4M26QHtIdPloj3g.1',
#  'link',
#  'https://us05web.zoom.us/j/81690932462?pwd=BG1xPitPTZx0ZMQ1jATFbswR3XqJuG.1',
#  'join',
#  'https://us05web.zoom.us/j/86546468416?pwd=vgLrHWK0l0WMw6nfgT0Mb2qzUdcyOG.1',
#  'https://us05web.zoom.us/j/82347408592?pwd=bap6BJ5lpH0Q6qOw9rofMePqx75Ovm.1',
#  'https://www.youtube.com/playlist?list=PLvcbYUQ5t0UHOLnBzl46_Q6QKtFgfMGc3',
#  '@918593099647',
#  'innalathem',
#  'innathem',
#  'notebooks',
#  'share',
#  'ako',
#  'okay',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'Anyone',
#  'offline',
#  '✋🏼',
#  'ok',
#  'https://meet.google.com/ihx-eeyg-mwi',
#  "Tomorrow's",
#  'schedule',
#  '🔴',
#  'session',
#  'rescheduled',
#  'to',
#  '3',
#  'pm',
#  'tomorrow',
#  'same',
#  'link',
#  'https://colab.research.google.com/drive/1klJqPJr4dvIQsX6fWjT6I4CRU4iqUEqH?usp=sharing',
#  'Go',
#  'through',
#  'the',
#  'gradient',
#  'descent',
#  'topics',
#  ...]

# %%
df[(df['Message'] == '<Media omitted>')&(df['User'] == 'jisshnu.___ (DS-Codeme)')]
# Out:
#              Message            Date                     User   Only date  \
# 34   <Media omitted>   04/03/24 5:58  jisshnu.___ (DS-Codeme)  2024-04-03
# 36   <Media omitted>  05/03/24 10:07  jisshnu.___ (DS-Codeme)  2024-05-03
# 45   <Media omitted>   06/03/24 1:08  jisshnu.___ (DS-Codeme)  2024-06-03
# 623  <Media omitted>   24/07/24 1:01  jisshnu.___ (DS-Codeme)  2024-07-24
#
#      Year  Month_num  Month  Day   Day_name  Hour  Minute
# 34   2024          4  April    3  Wednesday     5      58
# 36   2024          5    May    3     Friday    10       7
# 45   2024          6   June    3     Monday     1       8
# 623  2024          7   July   24  Wednesday     1       1

# %%
df['Message'].unique()
# Out:
# array(['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.',
#        'jisshnu.___ (DS-Codeme) created group "Data science "',
#        'jisshnu.___ (DS-Codeme) added you',
#        'jisshnu.___ (DS-Codeme) added +91 86181 86237',
#        'try to do the project  yourself first then only refer the collab',
#        'https://colab.research.google.com/drive/1tKXB0p6bcZ4gwTUNjp9zNpRMYxC952qj?usp=sharing',
#        'https://meet.google.com/xsu-gthd-hmw',
#        'https://colab.research.google.com/drive/1b_r9LNdmeSGUUIlFSQUteLKw07ESr5iQ?usp=sharing',
#        'https://colab.research.google.com/drive/1yIHdz2bMzzLvGqh1Dq02AAwyYFbnJAf-?usp=sharing',
#        'Refer this also while doing your project to understand how to use the sampling techniques. here i balanced the data after splitting to train and test',
#        'https://meet.google.com/sdk-sqzo-unn',
#        'https://docs.google.com/document/d/1SlzY5P0wQPr8ZsgBUc4m1mkr-fu-nlRZqBu_am2ZH2M/edit?usp=sharing',
#        'https://meet.google.com/xut-tqwq-pcd',
#        'jisshnu.___ (DS-Codeme) added +91 79077 33950', '<Media omitted>',
#        'https://colab.research.google.com/drive/1ljIcfFMyAOJpIRWrrWa-61vppqIydnRU?usp=sharing',
#        'Same link', 'same link',
#        'https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit?usp=sharing',
#        'https://meet.google.com/uiv-vkou-pda', 'join using same link',
#        'https://colab.research.google.com/drive/1P9fduGtId539V1MYs2ScQLPC6Ph8PrSx?usp=sharing',
#        'Class started?', 'no', 'https://meet.google.com/ind-raij-vzt',
#        'https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit#gid=0',
#        'This message was deleted', 'It’s showing no such meeting',
#        'https://meet.google.com/zpy-qjbm-sbj', 'please join',
#        'Waiting for this message', 'SAME LINK',
#        'https://meet.google.com/ewj-ckus-jmv',
#        'https://hamoyehq.medium.com/hamoye-data-science-internship-fall-2024-call-for-application-79488110376d',
#        'https://docs.google.com/forms/d/e/1FAIpQLSe9Sr9L3H7oObSSZSB-qndQYNal1OGGcyTBfOppZLyuOKWPRg/viewform',
#        'Problem statement 🌚', 'EDA + Classification + Power BI',
#        '= certificate', 'Some network issue', 'No join again',
#        'same link join', 'Join the same link', 'Please let me in',
#        "Tomorrow's machine learning class will start at 2 15 pm",
#        'Join the link', 'CREATE TABLE event (', 'join the same link',
#        'ds join the same link', 'same', 'Let me into the class.',
#        'network issue', 'Ok', 'wait couple of minutes',
#        'Join the same link..', '.', 'in akkettilla', 'Network issue und',
#        'Wait', 'ok', 'Join', 'Class ille', '??',
#        'https://www.kdnuggets.com/2020/06/naive-bayes-algorithm-everything.html',
#        '\U0001f6dc WiFi Passwords\U0001f6dc',
#        'ML session will start at 2:15 pm', 'ML Same link', 'same limk',
#        'https://colab.research.google.com/drive/108YjV5uDkumB8aw5RMrie3rLCeyWcNk4?usp=sharing',
#        'Same link 9:35', 'Mandatory SQL Assessment',
#        'Tomorrow Dax class will be from 11.15- 1.15 PM',
#        'ML Class will be from 9 AM To 11 Am',
#        'https://meet.google.com/uew-zqmr-sth',
#        "I haven't received the SQL assessment @918618186237 ,send it ASAP",
#        'Where I I have to send it in  group', 'Send here',
#        'Power bi join the same link <This message was edited>',
#        'Power bi same link', 'screen poi', 'Join please', 'Monday ',
#        'Afternoon', 'Ille', 'Class kaanum afternoon for ds', 'join',
#        'dax same link',
#        'https://www.kaggle.com/datasets/brijbhushannanda1979/bigmart-sales-data',
#        'Download dataset from this link and perform EDA',
#        'and then apply any regression model', 'Complete this task today',
#        "We postponed today's afternoon session", 'ML class', '👍🏽',
#        'https://www.kaggle.com/competitions/titanic/data',
#        'PCA Tomorrow 11.30-1 and 2.15 -3.45', '4th floor aan class 11.30',
#        'https://meet.google.com/svp-wgoq-ajb', '2.30 join',
#        'https://www.microsoft.com/en-us/cloudskillschallenge/ai/registration/2024?ocid=aisc23_CSC_skillsforaiblog_cnl#choose-your-challenge',
#        'Tomorrow 2.00PM:Lecture On Recommendation Engines, build your first Recommender <This message was edited>',
#        'How many of you are attending Offline??', 'Im not', '🤚🏻', '✌🏻',
#        'Conference Hall <This message was edited>', 'No online class?',
#        'https://meet.google.com/yyp-ybak-jqd', 'You deleted this message',
#        'https://meet.google.com/jiy-cjvd-ums', 'join in this',
#        'https://meet.google.com/wpa-gyyd-kte',
#        'class starts @2.30 pm today <This message was edited>',
#        'https://github.com/JovianHQ/opendatasets/blob/master/data/countries-languages-spoken/countries-languages.csv <This message was edited>',
#        'Create a Country Recommender based on the language spoken',
#        'https://www.kaggle.com/datasets/dylanjcastillo/7k-books-with-metadata',
#        'Build a Book Recommender based on the description about the book',
#        'No class today, try to explore more recommendation systems using various datasets',
#        'Okay',
#        'https://www.youtube.com/live/wB7m2YMqVVY?si=IJq7IixEgva7Tu8t',
#        'live class of hamoye', 'Anyone offline??',
#        'https://us05web.zoom.us/j/89944631210?pwd=Vi6hcSNnsdHS5bQgh5r44jeHLt9Hgo.1',
#        'https://meet.google.com/eir-sawr-tui', 'rejoin',
#        'https://meet.google.com/xuo-ahea-zvc',
#        '*Create a recommendation system which recommends books or documents* Data:scrape data from websites like goodreads and scribd or any other website, do it and submit it before coming monday 9..00AM try <This message was edited>',
#        'Tomorrow onwards There will be two sessions are going on for *Data Science* students',
#        "today's class is there?",
#        'https://us05web.zoom.us/j/84356593130?pwd=tE40wZMVVhZahfQfpMlWmaiuQMdVEh.1',
#        'ML class?', 'join in this link',
#        'https://us05web.zoom.us/j/82662632874?pwd=lgeKSnCVezGajLEX1IeAx3TBlt6Xd8.1',
#        'https://us05web.zoom.us/j/83954675823?pwd=hZBXtKvZBMKaci3f79IzVd4Munacw5.1',
#        '2.30', 'next class', 'join immediately', 'link  comes',
#        'https://us05web.zoom.us/j/89882762836?pwd=f4OJJDwtrLYksEeOXGEua1VsSK1gS0.1',
#        'https://us05web.zoom.us/j/83124834127?pwd=CZnC3e1LCu4BZKbtXpoR8vdUF0bY8W.1',
#        'https://us05web.zoom.us/j/84698759689?pwd=jc3uaX38A8XKT9i8aGEyEeV4FGOhbD.1',
#        'last join',
#        'https://us05web.zoom.us/j/87597044212?pwd=eYhexXtU8wlpMxKP894sKaZ9ESCEFv.1',
#        'https://us05web.zoom.us/j/81088179003?pwd=4cy88JdC9vDOk311hla6REoyV4ZHw5.1',
#        'https://us05web.zoom.us/j/85900123290?pwd=dHszQjo1DUVTUUK0eulZhlDGN0ePKE.1',
#        'https://us05web.zoom.us/j/85320192983?pwd=mbloGXvXoW4fR5CrQ7tkevcaB2X2ZM.1',
#        'https://us05web.zoom.us/j/86955036516?pwd=bKixQEfWmQTdTbHwDigNVcsZSmkHx4.1',
#        'https://us05web.zoom.us/j/88418826144?pwd=AGMp0uqMGf2gF6uSZwgJ1HqTyAjXTi.1',
#        'https://us05web.zoom.us/j/83068961004?pwd=fwxUEnK21rZ1M2Qn46HBArPHwUiU2g.1',
#        'https://www.kaggle.com/datasets/zygmunt/goodbooks-10k',
#        'https://us05web.zoom.us/j/82196771153?pwd=5SBVgnTDk5F6vIjFduX0TzsL5VeCFa.1',
#        'https://us05web.zoom.us/j/81310056571?pwd=9bpbaQ6goaGabCrJPHmoKHR7oFPKu5.1',
#        'https://us05web.zoom.us/j/84126238187?pwd=WPsF79MUYkPRheBHE3vTRqdxLUqyml.1',
#        'https://us05web.zoom.us/j/88298798338?pwd=OXqo2o2NfHu3Ty2Y5hkua2Ut3KXCP0.1',
#        'https://us05web.zoom.us/j/84745853077?pwd=xmT9cP4e5uSFiaUD6dcLrnkabbRMfj.1',
#        'JOIN',
#        'https://us05web.zoom.us/j/85029807729?pwd=R2FC3g5JSz2Cmk2327RnGCnwrgbG1X.1',
#        'Please add in',
#        'https://us05web.zoom.us/j/84998061454?pwd=Hf7VPgXs9s10R6kaWHp9fSvP2SChXG.1',
#        'https://us05web.zoom.us/j/88476935533?pwd=NGwH2oEMx62JoUOu6XIcj7GgiLQiUh.1',
#        'https://www.kaggle.com/datasets/prajitdatta/movielens-100k-dataset/data',
#        'https://us05web.zoom.us/j/83223361006?pwd=nMcKtUZMKxPJcn2dbwfR4Y4nwFrLUW.1',
#        'https://us05web.zoom.us/j/82183401601?pwd=B90w2RLezed2fSwwFytoVvbjDG3R1R.1',
#        'https://us05web.zoom.us/j/87644185104?pwd=UoZyDi9uVqE4COBvWTNKdXH6poOALK.1',
#        'https://us05web.zoom.us/j/83719435591?pwd=OAOinOmRv6owb4ur0XT7Xc4ezDCEhj.1',
#        'https://us05web.zoom.us/j/87168841298?pwd=6pkmUIjKiEwwVYMpLNv844bEVoGyC3.1',
#        'join at 2.30 pm',
#        'https://us05web.zoom.us/j/86285461568?pwd=m4IKlxw6ASWObFncC4hONqzuG7JJV9.1',
#        'https://us05web.zoom.us/j/82808190042?pwd=0NVFr47d2PDPGOC1ONwDGNvaTiep8q.1',
#        'https://us05web.zoom.us/j/85777199753?pwd=lPVl2Yd5x1iJXohgGXhRdE0fbWH4rv.1',
#        'https://visualstudio.microsoft.com/visual-cpp-build-tools/',
#        'Link?',
#        'https://us05web.zoom.us/j/84172735576?pwd=p9JDPvN1splta73xe0e0cJEljAxU14.1',
#        'https://us05web.zoom.us/j/86837283209?pwd=BiZRMT5mflOnTH7qv9PkvLXpKekvja.1',
#        'https://us05web.zoom.us/j/87894573653?pwd=dalYPnEGwRnvhYF9wXb5tXmMWhaZX6.1',
#        'https://us05web.zoom.us/j/89958400034?pwd=pB3kaxEXbSBonzej9ZjYhnOdDycChI.1',
#        'https://us05web.zoom.us/j/81104718108?pwd=QZabNNMb5lDbC8ddg3lwXjTrRjb2nG.1',
#        '*market basket analysis*',
#        'https://us05web.zoom.us/j/88244453101?pwd=FdH0PcnOXMSjsT3A0IoaQShXNKbsa7.1',
#        'https://us04web.zoom.us/j/72173791910?pwd=bADdLHM7aJFqaHJxatinEs1GK6Fm7N.1',
#        'https://sampleportfolio-a7brzwhi85rmvtef4wngqj.streamlit.app/',
#        'let me know if you have any doubts',
#        'https://meet.google.com/hnf-wehd-ypx', 'Those who submitted :',
#        '',
#        'https://us05web.zoom.us/j/88538105805?pwd=ZSYtpaIb5n02IwfADmkStah47tWKqU.1',
#        'https://deploy-asnafidha.streamlit.app', 'Sorry',
#        'https://us05web.zoom.us/j/81270550054?pwd=jDnkE79Y8JliuNVoPkuHfKE0oLexcG.1',
#        'https://us05web.zoom.us/j/84088354300?pwd=DI2TLClARzPcf4dRnppAt8ajLO0g0v.1',
#        'https://us05web.zoom.us/j/85018623759?pwd=viFBEMe7js12WkpzvnsNHG2pawwhjY.1',
#        'https://us04web.zoom.us/j/79134534643?pwd=n6ka0KpC5XbqUF1YBiVDfGJLBp0gI7.1',
#        'https://us05web.zoom.us/j/87430068127?pwd=bEX00IJNqEAzL9YvMhVEdtahO84GbN.1',
#        'https://us05web.zoom.us/j/86927643942?pwd=UNWBUduc0ahzwvaZbweOP4QIBxPtrC.1',
#        'https://us05web.zoom.us/j/86189409946?pwd=jKxbPOLxwZKt3G3FLpoaY1dk3MMp7I.1',
#        'Perform the same > AR model on Female Birth Data', '3.35 pm',
#        'https://us04web.zoom.us/j/76691224273?pwd=bby3tlcIi3rHzVyg4jYSBjd2cntbtq.1',
#        'Perform the same on the shampoo dataset',
#        'Please share the final notebook', 'k',
#        'modify the days of prediction',
#        'like if you want to predict for the last 15 days or 30 days and so on',
#        '@919946189970',
#        'https://www.kaggle.com/datasets/niketchauhan/covid-19-time-series-data',
#        'Link to Covid 19 dataset', 'choose one country from this data',
#        'and perform AutoRegression in order to find the covid cases',
#        'try different countries and compare results',
#        'submit it before monday',
#        "Tomorrow's Data Science session is scheduled at 2:30 pm",
#        'How many of u are attending online?', '✋🏼', '🤚🏽', '🤚',
#        'For those in attendance offline, the session will take place in the last classroom.',
#        'https://us05web.zoom.us/j/87110841572?pwd=OWJbPWbvehs3oWoB949WmyAFXXQwMB.1',
#        'Invalid meeting id',
#        'https://us05web.zoom.us/j/84426665904?pwd=eW10ScuhCCcu6diyauNYhTVsWoM9LB.1',
#        'https://atlas.mitre.org/matrices/ATLAS',
#        'https://incidentdatabase.ai/',
#        'https://us05web.zoom.us/j/86732036320?pwd=yaIPNxa9hp9B6H5j9Ai3ptzuqqSWmu.1',
#        'https://meet.google.com/vrs-wvoh-zng',
#        'https://us05web.zoom.us/j/84146894791?pwd=0FGmCXYSFl4GRMAUUQxPIJnr0y189w.1',
#        'https://us05web.zoom.us/j/85738513589?pwd=PzjFyd46iBkdv6jWYqDb4hKhaLaBWb.1',
#        'https://us05web.zoom.us/j/86258974313?pwd=ZO778uGGRCZaZ1rXJjEE9zDaMxvhCK.1',
#        'https://us05web.zoom.us/j/81324776140?pwd=NqfRe3VCI7kv6hNjXNG26xsxSFBLUh.1',
#        'https://us05web.zoom.us/j/85302314572?pwd=LQlX8uiB8lxqGwzHLCuDih5lmgj0XW.1',
#        'https://www.youtube.com/watch?v=aircAruvnKk&t=784s',
#        'https://us05web.zoom.us/j/81956643317?pwd=a2Dnir1U7fq4Y1fPoLoKt4KysYsVlm.1',
#        'https://us05web.zoom.us/j/83794961231?pwd=LSLhV9pdiXCEiEHkkFmNNoW09m7PCJ.1',
#        'https://us05web.zoom.us/j/83432770790?pwd=15aIavmf3exCGAUn0MLQRw3ZW2B8VY.1',
#        "Tomorrow's schedule", 'anyone offline?', 'online 🙌🏻',
#        'https://us05web.zoom.us/j/89768721231?pwd=RUHgbb3leOUDroj4M26QHtIdPloj3g.1',
#        'link',
#        'https://us05web.zoom.us/j/81690932462?pwd=BG1xPitPTZx0ZMQ1jATFbswR3XqJuG.1',
#        'https://us05web.zoom.us/j/86546468416?pwd=vgLrHWK0l0WMw6nfgT0Mb2qzUdcyOG.1',
#        'https://us05web.zoom.us/j/82347408592?pwd=bap6BJ5lpH0Q6qOw9rofMePqx75Ovm.1',
#        'https://www.youtube.com/playlist?list=PLvcbYUQ5t0UHOLnBzl46_Q6QKtFgfMGc3',
#        '@918593099647 innalathem innathem notebooks share ako', 'okay',
#        'Anyone offline', 'https://meet.google.com/ihx-eeyg-mwi',
#        '🔴 session rescheduled to 3 pm tomorrow',
#        'https://colab.research.google.com/drive/1klJqPJr4dvIQsX6fWjT6I4CRU4iqUEqH?usp=sharing',
#        'Go through the gradient descent topics that we learned for linear models.',
#        "Its necessary for tomorrow's session",
#        'We have offline session tomorrow at 11 am', 'ANYONE OFFLINE?',
#        'https://us05web.zoom.us/j/87386242572?pwd=ELelyhYQxEmPNwtWba2ZLmEDF23Et9.1',
#        'https://us05web.zoom.us/j/88583487724?pwd=gey9tmKciyfuaRjqapQa9bMCPkMy3t.1',
#        'https://us05web.zoom.us/j/81380987479?pwd=G50yjRywUHypiqguW4p02RW9wqCqzN.1',
#        'reamining will discuss in the next class, take a look at Logistic regression',
#        'class will start soon',
#        'https://us05web.zoom.us/j/84975007689?pwd=h6wFrvavIAMux0cnHnaZyPadbGeFvN.1',
#        'Let me in', '@919778218181 meet',
#        'https://us05web.zoom.us/j/81890576665?pwd=c1QHxvO4aEIEXCNernGf85Yy6VVQJ1.1',
#        'https://us06web.zoom.us/j/82998391278?pwd=UKupeIbzYEOwemN7P4Uw5ArRaANN7k.1',
#        'ini aarenkilum join cheyyunnundo?', 'Yes', '@917736866448 ???',
#        'Sir please let me in', '@918593099647',
#        'https://us06web.zoom.us/j/85864309016?pwd=Yw5Zb7Ha739FPtz6n1rm74TCVSBpiU.1',
#        'Notebook', 'Recording also',
#        'check out this tutorials from tensorflow itself, https://www.tensorflow.org/tutorials',
#        "Today's class starts @2.30 PM everyone be on time :",
#        'https://us06web.zoom.us/j/81668957371?pwd=YwBWdXxDTkypIwrWcfIutDfBzzWbw8.1',
#        'B- blood kittaan indo arelm', 'Positive nd',
#        'https://us06web.zoom.us/j/85790204001?pwd=aUmiRhNSlP3WI2WkMRzmzb5lfHaJAv.1',
#        'https://us06web.zoom.us/j/82211794464?pwd=9jODZBXpZGvJziz15TInGkFKfqh6Db.1',
#        'class starts @2.30pm',
#        'https://us06web.zoom.us/j/89079927141?pwd=uAuUKsCJ3HYLV9XSdtrIfFhAM4Zlua.1',
#        'https://us06web.zoom.us/j/84819824369?pwd=W91jLH9SSz2dwjsfUqaJnCezd6OIxy.1',
#        'https://www.kaggle.com/datasets/gauravtopre/bank-customer-churn-dataset',
#        'class starts @2.30 on CNN',
#        'https://us06web.zoom.us/j/84150849582?pwd=E5eNW8ZSXcnQe7krTJ3ynobU9l8qxR.1',
#        'CLASS WILL START @2.30 ON TFL AND PADDING ANS STRIPE',
#        'https://us06web.zoom.us/j/88676945662?pwd=qtkCSpiakGI73ENb4BuLxM3JmhIMKM.1',
#        'Unable to join', 'Facing network issues',
#        'https://us06web.zoom.us/j/84774931149?pwd=IZhaEyGogISiuWUJwcbaZWxaFs5WK8.1',
#        'asap',
#        'https://us06web.zoom.us/j/89735874355?pwd=KtdBvYzjffeLwYbyA3HUzt7VwpuKw1.1',
#        'complete this task and  implement CNN on top of any image dataset',
#        'imlement CNN on flowers dataset as well',
#        'and submit those notes before monday afternoon',
#        'Tomorrow you will not have regular session instead you will be assigned a task and it will be consider as your Deep Learning *Mini Project* <This message was edited>',
#        'Ok sir',
#        'class starts @2.30 on Introduction to Computer Vision and Image manipulation',
#        'https://us06web.zoom.us/j/89163859148?pwd=lyAoMKZRNWAgriZ9pai2IszdGQ293o.1',
#        'https://us06web.zoom.us/j/85373550975?pwd=yo9UTFvYwPycn4CedQmbipCrb3kFVi.1',
#        '@919037649226 ????', '@917907733950 ??//', 'On the way',
#        'offline aano?', 'Alla', 'Connection issue', 'Athaan',
#        'please let me in',
#        'amal look at this :https://www.tutorialspoint.com/opencv/index.htm',
#        'https://us06web.zoom.us/j/83628900360?pwd=4dpav7Gb3MahIZyHBeeHSY3ktU1pu6.1',
#        'https://us06web.zoom.us/j/88443754683?pwd=TSaHXIo2KIsgMhkPeVZkEuaDFd8l2W.1',
#        'Dear Students,', 'Reminder:',
#        "Since the review plan interviews are going on , you won't have data science session today",
#        'Since I do have a meeting scheduled today CV classes are postponed to Saturday (from morning to evening)',
#        "And those who are attending today's Aptitude test , this is a rare chance any interview will not complete without aptitude and mental ability so make sure to attend",
#        'https://us06web.zoom.us/j/82621147975?pwd=Wcj697cm8G6LqtjDXzNr6PDpsaY7KI.1',
#        'https://us06web.zoom.us/j/84505621870?pwd=s8h800UVxjg6EybmgL8AyplvEm4Qst.1',
#        'https://us04web.zoom.us/j/5019495850?pwd=dENBUnN6a043bzlHcGpJY3Ara2lWZz09',
#        'https://us04web.zoom.us/j/74450854485?pwd=E1z5A4tcHiQkI3Tui6iNrKrMl0LxqE.1',
#        'everyone must attend github class @2.30 everyone can attend those can attend offline be offline and others can join through online *Dont Miss It*',
#        'https://meet.google.com/wfx-cszi-iyb',
#        "How many of you are attending today's GIT class?",
#        'and how many attended yesterday?',
#        "I have attended yesterday's class", 'what about today?', 'Me',
#        'Will attend through online', 'dont miss it guys',
#        'you will not get its recordings',
#        'very much crucial for  team work <This message was edited>',
#        'Yesterday attended.... Today through online',
#        'class starts @2.30 pm', 'git or cv', 'cv',
#        'https://meet.google.com/tfq-dyhi-aoa',
#        'Anyone attending interview today?', 'class @2.30',
#        'https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09',
#        'Practice Computer Vision Tasks Which we are discussed by taking different images and push it inside Git',
#        'Today we do have git classes @2.30 from Dilshad sir *from scratch* how many of are going to attend?? let me know if you are not attending i will go with CV class (There are many things which we are not disccused in our classroom in git so it will be really helpfull) , i want to know before 1.00PM',
#        'I will attend', 'anyone else?', 'he will explain from scratch',
#        '✋🏻', 'try to do practicals',
#        'then only you will get know the mistakes and ask doubts he will rectify it',
#        'will attend', 'Sir link?', 'become late', 'just started',
#        'join now', 'otherwise you cant follow', '🔴Review plan update :',
#        'join in the same link', 'Join in this link for git session',
#        'You guys can now access the entire course recordings go through it accordingly (you will be notified in your mail)',
#        'let me know if you dont', 'Notification already sent?', 'ya',
#        '@919946189970  your mail id?', 'jishnumss7@gmail.com',
#        'Received . Thanks', 'Recieved', 'Received', 'Not received',
#        'Go through the CNN section and we will continue our discussion from tomorrow onwards',
#        'Class @2.30 PM', 'join <This message was edited>',
#        'Workout try it on different images', 'Object Detection',
#        'Resources', 'try out',
#        'and implement other image processing techniques',
#        'We will start our NLP (Natural Language Processing) session from tomorrow (6/1/2024) 2.30PM onwards',
#        'Please admit', "There won't be any session this afternoon",
#        "There won't be any session today",
#        'Complete your regex assignment and share the GitHub link',
#        "We'll resume your NLP sessions from tomorrow ", 'joinn',
#        'anyone joining?', 'Yes, sir oru 5 mins',
#        '@919037649226 are you join??', 'yes', 'sir notebook share cheyuo',
#        'any more people joining? <This message was edited>',
#        'will wait until 2.45', 'Sir', 'Njn ind', 'let me in', 'hi',
#        'class starts at 2.30pm', 'Link',
#        'Monday onwards you will get Class on Django for MLOPS your last session',
#        'class starts @2.30',
#        'we are planning to give a 30 days Project Bootcamp for this batch *30 days 30 Projects*, where we will build 30 end to end projects from various domains which we are discussed in our entire curriculum. how many of you are interested ?? i need everyone to attend the session otherwise we will drop the plan every day 2 hrs , if you are interested let me know.',
#        'Iam interested', '👍🏼',
#        'jisshnu.___ (DS-Codeme) added Nayana(OldBatch) J Nair',
#        "Today's session postponed to 3.pm",
#        'https://meet.google.com/exf-ftsp-xpg',
#        'https://blogs.oracle.com/oracleuniversity/post/announcing-oci-2024-generative-ai-professional-certification-and-course',
#        'join all',
#        '🎤Since the django session has been completed we will be starting our 30 Days Project session from  Thursday August-1 by taking projects from ML,CV,DL,RECOMMENDER ENGINES AND SO ON *let me know how many of you are in* ?',
#        'let me know how many of you are in?', 'Count me in',
#        'Those who attending the Camp',
#        'We will be starting our project session from Tomorrow onwards',
#        '*Day 1 of Project Bootcamp*', '*Day 2 of Project Bootcamp*',
#        'Waiting..', 'Who can join today and coming lectures:',
#        'https://www.pwc.in/careers/experienced-jobs/description.html?wdjobreqid=554074WD&wdcountry=IND&jobtitle=Specialist%203&wdjobsite=Global_Experienced_Careers',
#        'pwc fresher opening for ds,apply asap',
#        'those who are not submitted the project task will get a chance to submit their project link before 2.30pm today'],
#       dtype=object)

# %%
df[df['Message']=='<Media omitted>']
# Out:
#              Message            Date                     User   Only date  \
# 14   <Media omitted>   28/02/24 1:20      Aysha Hamna(CodeMe)  2024-02-28
# 20   <Media omitted>  01/03/24 12:06      Aysha Hamna(CodeMe)  2024-01-03
# 30   <Media omitted>   04/03/24 1:23            Asif (CodeMe)  2024-04-03
# 34   <Media omitted>   04/03/24 5:58  jisshnu.___ (DS-Codeme)  2024-04-03
# 36   <Media omitted>  05/03/24 10:07  jisshnu.___ (DS-Codeme)  2024-05-03
# ..               ...             ...                      ...         ...
# 591  <Media omitted>   15/07/24 5:53                  NISAMLC  2024-07-15
# 604  <Media omitted>   18/07/24 4:02                  NISAMLC  2024-07-18
# 609  <Media omitted>   19/07/24 3:43                  NISAMLC  2024-07-19
# 610  <Media omitted>   19/07/24 3:54                  NISAMLC  2024-07-19
# 623  <Media omitted>   24/07/24 1:01  jisshnu.___ (DS-Codeme)  2024-07-24
#
#      Year  Month_num     Month  Day   Day_name  Hour  Minute
# 14   2024          2  February   28  Wednesday     1      20
# 20   2024          1   January    3  Wednesday    12       6
# 30   2024          4     April    3  Wednesday     1      23
# 34   2024          4     April    3  Wednesday     5      58
# 36   2024          5       May    3     Friday    10       7
# ..    ...        ...       ...  ...        ...   ...     ...
# 591  2024          7      July   15     Monday     5      53
# 604  2024          7      July   18   Thursday     4       2
# 609  2024          7      July   19     Friday     3      43
# 610  2024          7      July   19     Friday     3      54
# 623  2024          7      July   24  Wednesday     1       1
#
# [72 rows x 11 columns]

# %%
df['User'].value_counts().head()
# Out:
# User
# NISAMLC                    288
# Asif (CodeMe)               72
# Aysha Hamna(CodeMe)         71
# jisshnu.___ (DS-Codeme)     68
# Rashid (DS-Codeme)          39
# Name: count, dtype: int64

# %%
counts = df['User'].value_counts().head()
plt.figure(figsize=(15,7))
plt.bar(counts.index,counts.values)
plt.xticks(rotation = 'vertical')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'NISAMLC'),
#   Text(1, 0, 'Asif (CodeMe)'),
#   Text(2, 0, 'Aysha Hamna(CodeMe)'),
#   Text(3, 0, 'jisshnu.___ (DS-Codeme)'),
#   Text(4, 0, 'Rashid (DS-Codeme)')])

# %%
df.dtypes
# Out:
# Message      object
# Date         object
# User         object
# Only date    object
# Year          int32
# Month_num     int32
# Month        object
# Day           int32
# Day_name     object
# Hour          int32
# Minute        int32
# dtype: object

# %%
# computationally heavy

wordmap = {}
for message in df['Message']:
    dummy = message.split()
    for word in dummy:
        if word in wordmap:
            wordmap[word]+=1
            
        else:
            wordmap[word] = 1
            
            
wordmap = dict(sorted(wordmap.items(),key = lambda x:x[1],reverse = True))

wordmap
# Out:
# {'<Media': 72,
#  'omitted>': 72,
#  'join': 67,
#  'the': 40,
#  'message': 33,
#  'link': 31,
#  'will': 30,
#  'was': 28,
#  'class': 26,
#  'to': 25,
#  'in': 24,
#  'and': 23,
#  'same': 23,
#  'deleted': 22,
#  'are': 21,
#  'this': 19,
#  'you': 19,
#  'session': 19,
#  'This': 18,
#  'me': 15,
#  'from': 15,
#  'of': 14,
#  'on': 14,
#  'be': 13,
#  'it': 12,
#  'starts': 12,
#  '@2.30': 12,
#  'for': 11,
#  'https://us06web.zoom.us/j/6732259030?pwd=QXpZc0V2SS84cS9CTGJBMUt5LzJCUT09': 11,
#  'let': 10,
#  '<This': 10,
#  'edited>': 10,
#  'we': 10,
#  '✋🏻': 10,
#  'many': 9,
#  'a': 9,
#  'not': 8,
#  'your': 8,
#  'at': 8,
#  'pm': 8,
#  'have': 8,
#  'any': 8,
#  'attend': 8,
#  'try': 7,
#  'Join': 7,
#  'today': 7,
#  'attending': 7,
#  'know': 7,
#  'can': 6,
#  'how': 6,
#  'Class': 6,
#  'please': 6,
#  'Please': 6,
#  'Ok': 6,
#  'Tomorrow': 6,
#  'I': 6,
#  'through': 6,
#  'our': 6,
#  'or': 5,
#  'jisshnu.___': 5,
#  '(DS-Codeme)': 5,
#  'do': 5,
#  'project': 5,
#  'Same': 5,
#  'ML': 5,
#  'dataset': 5,
#  'online': 5,
#  'You': 5,
#  'rejoin': 5,
#  'before': 5,
#  'onwards': 5,
#  'if': 5,
#  'who': 5,
#  'days': 5,
#  '30': 5,
#  '✋🏼': 5,
#  'those': 5,
#  'offline': 5,
#  'tomorrow': 5,
#  '@2.30pm': 5,
#  'No': 4,
#  'added': 4,
#  'i': 4,
#  'data': 4,
#  'https://meet.google.com/ind-raij-vzt': 4,
#  'Power': 4,
#  'issue': 4,
#  "Tomorrow's": 4,
#  'start': 4,
#  'ok': 4,
#  'afternoon': 4,
#  'task': 4,
#  'We': 4,
#  "today's": 4,
#  'Okay': 4,
#  'submit': 4,
#  'immediately': 4,
#  'last': 4,
#  'JOIN': 4,
#  'Link?': 4,
#  ':': 4,
#  'share': 4,
#  'k': 4,
#  'okay': 4,
#  'everyone': 4,
#  'CNN': 4,
#  'sir': 4,
#  ',': 4,
#  'get': 4,
#  'git': 4,
#  'Received': 4,
#  'Project': 4,
#  'then': 3,
#  'meeting': 3,
#  'SAME': 3,
#  'LINK': 3,
#  'network': 3,
#  '2': 3,
#  'Let': 3,
#  'PM': 3,
#  'bi': 3,
#  'postponed': 3,
#  '2.30': 3,
#  'Recommender': 3,
#  'How': 3,
#  'class?': 3,
#  'Anyone': 3,
#  'which': 3,
#  'monday': 3,
#  'There': 3,
#  'going': 3,
#  'is': 3,
#  'Those': 3,
#  'submitted': 3,
#  'so': 3,
#  'different': 3,
#  'anyone': 3,
#  '@918593099647': 3,
#  'Sir': 3,
#  'Dear': 3,
#  'Students,': 3,
#  'Reminder:': 3,
#  'plan': 3,
#  "won't": 3,
#  'interested': 3,
#  'one': 2,
#  'group': 2,
#  'science': 2,
#  '+91': 2,
#  'first': 2,
#  'only': 2,
#  'also': 2,
#  'here': 2,
#  'test': 2,
#  'using': 2,
#  'no': 2,
#  'https://meet.google.com/ewj-ckus-jmv': 2,
#  'EDA': 2,
#  '+': 2,
#  '15': 2,
#  'ds': 2,
#  'wait': 2,
#  '.': 2,
#  '??': 2,
#  'SQL': 2,
#  '11': 2,
#  'https://meet.google.com/uew-zqmr-sth': 2,
#  'received': 2,
#  'Monday': 2,
#  'perform': 2,
#  'regression': 2,
#  'model': 2,
#  'Complete': 2,
#  'On': 2,
#  'build': 2,
#  '🤚🏻': 2,
#  'based': 2,
#  'about': 2,
#  'more': 2,
#  'recommendation': 2,
#  'various': 2,
#  'like': 2,
#  'other': 2,
#  'coming': 2,
#  'sessions': 2,
#  'next': 2,
#  'add': 2,
#  'doubts': 2,
#  'Perform': 2,
#  'Data': 2,
#  'notebook': 2,
#  'want': 2,
#  '@919946189970': 2,
#  'Link': 2,
#  'scheduled': 2,
#  'take': 2,
#  'schedule': 2,
#  'Go': 2,
#  'look': 2,
#  'Yes': 2,
#  'out': 2,
#  "Today's": 2,
#  'ON': 2,
#  'AND': 2,
#  'asap': 2,
#  'complete': 2,
#  'implement': 2,
#  'image': 2,
#  'as': 2,
#  'Computer': 2,
#  'Vision': 2,
#  '@919037649226': 2,
#  'Since': 2,
#  'CV': 2,
#  'classes': 2,
#  'chance': 2,
#  'interview': 2,
#  'https://meet.google.com/wfx-cszi-iyb': 2,
#  'attended': 2,
#  'today?': 2,
#  'Me': 2,
#  'dont': 2,
#  'guys': 2,
#  'recordings': 2,
#  'Today': 2,
#  'cv': 2,
#  'discussed': 2,
#  'by': 2,
#  'taking': 2,
#  'images': 2,
#  'go': 2,
#  'he': 2,
#  'now': 2,
#  'otherwise': 2,
#  'entire': 2,
#  'NLP': 2,
#  'joining?': 2,
#  '2.30pm': 2,
#  'end': 2,
#  'projects': 2,
#  '👍🏼': 2,
#  'https://meet.google.com/exf-ftsp-xpg': 2,
#  'all': 2,
#  'starting': 2,
#  '*Day': 2,
#  'Bootcamp*': 2,
#  'Messages': 1,
#  'calls': 1,
#  'end-to-end': 1,
#  'encrypted.': 1,
#  'outside': 1,
#  'chat,': 1,
#  'even': 1,
#  'WhatsApp,': 1,
#  'read': 1,
#  'listen': 1,
#  'them.': 1,
#  'Tap': 1,
#  'learn': 1,
#  'more.': 1,
#  'created': 1,
#  '"Data': 1,
#  '"': 1,
#  '86181': 1,
#  '86237': 1,
#  'yourself': 1,
#  'refer': 1,
#  'collab': 1,
#  'https://colab.research.google.com/drive/1tKXB0p6bcZ4gwTUNjp9zNpRMYxC952qj?usp=sharing': 1,
#  'https://meet.google.com/xsu-gthd-hmw': 1,
#  'https://colab.research.google.com/drive/1b_r9LNdmeSGUUIlFSQUteLKw07ESr5iQ?usp=sharing': 1,
#  'https://colab.research.google.com/drive/1yIHdz2bMzzLvGqh1Dq02AAwyYFbnJAf-?usp=sharing': 1,
#  'Refer': 1,
#  'while': 1,
#  'doing': 1,
#  'understand': 1,
#  'use': 1,
#  'sampling': 1,
#  'techniques.': 1,
#  'balanced': 1,
#  'after': 1,
#  'splitting': 1,
#  'train': 1,
#  'https://meet.google.com/sdk-sqzo-unn': 1,
#  'https://docs.google.com/document/d/1SlzY5P0wQPr8ZsgBUc4m1mkr-fu-nlRZqBu_am2ZH2M/edit?usp=sharing': 1,
#  'https://meet.google.com/xut-tqwq-pcd': 1,
#  '79077': 1,
#  '33950': 1,
#  'https://colab.research.google.com/drive/1ljIcfFMyAOJpIRWrrWa-61vppqIydnRU?usp=sharing': 1,
#  'https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit?usp=sharing': 1,
#  'https://meet.google.com/uiv-vkou-pda': 1,
#  'https://colab.research.google.com/drive/1P9fduGtId539V1MYs2ScQLPC6Ph8PrSx?usp=sharing': 1,
#  'started?': 1,
#  'https://docs.google.com/spreadsheets/d/1MEyfPtRx9ybLxzYXI6In0tDkfOGAuM0nBHzT5tziM_s/edit#gid=0': 1,
#  'It’s': 1,
#  'showing': 1,
#  'such': 1,
#  'https://meet.google.com/zpy-qjbm-sbj': 1,
#  'Waiting': 1,
#  'https://hamoyehq.medium.com/hamoye-data-science-internship-fall-2024-call-for-application-79488110376d': 1,
#  'https://docs.google.com/forms/d/e/1FAIpQLSe9Sr9L3H7oObSSZSB-qndQYNal1OGGcyTBfOppZLyuOKWPRg/viewform': 1,
#  'Problem': 1,
#  'statement': 1,
#  '🌚': 1,
#  'Classification': 1,
#  'BI': 1,
#  '=': 1,
#  'certificate': 1,
#  'Some': 1,
#  'again': 1,
#  'machine': 1,
#  'learning': 1,
#  'CREATE': 1,
#  'TABLE': 1,
#  'event': 1,
#  '(': 1,
#  'into': 1,
#  'class.': 1,
#  'couple': 1,
#  'minutes': 1,
#  'link..': 1,
#  'akkettilla': 1,
#  'Network': 1,
#  'und': 1,
#  'Wait': 1,
#  'ille': 1,
#  'https://www.kdnuggets.com/2020/06/naive-bayes-algorithm-everything.html': 1,
#  '\U0001f6dc': 1,
#  'WiFi': 1,
#  'Passwords\U0001f6dc': 1,
#  '2:15': 1,
#  'limk': 1,
#  'https://colab.research.google.com/drive/108YjV5uDkumB8aw5RMrie3rLCeyWcNk4?usp=sharing': 1,
#  '9:35': 1,
#  'Mandatory': 1,
#  'Assessment': 1,
#  'Dax': 1,
#  '11.15-': 1,
#  '1.15': 1,
#  '9': 1,
#  'AM': 1,
#  'To': 1,
#  'Am': 1,
#  "haven't": 1,
#  'assessment': 1,
#  '@918618186237': 1,
#  ',send': 1,
#  'ASAP': 1,
#  'Where': 1,
#  'send': 1,
#  'Send': 1,
#  'screen': 1,
#  'poi': 1,
#  'Afternoon': 1,
#  'Ille': 1,
#  'kaanum': 1,
#  'dax': 1,
#  'https://www.kaggle.com/datasets/brijbhushannanda1979/bigmart-sales-data': 1,
#  'Download': 1,
#  'apply': 1,
#  '👍🏽': 1,
#  'https://www.kaggle.com/competitions/titanic/data': 1,
#  'PCA': 1,
#  '11.30-1': 1,
#  '2.15': 1,
#  '-3.45': 1,
#  '4th': 1,
#  'floor': 1,
#  'aan': 1,
#  '11.30': 1,
#  'https://meet.google.com/svp-wgoq-ajb': 1,
#  'https://www.microsoft.com/en-us/cloudskillschallenge/ai/registration/2024?ocid=aisc23_CSC_skillsforaiblog_cnl#choose-your-challenge': 1,
#  '2.00PM:Lecture': 1,
#  'Recommendation': 1,
#  'Engines,': 1,
#  'Offline??': 1,
#  'Im': 1,
#  '✌🏻': 1,
#  'Conference': 1,
#  'Hall': 1,
#  'https://meet.google.com/yyp-ybak-jqd': 1,
#  'https://meet.google.com/jiy-cjvd-ums': 1,
#  'https://meet.google.com/wpa-gyyd-kte': 1,
#  'https://github.com/JovianHQ/opendatasets/blob/master/data/countries-languages-spoken/countries-languages.csv': 1,
#  'Create': 1,
#  'Country': 1,
#  'language': 1,
#  'spoken': 1,
#  'https://www.kaggle.com/datasets/dylanjcastillo/7k-books-with-metadata': 1,
#  'Build': 1,
#  'Book': 1,
#  'description': 1,
#  'book': 1,
#  'today,': 1,
#  'explore': 1,
#  'systems': 1,
#  'datasets': 1,
#  'https://www.youtube.com/live/wB7m2YMqVVY?si=IJq7IixEgva7Tu8t': 1,
#  'live': 1,
#  'hamoye': 1,
#  'offline??': 1,
#  'https://us05web.zoom.us/j/89944631210?pwd=Vi6hcSNnsdHS5bQgh5r44jeHLt9Hgo.1': 1,
#  'https://meet.google.com/eir-sawr-tui': 1,
#  'https://meet.google.com/xuo-ahea-zvc': 1,
#  '*Create': 1,
#  'system': 1,
#  'recommends': 1,
#  'books': 1,
#  'documents*': 1,
#  'Data:scrape': 1,
#  'websites': 1,
#  'goodreads': 1,
#  'scribd': 1,
#  'website,': 1,
#  '9..00AM': 1,
#  'two': 1,
#  '*Data': 1,
#  'Science*': 1,
#  'students': 1,
#  'there?': 1,
#  'https://us05web.zoom.us/j/84356593130?pwd=tE40wZMVVhZahfQfpMlWmaiuQMdVEh.1': 1,
#  'https://us05web.zoom.us/j/82662632874?pwd=lgeKSnCVezGajLEX1IeAx3TBlt6Xd8.1': 1,
#  'https://us05web.zoom.us/j/83954675823?pwd=hZBXtKvZBMKaci3f79IzVd4Munacw5.1': 1,
#  'comes': 1,
#  'https://us05web.zoom.us/j/89882762836?pwd=f4OJJDwtrLYksEeOXGEua1VsSK1gS0.1': 1,
#  'https://us05web.zoom.us/j/83124834127?pwd=CZnC3e1LCu4BZKbtXpoR8vdUF0bY8W.1': 1,
#  'https://us05web.zoom.us/j/84698759689?pwd=jc3uaX38A8XKT9i8aGEyEeV4FGOhbD.1': 1,
#  'https://us05web.zoom.us/j/87597044212?pwd=eYhexXtU8wlpMxKP894sKaZ9ESCEFv.1': 1,
#  'https://us05web.zoom.us/j/81088179003?pwd=4cy88JdC9vDOk311hla6REoyV4ZHw5.1': 1,
#  'https://us05web.zoom.us/j/85900123290?pwd=dHszQjo1DUVTUUK0eulZhlDGN0ePKE.1': 1,
#  'https://us05web.zoom.us/j/85320192983?pwd=mbloGXvXoW4fR5CrQ7tkevcaB2X2ZM.1': 1,
#  'https://us05web.zoom.us/j/86955036516?pwd=bKixQEfWmQTdTbHwDigNVcsZSmkHx4.1': 1,
#  'https://us05web.zoom.us/j/88418826144?pwd=AGMp0uqMGf2gF6uSZwgJ1HqTyAjXTi.1': 1,
#  'https://us05web.zoom.us/j/83068961004?pwd=fwxUEnK21rZ1M2Qn46HBArPHwUiU2g.1': 1,
#  'https://www.kaggle.com/datasets/zygmunt/goodbooks-10k': 1,
#  'https://us05web.zoom.us/j/82196771153?pwd=5SBVgnTDk5F6vIjFduX0TzsL5VeCFa.1': 1,
#  'https://us05web.zoom.us/j/81310056571?pwd=9bpbaQ6goaGabCrJPHmoKHR7oFPKu5.1': 1,
#  'https://us05web.zoom.us/j/84126238187?pwd=WPsF79MUYkPRheBHE3vTRqdxLUqyml.1': 1,
#  'https://us05web.zoom.us/j/88298798338?pwd=OXqo2o2NfHu3Ty2Y5hkua2Ut3KXCP0.1': 1,
#  'https://us05web.zoom.us/j/84745853077?pwd=xmT9cP4e5uSFiaUD6dcLrnkabbRMfj.1': 1,
#  'https://us05web.zoom.us/j/85029807729?pwd=R2FC3g5JSz2Cmk2327RnGCnwrgbG1X.1': 1,
#  'https://us05web.zoom.us/j/84998061454?pwd=Hf7VPgXs9s10R6kaWHp9fSvP2SChXG.1': 1,
#  'https://us05web.zoom.us/j/88476935533?pwd=NGwH2oEMx62JoUOu6XIcj7GgiLQiUh.1': 1,
#  'https://www.kaggle.com/datasets/prajitdatta/movielens-100k-dataset/data': 1,
#  'https://us05web.zoom.us/j/83223361006?pwd=nMcKtUZMKxPJcn2dbwfR4Y4nwFrLUW.1': 1,
#  'https://us05web.zoom.us/j/82183401601?pwd=B90w2RLezed2fSwwFytoVvbjDG3R1R.1': 1,
#  'https://us05web.zoom.us/j/87644185104?pwd=UoZyDi9uVqE4COBvWTNKdXH6poOALK.1': 1,
#  'https://us05web.zoom.us/j/83719435591?pwd=OAOinOmRv6owb4ur0XT7Xc4ezDCEhj.1': 1,
#  'https://us05web.zoom.us/j/87168841298?pwd=6pkmUIjKiEwwVYMpLNv844bEVoGyC3.1': 1,
#  'https://us05web.zoom.us/j/86285461568?pwd=m4IKlxw6ASWObFncC4hONqzuG7JJV9.1': 1,
#  'https://us05web.zoom.us/j/82808190042?pwd=0NVFr47d2PDPGOC1ONwDGNvaTiep8q.1': 1,
#  'https://us05web.zoom.us/j/85777199753?pwd=lPVl2Yd5x1iJXohgGXhRdE0fbWH4rv.1': 1,
#  'https://visualstudio.microsoft.com/visual-cpp-build-tools/': 1,
#  'https://us05web.zoom.us/j/84172735576?pwd=p9JDPvN1splta73xe0e0cJEljAxU14.1': 1,
#  'https://us05web.zoom.us/j/86837283209?pwd=BiZRMT5mflOnTH7qv9PkvLXpKekvja.1': 1,
#  'https://us05web.zoom.us/j/87894573653?pwd=dalYPnEGwRnvhYF9wXb5tXmMWhaZX6.1': 1,
#  'https://us05web.zoom.us/j/89958400034?pwd=pB3kaxEXbSBonzej9ZjYhnOdDycChI.1': 1,
#  'https://us05web.zoom.us/j/81104718108?pwd=QZabNNMb5lDbC8ddg3lwXjTrRjb2nG.1': 1,
#  '*market': 1,
#  'basket': 1,
#  'analysis*': 1,
#  'https://us05web.zoom.us/j/88244453101?pwd=FdH0PcnOXMSjsT3A0IoaQShXNKbsa7.1': 1,
#  'https://us04web.zoom.us/j/72173791910?pwd=bADdLHM7aJFqaHJxatinEs1GK6Fm7N.1': 1,
#  'https://sampleportfolio-a7brzwhi85rmvtef4wngqj.streamlit.app/': 1,
#  'https://meet.google.com/hnf-wehd-ypx': 1,
#  'https://us05web.zoom.us/j/88538105805?pwd=ZSYtpaIb5n02IwfADmkStah47tWKqU.1': 1,
#  'https://deploy-asnafidha.streamlit.app': 1,
#  'Sorry': 1,
#  'https://us05web.zoom.us/j/81270550054?pwd=jDnkE79Y8JliuNVoPkuHfKE0oLexcG.1': 1,
#  'https://us05web.zoom.us/j/84088354300?pwd=DI2TLClARzPcf4dRnppAt8ajLO0g0v.1': 1,
#  'https://us05web.zoom.us/j/85018623759?pwd=viFBEMe7js12WkpzvnsNHG2pawwhjY.1': 1,
#  'https://us04web.zoom.us/j/79134534643?pwd=n6ka0KpC5XbqUF1YBiVDfGJLBp0gI7.1': 1,
#  'https://us05web.zoom.us/j/87430068127?pwd=bEX00IJNqEAzL9YvMhVEdtahO84GbN.1': 1,
#  'https://us05web.zoom.us/j/86927643942?pwd=UNWBUduc0ahzwvaZbweOP4QIBxPtrC.1': 1,
#  'https://us05web.zoom.us/j/86189409946?pwd=jKxbPOLxwZKt3G3FLpoaY1dk3MMp7I.1': 1,
#  '>': 1,
#  'AR': 1,
#  'Female': 1,
#  'Birth': 1,
#  '3.35': 1,
#  'https://us04web.zoom.us/j/76691224273?pwd=bby3tlcIi3rHzVyg4jYSBjd2cntbtq.1': 1,
#  'shampoo': 1,
#  'final': 1,
#  'modify': 1,
#  'prediction': 1,
#  'predict': 1,
#  'https://www.kaggle.com/datasets/niketchauhan/covid-19-time-series-data': 1,
#  'Covid': 1,
#  '19': 1,
#  'choose': 1,
#  'country': 1,
#  'AutoRegression': 1,
#  'order': 1,
#  'find': 1,
#  'covid': 1,
#  'cases': 1,
#  'countries': 1,
#  'compare': 1,
#  'results': 1,
#  'Science': 1,
#  '2:30': 1,
#  'u': 1,
#  'online?': 1,
#  '🤚🏽': 1,
#  '🤚': 1,
#  'For': 1,
#  'attendance': 1,
#  'offline,': 1,
#  'place': 1,
#  'classroom.': 1,
#  'https://us05web.zoom.us/j/87110841572?pwd=OWJbPWbvehs3oWoB949WmyAFXXQwMB.1': 1,
#  'Invalid': 1,
#  'id': 1,
#  'https://us05web.zoom.us/j/84426665904?pwd=eW10ScuhCCcu6diyauNYhTVsWoM9LB.1': 1,
#  'https://atlas.mitre.org/matrices/ATLAS': 1,
#  'https://incidentdatabase.ai/': 1,
#  'https://us05web.zoom.us/j/86732036320?pwd=yaIPNxa9hp9B6H5j9Ai3ptzuqqSWmu.1': 1,
#  'https://meet.google.com/vrs-wvoh-zng': 1,
#  'https://us05web.zoom.us/j/84146894791?pwd=0FGmCXYSFl4GRMAUUQxPIJnr0y189w.1': 1,
#  'https://us05web.zoom.us/j/85738513589?pwd=PzjFyd46iBkdv6jWYqDb4hKhaLaBWb.1': 1,
#  'https://us05web.zoom.us/j/86258974313?pwd=ZO778uGGRCZaZ1rXJjEE9zDaMxvhCK.1': 1,
#  'https://us05web.zoom.us/j/81324776140?pwd=NqfRe3VCI7kv6hNjXNG26xsxSFBLUh.1': 1,
#  'https://us05web.zoom.us/j/85302314572?pwd=LQlX8uiB8lxqGwzHLCuDih5lmgj0XW.1': 1,
#  'https://www.youtube.com/watch?v=aircAruvnKk&t=784s': 1,
#  'https://us05web.zoom.us/j/81956643317?pwd=a2Dnir1U7fq4Y1fPoLoKt4KysYsVlm.1': 1,
#  'https://us05web.zoom.us/j/83794961231?pwd=LSLhV9pdiXCEiEHkkFmNNoW09m7PCJ.1': 1,
#  'https://us05web.zoom.us/j/83432770790?pwd=15aIavmf3exCGAUn0MLQRw3ZW2B8VY.1': 1,
#  'offline?': 1,
#  '🙌🏻': 1,
#  'https://us05web.zoom.us/j/89768721231?pwd=RUHgbb3leOUDroj4M26QHtIdPloj3g.1': 1,
#  'https://us05web.zoom.us/j/81690932462?pwd=BG1xPitPTZx0ZMQ1jATFbswR3XqJuG.1': 1,
#  'https://us05web.zoom.us/j/86546468416?pwd=vgLrHWK0l0WMw6nfgT0Mb2qzUdcyOG.1': 1,
#  'https://us05web.zoom.us/j/82347408592?pwd=bap6BJ5lpH0Q6qOw9rofMePqx75Ovm.1': 1,
#  'https://www.youtube.com/playlist?list=PLvcbYUQ5t0UHOLnBzl46_Q6QKtFgfMGc3': 1,
#  'innalathem': 1,
#  'innathem': 1,
#  'notebooks': 1,
#  'ako': 1,
#  'https://meet.google.com/ihx-eeyg-mwi': 1,
#  '🔴': 1,
#  'rescheduled': 1,
#  '3': 1,
#  'https://colab.research.google.com/drive/1klJqPJr4dvIQsX6fWjT6I4CRU4iqUEqH?usp=sharing': 1,
#  'gradient': 1,
#  'descent': 1,
#  'topics': 1,
#  'that': 1,
#  'learned': 1,
#  'linear': 1,
#  'models.': 1,
#  'Its': 1,
#  'necessary': 1,
#  "tomorrow's": 1,
#  'am': 1,
#  'ANYONE': 1,
#  'OFFLINE?': 1,
#  'https://us05web.zoom.us/j/87386242572?pwd=ELelyhYQxEmPNwtWba2ZLmEDF23Et9.1': 1,
#  'https://us05web.zoom.us/j/88583487724?pwd=gey9tmKciyfuaRjqapQa9bMCPkMy3t.1': 1,
#  'https://us05web.zoom.us/j/81380987479?pwd=G50yjRywUHypiqguW4p02RW9wqCqzN.1': 1,
#  'reamining': 1,
#  'discuss': 1,
#  'class,': 1,
#  'Logistic': 1,
#  'soon': 1,
#  'https://us05web.zoom.us/j/84975007689?pwd=h6wFrvavIAMux0cnHnaZyPadbGeFvN.1': 1,
#  '@919778218181': 1,
#  'meet': 1,
#  'https://us05web.zoom.us/j/81890576665?pwd=c1QHxvO4aEIEXCNernGf85Yy6VVQJ1.1': 1,
#  'https://us06web.zoom.us/j/82998391278?pwd=UKupeIbzYEOwemN7P4Uw5ArRaANN7k.1': 1,
#  'ini': 1,
#  'aarenkilum': 1,
#  'cheyyunnundo?': 1,
#  '@917736866448': 1,
#  '???': 1,
#  'https://us06web.zoom.us/j/85864309016?pwd=Yw5Zb7Ha739FPtz6n1rm74TCVSBpiU.1': 1,
#  'Notebook': 1,
#  'Recording': 1,
#  'check': 1,
#  'tutorials': 1,
#  'tensorflow': 1,
#  'itself,': 1,
#  'https://www.tensorflow.org/tutorials': 1,
#  'time': 1,
#  'https://us06web.zoom.us/j/81668957371?pwd=YwBWdXxDTkypIwrWcfIutDfBzzWbw8.1': 1,
#  'B-': 1,
#  'blood': 1,
#  'kittaan': 1,
#  'indo': 1,
#  'arelm': 1,
#  'Positive': 1,
#  'nd': 1,
#  'https://us06web.zoom.us/j/85790204001?pwd=aUmiRhNSlP3WI2WkMRzmzb5lfHaJAv.1': 1,
#  'https://us06web.zoom.us/j/82211794464?pwd=9jODZBXpZGvJziz15TInGkFKfqh6Db.1': 1,
#  'https://us06web.zoom.us/j/89079927141?pwd=uAuUKsCJ3HYLV9XSdtrIfFhAM4Zlua.1': 1,
#  'https://us06web.zoom.us/j/84819824369?pwd=W91jLH9SSz2dwjsfUqaJnCezd6OIxy.1': 1,
#  'https://www.kaggle.com/datasets/gauravtopre/bank-customer-churn-dataset': 1,
#  'https://us06web.zoom.us/j/84150849582?pwd=E5eNW8ZSXcnQe7krTJ3ynobU9l8qxR.1': 1,
#  'CLASS': 1,
#  'WILL': 1,
#  'START': 1,
#  'TFL': 1,
#  'PADDING': 1,
#  'ANS': 1,
#  'STRIPE': 1,
#  'https://us06web.zoom.us/j/88676945662?pwd=qtkCSpiakGI73ENb4BuLxM3JmhIMKM.1': 1,
#  'Unable': 1,
#  'Facing': 1,
#  'issues': 1,
#  'https://us06web.zoom.us/j/84774931149?pwd=IZhaEyGogISiuWUJwcbaZWxaFs5WK8.1': 1,
#  'https://us06web.zoom.us/j/89735874355?pwd=KtdBvYzjffeLwYbyA3HUzt7VwpuKw1.1': 1,
#  'top': 1,
#  'imlement': 1,
#  'flowers': 1,
#  'well': 1,
#  'notes': 1,
#  'regular': 1,
#  'instead': 1,
#  'assigned': 1,
#  'consider': 1,
#  'Deep': 1,
#  'Learning': 1,
#  '*Mini': 1,
#  'Project*': 1,
#  'Introduction': 1,
#  'Image': 1,
#  'manipulation': 1,
#  'https://us06web.zoom.us/j/89163859148?pwd=lyAoMKZRNWAgriZ9pai2IszdGQ293o.1': 1,
#  'https://us06web.zoom.us/j/85373550975?pwd=yo9UTFvYwPycn4CedQmbipCrb3kFVi.1': 1,
#  '????': 1,
#  '@917907733950': 1,
#  '??//': 1,
#  'way': 1,
#  'aano?': 1,
#  'Alla': 1,
#  'Connection': 1,
#  'Athaan': 1,
#  'amal': 1,
#  ':https://www.tutorialspoint.com/opencv/index.htm': 1,
#  'https://us06web.zoom.us/j/83628900360?pwd=4dpav7Gb3MahIZyHBeeHSY3ktU1pu6.1': 1,
#  'https://us06web.zoom.us/j/88443754683?pwd=TSaHXIo2KIsgMhkPeVZkEuaDFd8l2W.1': 1,
#  'review': 1,
#  'interviews': 1,
#  'Saturday': 1,
#  '(from': 1,
#  'morning': 1,
#  'evening)': 1,
#  'And': 1,
#  'Aptitude': 1,
#  'rare': 1,
#  'without': 1,
#  'aptitude': 1,
#  'mental': 1,
#  'ability': 1,
#  'make': 1,
#  'sure': 1,
#  'https://us06web.zoom.us/j/82621147975?pwd=Wcj697cm8G6LqtjDXzNr6PDpsaY7KI.1': 1,
#  'https://us06web.zoom.us/j/84505621870?pwd=s8h800UVxjg6EybmgL8AyplvEm4Qst.1': 1,
#  'https://us04web.zoom.us/j/5019495850?pwd=dENBUnN6a043bzlHcGpJY3Ara2lWZz09': 1,
#  'https://us04web.zoom.us/j/74450854485?pwd=E1z5A4tcHiQkI3Tui6iNrKrMl0LxqE.1': 1,
#  'must': 1,
#  'github': 1,
#  'others': 1,
#  '*Dont': 1,
#  'Miss': 1,
#  'It*': 1,
#  'GIT': 1,
#  'yesterday?': 1,
#  "yesterday's": 1,
#  'what': 1,
#  'Will': 1,
#  'miss': 1,
#  'its': 1,
#  'very': 1,
#  'much': 1,
#  'crucial': 1,
#  'team': 1,
#  'work': 1,
#  'Yesterday': 1,
#  'attended....': 1,
#  'https://meet.google.com/tfq-dyhi-aoa': 1,
#  'Practice': 1,
#  'Tasks': 1,
#  'Which': 1,
#  'push': 1,
#  'inside': 1,
#  'Git': 1,
#  'Dilshad': 1,
#  '*from': 1,
#  'scratch*': 1,
#  'attend??': 1,
#  'with': 1,
#  '(There': 1,
#  'things': 1,
#  'disccused': 1,
#  'classroom': 1,
#  'really': 1,
#  'helpfull)': 1,
#  '1.00PM': 1,
#  'else?': 1,
#  'explain': 1,
#  'scratch': 1,
#  'practicals': 1,
#  'mistakes': 1,
#  'ask': 1,
#  'rectify': 1,
#  'link?': 1,
#  'become': 1,
#  'late': 1,
#  'just': 1,
#  'started': 1,
#  'cant': 1,
#  'follow': 1,
#  '🔴Review': 1,
#  'update': 1,
#  'access': 1,
#  'course': 1,
#  'accordingly': 1,
#  '(you': 1,
#  'notified': 1,
#  'mail)': 1,
#  'Notification': 1,
#  'already': 1,
#  'sent?': 1,
#  'ya': 1,
#  'mail': 1,
#  'id?': 1,
#  'jishnumss7@gmail.com': 1,
#  'Thanks': 1,
#  'Recieved': 1,
#  'Not': 1,
#  'section': 1,
#  'continue': 1,
#  'discussion': 1,
#  'Workout': 1,
#  'Object': 1,
#  'Detection': 1,
#  'Resources': 1,
#  'processing': 1,
#  'techniques': 1,
#  '(Natural': 1,
#  'Language': 1,
#  'Processing)': 1,
#  '(6/1/2024)': 1,
#  '2.30PM': 1,
#  'admit': 1,
#  'regex': 1,
#  'assignment': 1,
#  'GitHub': 1,
#  "We'll": 1,
#  'resume': 1,
#  'joinn': 1,
#  'Yes,': 1,
#  'oru': 1,
#  '5': 1,
#  'mins': 1,
#  'join??': 1,
#  'yes': 1,
#  'cheyuo': 1,
#  'people': 1,
#  'until': 1,
#  '2.45': 1,
#  'Njn': 1,
#  'ind': 1,
#  'hi': 1,
#  'Django': 1,
#  'MLOPS': 1,
#  'planning': 1,
#  'give': 1,
#  'Bootcamp': 1,
#  'batch': 1,
#  '*30': 1,
#  'Projects*,': 1,
#  'where': 1,
#  'domains': 1,
#  'curriculum.': 1,
#  'need': 1,
#  'drop': 1,
#  'every': 1,
#  'day': 1,
#  'hrs': 1,
#  'know.': 1,
#  'Iam': 1,
#  'Nayana(OldBatch)': 1,
#  'J': 1,
#  'Nair': 1,
#  '3.pm': 1,
#  'https://blogs.oracle.com/oracleuniversity/post/announcing-oci-2024-generative-ai-professional-certification-and-course': 1,
#  '🎤Since': 1,
#  'django': 1,
#  'has': 1,
#  'been': 1,
#  'completed': 1,
#  'Days': 1,
#  'Thursday': 1,
#  'August-1': 1,
#  'ML,CV,DL,RECOMMENDER': 1,
#  'ENGINES': 1,
#  'SO': 1,
#  '*let': 1,
#  'in*': 1,
#  '?': 1,
#  'in?': 1,
#  'Count': 1,
#  'Camp': 1,
#  '1': 1,
#  'Waiting..': 1,
#  'Who': 1,
#  'lectures:': 1,
#  'https://www.pwc.in/careers/experienced-jobs/description.html?wdjobreqid=554074WD&wdcountry=IND&jobtitle=Specialist%203&wdjobsite=Global_Experienced_Careers': 1,
#  'pwc': 1,
#  'fresher': 1,
#  'opening': 1,
#  'ds,apply': 1,
#  'their': 1}

# %%
# top 20 words used in the whatsapp group

from collections import Counter
words = []
for message in df['Message']:
    words.extend(message.split())
    
wordmap = dict(Counter(words).most_common(20))
wordmap = dict(sorted(wordmap.items(),key=lambda x:x[1],reverse=True))
newdf = pd.DataFrame(wordmap.items())
newdf
# Out:
#            0   1
# 0     <Media  72
# 1   omitted>  72
# 2       join  67
# 3        the  40
# 4    message  33
# 5       link  31
# 6       will  30
# 7        was  28
# 8      class  26
# 9         to  25
# 10        in  24
# 11       and  23
# 12      same  23
# 13   deleted  22
# 14       are  21
# 15      this  19
# 16       you  19
# 17   session  19
# 18      This  18
# 19        me  15

# %%
temp = df[(df['User']!='Group Notification') | (df['User']!='<Media omitted>')]
temp
# Out:
#                                                Message            Date  \
# 0    Messages and calls are end-to-end encrypted. N...   26/02/24 3:50
# 1    jisshnu.___ (DS-Codeme) created group "Data sc...   26/02/24 3:01
# 2                    jisshnu.___ (DS-Codeme) added you   26/02/24 3:50
# 3        jisshnu.___ (DS-Codeme) added +91 86181 86237   26/02/24 3:51
# 4    try to do the project  yourself first then onl...   26/02/24 3:51
# ..                                                 ...             ...
# 643                                          Waiting..   02/08/24 2:35
# 644            Who can join today and coming lectures:   02/08/24 2:36
# 645  https://www.pwc.in/careers/experienced-jobs/de...   03/08/24 2:36
# 646              pwc fresher opening for ds,apply asap   03/08/24 2:37
# 647  those who are not submitted the project task w...  05/08/24 10:22
#
#                         User   Only date  Year  Month_num     Month  Day  \
# 0         Group Notification  2024-02-26  2024          2  February   26
# 1         Group Notification  2024-02-26  2024          2  February   26
# 2         Group Notification  2024-02-26  2024          2  February   26
# 3         Group Notification  2024-02-26  2024          2  February   26
# 4    jisshnu.___ (DS-Codeme)  2024-02-26  2024          2  February   26
# ..                       ...         ...   ...        ...       ...  ...
# 643       Rashid (DS-Codeme)  2024-02-08  2024          2  February    8
# 644                  NISAMLC  2024-02-08  2024          2  February    8
# 645            Asif (CodeMe)  2024-03-08  2024          3     March    8
# 646            Asif (CodeMe)  2024-03-08  2024          3     March    8
# 647                  NISAMLC  2024-05-08  2024          5       May    8
#
#       Day_name  Hour  Minute
# 0       Monday     3      50
# 1       Monday     3       1
# 2       Monday     3      50
# 3       Monday     3      51
# 4       Monday     3      51
# ..         ...   ...     ...
# 643   Thursday     2      35
# 644   Thursday     2      36
# 645     Friday     2      36
# 646     Friday     2      37
# 647  Wednesday    10      22
#
# [648 rows x 11 columns]

# %%
def gettopwords(selecteduser,df):

    # getting the stopwords

    file = open('stop_hinglish.txt','r')
    stopwords = file.read()
    stopwords = stopwords.split('\n')
    
    if selecteduser!='Overall':
        df = df[df['User']==selecteduser]
        
    temp = df[(df['User']!='Group Notification') |
             (df['User']!='<Media omitted>')]
    
    words = []
    
    for message in df['Message']:
        for word in message.lower().split():
            if word not in stopwords:
                words.append(word)
                
    
    mostcommon = pd.DataFrame(Counter(words).most_common(20))
    return mostcommon



mostcommon = gettopwords('Overall',df)

mostcommon
# Out:
#                                                     0   1
# 0                                                join  78
# 1                                              <media  72
# 2                                            omitted>  72
# 3                                                link  36
# 4                                               class  33
# 5                                             message  33
# 6                                             deleted  22
# 7                                             session  19
# 8                                              starts  12
# 9                                               @2.30  12
# 10                                                 pm  11
# 11                                           tomorrow  11
# 12  https://us06web.zoom.us/j/6732259030?pwd=qxpzc...  11
# 13                                              <this  10
# 14                                            edited>  10
# 15                                                 ✋🏻  10
# 16                                            project   9
# 17                                              today   9
# 18                                             attend   8
# 19                                          attending   7

# %% [raw]
# !pip install emoji

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#                                               0.0/431.4 kB ? eta -:--:--
#      --------------                         163.8/431.4 kB 5.0 MB/s eta 0:00:01
#      -------------------------------------- 431.4/431.4 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from emoji) (4.9.0)
# Installing collected packages: emoji
# Successfully installed emoji-2.12.1
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\LENOVO\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\LENOVO\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\LENOVO\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\LENOVO\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\LENOVO\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\LENOVO\AppData\Roaming\Python\Python311\site-packages)

# %%
import emoji

# %%
def emojihelp(selecteduser,df):
    
    if selecteduser!='Overall':
        df = df[df['User']==selecteduser]
        
    emojis = []
    for message in df['Message']:
        emojis.extend([c for c in message if c in emoji.EMOJI_DATA])
        
    
    emojidf = pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))
    
    return emojidf


dfmoji = emojihelp('Overall',df)
dfmoji
# Out:
#     0   1
# 0   ✋  15
# 1   🏻  14
# 2   🏼   7
# 3   🤚   4
# 4   👍   3
# 5   🛜   2
# 6   🏽   2
# 7   🔴   2
# 8   🌚   1
# 9   ✌   1
# 10  🙌   1
# 11  🎤   1

# %%
dfmoji.columns = ['Emoji','Count']
dfmoji
# Out:
#    Emoji  Count
# 0      ✋     15
# 1      🏻     14
# 2      🏼      7
# 3      🤚      4
# 4      👍      3
# 5      🛜      2
# 6      🏽      2
# 7      🔴      2
# 8      🌚      1
# 9      ✌      1
# 10     🙌      1
# 11     🎤      1

# %%
df.head()
# Out:
#                                              Message           Date  \
# 0  Messages and calls are end-to-end encrypted. N...  26/02/24 3:50
# 1  jisshnu.___ (DS-Codeme) created group "Data sc...  26/02/24 3:01
# 2                  jisshnu.___ (DS-Codeme) added you  26/02/24 3:50
# 3      jisshnu.___ (DS-Codeme) added +91 86181 86237  26/02/24 3:51
# 4  try to do the project  yourself first then onl...  26/02/24 3:51
#
#                       User   Only date  Year  Month_num     Month  Day  \
# 0       Group Notification  2024-02-26  2024          2  February   26
# 1       Group Notification  2024-02-26  2024          2  February   26
# 2       Group Notification  2024-02-26  2024          2  February   26
# 3       Group Notification  2024-02-26  2024          2  February   26
# 4  jisshnu.___ (DS-Codeme)  2024-02-26  2024          2  February   26
#
#   Day_name  Hour  Minute
# 0   Monday     3      50
# 1   Monday     3       1
# 2   Monday     3      50
# 3   Monday     3      51
# 4   Monday     3      51

# %%
def monthtimeline(selecteduser,df):
    temp = df.groupby(['Year','Month_num','Month']).count()['Message'].reset_index().sort_values(['Message'])
    
    time = []
    for i in range(temp.shape[0]):
        time.append(temp['Month'][i]+"-"+str(temp['Year'][i]))

    temp['Time'] = time
    return temp

# %%
df.head()
# Out:
#                                              Message           Date  \
# 0  Messages and calls are end-to-end encrypted. N...  26/02/24 3:50
# 1  jisshnu.___ (DS-Codeme) created group "Data sc...  26/02/24 3:01
# 2                  jisshnu.___ (DS-Codeme) added you  26/02/24 3:50
# 3      jisshnu.___ (DS-Codeme) added +91 86181 86237  26/02/24 3:51
# 4  try to do the project  yourself first then onl...  26/02/24 3:51
#
#                       User   Only date  Year  Month_num     Month  Day  \
# 0       Group Notification  2024-02-26  2024          2  February   26
# 1       Group Notification  2024-02-26  2024          2  February   26
# 2       Group Notification  2024-02-26  2024          2  February   26
# 3       Group Notification  2024-02-26  2024          2  February   26
# 4  jisshnu.___ (DS-Codeme)  2024-02-26  2024          2  February   26
#
#   Day_name  Hour  Minute
# 0   Monday     3      50
# 1   Monday     3       1
# 2   Monday     3      50
# 3   Monday     3      51
# 4   Monday     3      51

# %%
temp = df.groupby(['Year','Month_num','Month']).count()['Message'].reset_index()
temp
# Out:
#     Year  Month_num      Month  Message
# 0   2024          1    January       30
# 1   2024          2   February       34
# 2   2024          3      March      102
# 3   2024          4      April      164
# 4   2024          5        May       90
# 5   2024          6       June       84
# 6   2024          7       July       64
# 7   2024          8     August       20
# 8   2024          9  September       11
# 9   2024         10    October       12
# 10  2024         11   November       22
# 11  2024         12   December       15

# %%
temp = df.groupby(['Year','Month_num','Month']).count()['Message'].reset_index()
temp
# Out:
#     Year  Month_num      Month  Message
# 0   2024          1    January       30
# 1   2024          2   February       34
# 2   2024          3      March      102
# 3   2024          4      April      164
# 4   2024          5        May       90
# 5   2024          6       June       84
# 6   2024          7       July       64
# 7   2024          8     August       20
# 8   2024          9  September       11
# 9   2024         10    October       12
# 10  2024         11   November       22
# 11  2024         12   December       15

# %%
temp.shape
# Out:
# (12, 4)

# %%
str(temp['Month'][0])+"-"+str(temp['Year'][0])
# Out:
# 'January-2024'

# %%
time = []
for i in range(temp.shape[0]):
    time.append(temp['Month'][i]+ "-" +str(temp['Year'][i]))
    
temp['Time'] = time

temp
# Out:
#     Year  Month_num      Month  Message            Time
# 0   2024          1    January       30    January-2024
# 1   2024          2   February       34   February-2024
# 2   2024          3      March      102      March-2024
# 3   2024          4      April      164      April-2024
# 4   2024          5        May       90        May-2024
# 5   2024          6       June       84       June-2024
# 6   2024          7       July       64       July-2024
# 7   2024          8     August       20     August-2024
# 8   2024          9  September       11  September-2024
# 9   2024         10    October       12    October-2024
# 10  2024         11   November       22   November-2024
# 11  2024         12   December       15   December-2024

# %%
temp
# Out:
#     Year  Month_num      Month  Message            Time
# 0   2024          1    January       30    January-2024
# 1   2024          2   February       34   February-2024
# 2   2024          3      March      102      March-2024
# 3   2024          4      April      164      April-2024
# 4   2024          5        May       90        May-2024
# 5   2024          6       June       84       June-2024
# 6   2024          7       July       64       July-2024
# 7   2024          8     August       20     August-2024
# 8   2024          9  September       11  September-2024
# 9   2024         10    October       12    October-2024
# 10  2024         11   November       22   November-2024
# 11  2024         12   December       15   December-2024

# %%
df.head()
# Out:
#                                              Message           Date  \
# 0  Messages and calls are end-to-end encrypted. N...  26/02/24 3:50
# 1  jisshnu.___ (DS-Codeme) created group "Data sc...  26/02/24 3:01
# 2                  jisshnu.___ (DS-Codeme) added you  26/02/24 3:50
# 3      jisshnu.___ (DS-Codeme) added +91 86181 86237  26/02/24 3:51
# 4  try to do the project  yourself first then onl...  26/02/24 3:51
#
#                       User   Only date  Year  Month_num     Month  Day  \
# 0       Group Notification  2024-02-26  2024          2  February   26
# 1       Group Notification  2024-02-26  2024          2  February   26
# 2       Group Notification  2024-02-26  2024          2  February   26
# 3       Group Notification  2024-02-26  2024          2  February   26
# 4  jisshnu.___ (DS-Codeme)  2024-02-26  2024          2  February   26
#
#   Day_name  Hour  Minute
# 0   Monday     3      50
# 1   Monday     3       1
# 2   Monday     3      50
# 3   Monday     3      51
# 4   Monday     3      51

# %%
temp1 = df['Day_name'].value_counts()

# %%
temp1
# Out:
# Day_name
# Wednesday    164
# Thursday     126
# Monday       117
# Tuesday      108
# Friday        72
# Saturday      31
# Sunday        30
# Name: count, dtype: int64

# %%
list(temp1.index)
# Out:
# ['Wednesday', 'Thursday', 'Monday', 'Tuesday', 'Friday', 'Saturday', 'Sunday']

# %%
list(temp1.values)
# Out:
# [164, 126, 117, 108, 72, 31, 30]

# %%
temp2 = df['Month'].value_counts()

# %%
temp2
# Out:
# Month
# April        164
# March        102
# May           90
# June          84
# July          64
# February      34
# January       30
# November      22
# August        20
# December      15
# October       12
# September     11
# Name: count, dtype: int64

# %%
list(temp2.index),list(temp2.values)
# Out:
# (['April',
#   'March',
#   'May',
#   'June',
#   'July',
#   'February',
#   'January',
#   'November',
#   'August',
#   'December',
#   'October',
#   'September'],
#  [164, 102, 90, 84, 64, 34, 30, 22, 20, 15, 12, 11])

# %% [raw]
# def monthly_timeline(selected_user,df):
#
#     if selected_user != 'Overall':
#         df = df[df['user'] == selected_user]
#
#     timeline = df.groupby(['year', 'month_num', 'month']).count()['message'].reset_index()
#
#     time = []
#     for i in range(timeline.shape[0]):
#         time.append(timeline['month'][i] + "-" + str(timeline['year'][i]))
#
#     timeline['time'] = time
#
#     return timeline
